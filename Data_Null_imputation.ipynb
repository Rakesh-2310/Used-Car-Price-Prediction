# %%
import pandas as pd
import numpy as np

# %%
def MMM_imputation(df, column_name, imputation_method):
    """
    Impute missing values in a specified column using the chosen method.

    Parameters:
    - df: DataFrame to be processed.
    - column_name: Name of the column to impute.
    - imputation_method: Method of imputation ('mode', 'median', or 'mean').

    Returns:
    - None: The function modifies the DataFrame in place.
    """
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")

    if imputation_method == "mode":
        mode_value = df[column_name].mode()
        if mode_value.empty:
            raise ValueError(f"Mode could not be computed for column '{column_name}'.")
        df[column_name].fillna(mode_value[0], inplace=True)
    elif imputation_method == "median":
        if not pd.api.types.is_numeric_dtype(df[column_name]):
            raise ValueError(f"Median imputation is not applicable for non-numeric column '{column_name}'.")
        median_value = df[column_name].median()
        df[column_name].fillna(median_value, inplace=True)
    elif imputation_method == "mean":
        if not pd.api.types.is_numeric_dtype(df[column_name]):
            raise ValueError(f"Mean imputation is not applicable for non-numeric column '{column_name}'.")
        mean_value = df[column_name].mean()
        df[column_name].fillna(mean_value, inplace=True)
    else:
        raise ValueError("Imputation method must be 'mode', 'median', or 'mean'.")

# %%
df = pd.read_excel("combined_data.xlsx")

# %%
df_edit = df.copy()
df_edit.drop('Transmission',axis=1,inplace=True)#drop the Duplicate column 
df_edit.columns = df_edit.columns.str.lower().str.replace(" ", "_")
pd.set_option('display.max_columns',None)
df_edit.head(1)
# Out:
#    it      ft         bt        km transmission  ownerno      owner     oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner  Maruti
#
#             model  modelyear  centralvariantid variantname     price  \
# 0  Maruti Celerio       2015              3979         VXI  ₹ 4 Lakh
#
#   priceactual  pricesaving  pricefixedtext  \
# 0         NaN          NaN             NaN
#
#                                  trendingtext.imgurl trendingtext.heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
#
#                      trendingtext.desc registration_year  \
# 0  High chances of sale in next 6 days              2015
#
#       insurance_validity fuel_type    seats    kms_driven   rto    ownership  \
# 0  Third Party insurance    Petrol  5 Seats  1,20,000 Kms  KA51  Third Owner
#
#   engine_displacement  year_of_manufacture  power_steering  \
# 0              998 cc               2015.0            True
#
#    power_windows_front  air_conditioner  heater  adjustable_head_lights  \
# 0                 True             True    True                    True
#
#    manually_adjustable_exterior_rear_view_mirror  centeral_locking  \
# 0                                           True              True
#
#    child_safety_locks  power_windows_rear  remote_trunk_opener  \
# 0                True                True                 True
#
#    remote_fuel_lid_opener  low_fuel_warning_light  accessory_power_outlet  \
# 0                    True                    True                    True
#
#    vanity_mirror  rear_seat_headrest  cup_holders_front  digital_odometer  \
# 0           True                True               True              True
#
#    electronic_multi_tripmeter  fabric_upholstery  glove_compartment  \
# 0                        True               True               True
#
#    digital_clock  wheel_covers  power_antenna  chrome_grille  \
# 0           True          True           True           True
#
#    day_night_rear_view_mirror  passenger_side_rear_view_mirror  \
# 0                        True                             True
#
#    halogen_headlamps  rear_seat_belts  door_ajar_warning  side_impact_beams  \
# 0               True             True               True               True
#
#    front_impact_beams  adjustable_seats  centrally_mounted_fuel_tank  \
# 0                True              True                         True
#
#    engine_immobilizer  anti_theft_device  fog_lights_front  \
# 0                True               True             False
#
#    anti_lock_braking_system  cd_player  trunk_light  \
# 0                     False      False        False
#
#    multifunction_steering_wheel  navigation_system  smart_access_card_entry  \
# 0                         False              False                    False
#
#    engine_start_stop_button  gear_shift_indicator  luggage_hook_and_net  \
# 0                     False                 False                 False
#
#    adjustable_steering  tachometer  leather_steering_wheel  \
# 0                False       False                   False
#
#    outside_temperature_display  height_adjustable_driver_seat  \
# 0                        False                          False
#
#    power_adjustable_exterior_rear_view_mirror  \
# 0                                       False
#
#    electric_folding_rear_view_mirror  rear_window_wiper  rear_window_washer  \
# 0                              False              False               False
#
#    rear_window_defogger  alloy_wheels  integrated_antenna  \
# 0                 False         False               False
#
#    outside_rear_view_mirror_turn_indicators  roof_rail  power_door_locks  \
# 0                                     False      False             False
#
#    driver_air_bag  passenger_air_bag  seat_belt_warning  keyless_entry  \
# 0           False              False              False          False
#
#    engine_check_warning  crash_sensor    ebd  follow_me_home_headlamps  \
# 0                 False         False  False                     False
#
#    rear_camera  speed_sensing_auto_door_lock  \
# 0        False                         False
#
#    pretensioners_and_force_limiter_seatbelts  impact_sensing_auto_door_lock  \
# 0                                      False                          False
#
#    no_of_airbags  radio  speakers_front  speakers_rear  integrated2din_audio  \
# 0          False  False           False          False                 False
#
#    usb_auxiliary_input  bluetooth  touch_screen  number_of_speaker  \
# 0                False      False         False              False
#
#    glove_box_cooling  driving_experience_control_eco  tinted_glass  \
# 0              False                           False         False
#
#    rear_spoiler  chrome_garnish  vehicle_stability_control_system  \
# 0         False           False                             False
#
#    rear_reading_lamp  rear_seat_centre_arm_rest  cup_holders_rear  \
# 0              False                      False             False
#
#    rear_acvents  air_quality_control  height_adjustable_front_seat_belts  \
# 0         False                False                               False
#
#    cruise_control  voice_control  audio_system_remote_control  leather_seats  \
# 0           False          False                        False          False
#
#    fog_lights_rear  traction_control  seat_lumbar_support  battery_saver  \
# 0            False             False                False          False
#
#    lane_change_indicator  sun_roof  automatic_driving_lights  \
# 0                  False     False                     False
#
#    anti_theft_alarm  automatic_head_lamps  isofix_child_seat_mounts  \
# 0             False                 False                     False
#
#    hill_assist  tailgate_ajar  brake_assist  steering_wheel_gearshift_paddles  \
# 0        False          False         False                             False
#
#    ledtaillights  cigarette_lighter  rain_sensing_wiper  drive_modes  \
# 0          False              False               False        False
#
#    active_noise_cancellation  adjustable_headrest  hands_free_tailgate  \
# 0                      False                False                False
#
#    dual_tone_dashboard  leather_wrap_gear_shift_selector  \
# 0                False                             False
#
#    dual_tone_body_colour  leddrls  ledheadlights  cornering_headlamps  \
# 0                  False    False          False                False
#
#    cornering_foglamps  side_air_bag_front  side_air_bag_rear  \
# 0               False               False              False
#
#    tyre_pressure_monitor  clutch_lock  anti_pinch_power_windows  knee_airbags  \
# 0                  False        False                     False         False
#
#    apple_car_play  android_auto  mirror_link  wireless_phone_charging  \
# 0           False         False        False                    False
#
#    compass  moon_roof  projector_headlamps  speed_alert  \
# 0    False      False                False        False
#
#    eletronic_stability_control  touch_screen_size  xenon_headlamps  \
# 0                        False              False            False
#
#    cd_changer  power_boot  rear_folding_table  smoke_headlamps  dvd_player  \
# 0       False       False               False            False       False
#
#    internal_storage  rear_entertainment_system  remote_engine_start_stop  \
# 0             False                      False                     False
#
#    ventilated_seats  ledfog_lamps  view360camera  geo_fence_alert  \
# 0             False         False          False            False
#
#    steering_mounted_tripmeter  remote_climate_control  \
# 0                       False                   False
#
#    remote_horn_light_control  heated_wing_mirror  side_stepper  \
# 0                      False               False         False
#
#    blind_spot_monitor  hill_descent_control  heads_up_display  \
# 0               False                 False             False
#
#    sos_emergency_assistance  cassette_player  find_my_car_location  \
# 0                     False            False                 False
#
#    wifi_connectivity  headlamp_washers  real_time_vehicle_tracking  \
# 0              False             False                       False
#
#    roof_carrier  smart_key_band  lane_watch_camera  removable_convertible_top  \
# 0         False           False              False                      False
#
#    power_folding3rd_row_seat    mileage  engine         max_power torque  \
# 0                      False  23.1 kmpl  998 CC  67.04bhp@6000rpm   90Nm
#
#    seats.1  color  engine_type  displacement    max_torque  no_of_cylinder  \
# 0      5.0  White  K10B Engine         998.0  90Nm@3500rpm             3.0
#
#    values_per_cylinder value_configuration fuel_suppy_system borex_stroke  \
# 0                  4.0                DOHC              MPFi   73 X 82 mm
#
#   compression_ratio turbo_charger super_charger  length   width  height  \
# 0            11.0:1            No            No  3715mm  1635mm  1565mm
#
#   wheel_base front_tread rear_tread kerb_weight gross_weight  gear_box  \
# 0     2425mm      1420mm     1410mm       835kg       1250kg  5 Speed
#
#   drive_type  seating_capacity steering_type turning_radius front_brake_type  \
# 0        FWD               5.0         Power     4.7 metres  Ventilated Disc
#
#   rear_brake_type top_speed   acceleration         tyre_type  no_door_numbers  \
# 0            Drum  150 Kmph  15.05 Seconds  Tubeless, Radial              5.0
#
#   cargo_volumn wheel_size alloy_wheel_size ground_clearance_unladen  \
# 0   235-litres        NaN              NaN                      NaN
#
#                                            car_links       city
# 0  https://www.cardekho.com/used-car-details/used...  bangalore

# %%
pd.set_option('display.max_rows',None)
df_edit.dtypes
# Out:
# it                                                 int64
# ft                                                object
# bt                                                object
# km                                                object
# transmission                                      object
# ownerno                                            int64
# owner                                             object
# oem                                               object
# model                                             object
# modelyear                                          int64
# centralvariantid                                   int64
# variantname                                       object
# price                                             object
# priceactual                                       object
# pricesaving                                      float64
# pricefixedtext                                   float64
# trendingtext.imgurl                               object
# trendingtext.heading                              object
# trendingtext.desc                                 object
# registration_year                                 object
# insurance_validity                                object
# fuel_type                                         object
# seats                                             object
# kms_driven                                        object
# rto                                               object
# ownership                                         object
# engine_displacement                               object
# year_of_manufacture                              float64
# power_steering                                      bool
# power_windows_front                                 bool
# air_conditioner                                     bool
# heater                                              bool
# adjustable_head_lights                              bool
# manually_adjustable_exterior_rear_view_mirror       bool
# centeral_locking                                    bool
# child_safety_locks                                  bool
# power_windows_rear                                  bool
# remote_trunk_opener                                 bool
# remote_fuel_lid_opener                              bool
# low_fuel_warning_light                              bool
# accessory_power_outlet                              bool
# vanity_mirror                                       bool
# rear_seat_headrest                                  bool
# cup_holders_front                                   bool
# digital_odometer                                    bool
# electronic_multi_tripmeter                          bool
# fabric_upholstery                                   bool
# glove_compartment                                   bool
# digital_clock                                       bool
# wheel_covers                                        bool
# power_antenna                                       bool
# chrome_grille                                       bool
# day_night_rear_view_mirror                          bool
# passenger_side_rear_view_mirror                     bool
# halogen_headlamps                                   bool
# rear_seat_belts                                     bool
# door_ajar_warning                                   bool
# side_impact_beams                                   bool
# front_impact_beams                                  bool
# adjustable_seats                                    bool
# centrally_mounted_fuel_tank                         bool
# engine_immobilizer                                  bool
# anti_theft_device                                   bool
# fog_lights_front                                    bool
# anti_lock_braking_system                            bool
# cd_player                                           bool
# trunk_light                                         bool
# multifunction_steering_wheel                        bool
# navigation_system                                   bool
# smart_access_card_entry                             bool
# engine_start_stop_button                            bool
# gear_shift_indicator                                bool
# luggage_hook_and_net                                bool
# adjustable_steering                                 bool
# tachometer                                          bool
# leather_steering_wheel                              bool
# outside_temperature_display                         bool
# height_adjustable_driver_seat                       bool
# power_adjustable_exterior_rear_view_mirror          bool
# electric_folding_rear_view_mirror                   bool
# rear_window_wiper                                   bool
# rear_window_washer                                  bool
# rear_window_defogger                                bool
# alloy_wheels                                        bool
# integrated_antenna                                  bool
# outside_rear_view_mirror_turn_indicators            bool
# roof_rail                                           bool
# power_door_locks                                    bool
# driver_air_bag                                      bool
# passenger_air_bag                                   bool
# seat_belt_warning                                   bool
# keyless_entry                                       bool
# engine_check_warning                                bool
# crash_sensor                                        bool
# ebd                                                 bool
# follow_me_home_headlamps                            bool
# rear_camera                                         bool
# speed_sensing_auto_door_lock                        bool
# pretensioners_and_force_limiter_seatbelts           bool
# impact_sensing_auto_door_lock                       bool
# no_of_airbags                                       bool
# radio                                               bool
# speakers_front                                      bool
# speakers_rear                                       bool
# integrated2din_audio                                bool
# usb_auxiliary_input                                 bool
# bluetooth                                           bool
# touch_screen                                        bool
# number_of_speaker                                   bool
# glove_box_cooling                                   bool
# driving_experience_control_eco                      bool
# tinted_glass                                        bool
# rear_spoiler                                        bool
# chrome_garnish                                      bool
# vehicle_stability_control_system                    bool
# rear_reading_lamp                                   bool
# rear_seat_centre_arm_rest                           bool
# cup_holders_rear                                    bool
# rear_acvents                                        bool
# air_quality_control                                 bool
# height_adjustable_front_seat_belts                  bool
# cruise_control                                      bool
# voice_control                                       bool
# audio_system_remote_control                         bool
# leather_seats                                       bool
# fog_lights_rear                                     bool
# traction_control                                    bool
# seat_lumbar_support                                 bool
# battery_saver                                       bool
# lane_change_indicator                               bool
# sun_roof                                            bool
# automatic_driving_lights                            bool
# anti_theft_alarm                                    bool
# automatic_head_lamps                                bool
# isofix_child_seat_mounts                            bool
# hill_assist                                         bool
# tailgate_ajar                                       bool
# brake_assist                                        bool
# steering_wheel_gearshift_paddles                    bool
# ledtaillights                                       bool
# cigarette_lighter                                   bool
# rain_sensing_wiper                                  bool
# drive_modes                                         bool
# active_noise_cancellation                           bool
# adjustable_headrest                                 bool
# hands_free_tailgate                                 bool
# dual_tone_dashboard                                 bool
# leather_wrap_gear_shift_selector                    bool
# dual_tone_body_colour                               bool
# leddrls                                             bool
# ledheadlights                                       bool
# cornering_headlamps                                 bool
# cornering_foglamps                                  bool
# side_air_bag_front                                  bool
# side_air_bag_rear                                   bool
# tyre_pressure_monitor                               bool
# clutch_lock                                         bool
# anti_pinch_power_windows                            bool
# knee_airbags                                        bool
# apple_car_play                                      bool
# android_auto                                        bool
# mirror_link                                         bool
# wireless_phone_charging                             bool
# compass                                             bool
# moon_roof                                           bool
# projector_headlamps                                 bool
# speed_alert                                         bool
# eletronic_stability_control                         bool
# touch_screen_size                                   bool
# xenon_headlamps                                     bool
# cd_changer                                          bool
# power_boot                                          bool
# rear_folding_table                                  bool
# smoke_headlamps                                     bool
# dvd_player                                          bool
# internal_storage                                    bool
# rear_entertainment_system                           bool
# remote_engine_start_stop                            bool
# ventilated_seats                                    bool
# ledfog_lamps                                        bool
# view360camera                                       bool
# geo_fence_alert                                     bool
# steering_mounted_tripmeter                          bool
# remote_climate_control                              bool
# remote_horn_light_control                           bool
# heated_wing_mirror                                  bool
# side_stepper                                        bool
# blind_spot_monitor                                  bool
# hill_descent_control                                bool
# heads_up_display                                    bool
# sos_emergency_assistance                            bool
# cassette_player                                     bool
# find_my_car_location                                bool
# wifi_connectivity                                   bool
# headlamp_washers                                    bool
# real_time_vehicle_tracking                          bool
# roof_carrier                                        bool
# smart_key_band                                      bool
# lane_watch_camera                                   bool
# removable_convertible_top                           bool
# power_folding3rd_row_seat                           bool
# mileage                                           object
# engine                                            object
# max_power                                         object
# torque                                            object
# seats.1                                          float64
# color                                             object
# engine_type                                       object
# displacement                                     float64
# max_torque                                        object
# no_of_cylinder                                   float64
# values_per_cylinder                              float64
# value_configuration                               object
# fuel_suppy_system                                 object
# borex_stroke                                      object
# compression_ratio                                 object
# turbo_charger                                     object
# super_charger                                     object
# length                                            object
# width                                             object
# height                                            object
# wheel_base                                        object
# front_tread                                       object
# rear_tread                                        object
# kerb_weight                                       object
# gross_weight                                      object
# gear_box                                          object
# drive_type                                        object
# seating_capacity                                 float64
# steering_type                                     object
# turning_radius                                    object
# front_brake_type                                  object
# rear_brake_type                                   object
# top_speed                                         object
# acceleration                                      object
# tyre_type                                         object
# no_door_numbers                                  float64
# cargo_volumn                                      object
# wheel_size                                        object
# alloy_wheel_size                                  object
# ground_clearance_unladen                          object
# car_links                                         object
# city                                              object
# dtype: object

# %%
(df_edit.isnull().sum()/len(df_edit))*100
# Out:
# it                                                 0.000000
# ft                                                 0.000000
# bt                                                 0.047795
# km                                                 0.000000
# transmission                                       0.000000
# ownerno                                            0.000000
# owner                                              0.000000
# oem                                                0.000000
# model                                              0.000000
# modelyear                                          0.000000
# centralvariantid                                   0.000000
# variantname                                        0.000000
# price                                              0.000000
# priceactual                                       80.045406
# pricesaving                                      100.000000
# pricefixedtext                                   100.000000
# trendingtext.imgurl                                0.000000
# trendingtext.heading                               0.000000
# trendingtext.desc                                  0.000000
# registration_year                                  0.621341
# insurance_validity                                 0.047795
# fuel_type                                          0.000000
# seats                                              0.071693
# kms_driven                                         0.023898
# rto                                               10.682280
# ownership                                          0.382363
# engine_displacement                                0.047795
# year_of_manufacture                                0.238977
# power_steering                                     0.000000
# power_windows_front                                0.000000
# air_conditioner                                    0.000000
# heater                                             0.000000
# adjustable_head_lights                             0.000000
# manually_adjustable_exterior_rear_view_mirror      0.000000
# centeral_locking                                   0.000000
# child_safety_locks                                 0.000000
# power_windows_rear                                 0.000000
# remote_trunk_opener                                0.000000
# remote_fuel_lid_opener                             0.000000
# low_fuel_warning_light                             0.000000
# accessory_power_outlet                             0.000000
# vanity_mirror                                      0.000000
# rear_seat_headrest                                 0.000000
# cup_holders_front                                  0.000000
# digital_odometer                                   0.000000
# electronic_multi_tripmeter                         0.000000
# fabric_upholstery                                  0.000000
# glove_compartment                                  0.000000
# digital_clock                                      0.000000
# wheel_covers                                       0.000000
# power_antenna                                      0.000000
# chrome_grille                                      0.000000
# day_night_rear_view_mirror                         0.000000
# passenger_side_rear_view_mirror                    0.000000
# halogen_headlamps                                  0.000000
# rear_seat_belts                                    0.000000
# door_ajar_warning                                  0.000000
# side_impact_beams                                  0.000000
# front_impact_beams                                 0.000000
# adjustable_seats                                   0.000000
# centrally_mounted_fuel_tank                        0.000000
# engine_immobilizer                                 0.000000
# anti_theft_device                                  0.000000
# fog_lights_front                                   0.000000
# anti_lock_braking_system                           0.000000
# cd_player                                          0.000000
# trunk_light                                        0.000000
# multifunction_steering_wheel                       0.000000
# navigation_system                                  0.000000
# smart_access_card_entry                            0.000000
# engine_start_stop_button                           0.000000
# gear_shift_indicator                               0.000000
# luggage_hook_and_net                               0.000000
# adjustable_steering                                0.000000
# tachometer                                         0.000000
# leather_steering_wheel                             0.000000
# outside_temperature_display                        0.000000
# height_adjustable_driver_seat                      0.000000
# power_adjustable_exterior_rear_view_mirror         0.000000
# electric_folding_rear_view_mirror                  0.000000
# rear_window_wiper                                  0.000000
# rear_window_washer                                 0.000000
# rear_window_defogger                               0.000000
# alloy_wheels                                       0.000000
# integrated_antenna                                 0.000000
# outside_rear_view_mirror_turn_indicators           0.000000
# roof_rail                                          0.000000
# power_door_locks                                   0.000000
# driver_air_bag                                     0.000000
# passenger_air_bag                                  0.000000
# seat_belt_warning                                  0.000000
# keyless_entry                                      0.000000
# engine_check_warning                               0.000000
# crash_sensor                                       0.000000
# ebd                                                0.000000
# follow_me_home_headlamps                           0.000000
# rear_camera                                        0.000000
# speed_sensing_auto_door_lock                       0.000000
# pretensioners_and_force_limiter_seatbelts          0.000000
# impact_sensing_auto_door_lock                      0.000000
# no_of_airbags                                      0.000000
# radio                                              0.000000
# speakers_front                                     0.000000
# speakers_rear                                      0.000000
# integrated2din_audio                               0.000000
# usb_auxiliary_input                                0.000000
# bluetooth                                          0.000000
# touch_screen                                       0.000000
# number_of_speaker                                  0.000000
# glove_box_cooling                                  0.000000
# driving_experience_control_eco                     0.000000
# tinted_glass                                       0.000000
# rear_spoiler                                       0.000000
# chrome_garnish                                     0.000000
# vehicle_stability_control_system                   0.000000
# rear_reading_lamp                                  0.000000
# rear_seat_centre_arm_rest                          0.000000
# cup_holders_rear                                   0.000000
# rear_acvents                                       0.000000
# air_quality_control                                0.000000
# height_adjustable_front_seat_belts                 0.000000
# cruise_control                                     0.000000
# voice_control                                      0.000000
# audio_system_remote_control                        0.000000
# leather_seats                                      0.000000
# fog_lights_rear                                    0.000000
# traction_control                                   0.000000
# seat_lumbar_support                                0.000000
# battery_saver                                      0.000000
# lane_change_indicator                              0.000000
# sun_roof                                           0.000000
# automatic_driving_lights                           0.000000
# anti_theft_alarm                                   0.000000
# automatic_head_lamps                               0.000000
# isofix_child_seat_mounts                           0.000000
# hill_assist                                        0.000000
# tailgate_ajar                                      0.000000
# brake_assist                                       0.000000
# steering_wheel_gearshift_paddles                   0.000000
# ledtaillights                                      0.000000
# cigarette_lighter                                  0.000000
# rain_sensing_wiper                                 0.000000
# drive_modes                                        0.000000
# active_noise_cancellation                          0.000000
# adjustable_headrest                                0.000000
# hands_free_tailgate                                0.000000
# dual_tone_dashboard                                0.000000
# leather_wrap_gear_shift_selector                   0.000000
# dual_tone_body_colour                              0.000000
# leddrls                                            0.000000
# ledheadlights                                      0.000000
# cornering_headlamps                                0.000000
# cornering_foglamps                                 0.000000
# side_air_bag_front                                 0.000000
# side_air_bag_rear                                  0.000000
# tyre_pressure_monitor                              0.000000
# clutch_lock                                        0.000000
# anti_pinch_power_windows                           0.000000
# knee_airbags                                       0.000000
# apple_car_play                                     0.000000
# android_auto                                       0.000000
# mirror_link                                        0.000000
# wireless_phone_charging                            0.000000
# compass                                            0.000000
# moon_roof                                          0.000000
# projector_headlamps                                0.000000
# speed_alert                                        0.000000
# eletronic_stability_control                        0.000000
# touch_screen_size                                  0.000000
# xenon_headlamps                                    0.000000
# cd_changer                                         0.000000
# power_boot                                         0.000000
# rear_folding_table                                 0.000000
# smoke_headlamps                                    0.000000
# dvd_player                                         0.000000
# internal_storage                                   0.000000
# rear_entertainment_system                          0.000000
# remote_engine_start_stop                           0.000000
# ventilated_seats                                   0.000000
# ledfog_lamps                                       0.000000
# view360camera                                      0.000000
# geo_fence_alert                                    0.000000
# steering_mounted_tripmeter                         0.000000
# remote_climate_control                             0.000000
# remote_horn_light_control                          0.000000
# heated_wing_mirror                                 0.000000
# side_stepper                                       0.000000
# blind_spot_monitor                                 0.000000
# hill_descent_control                               0.000000
# heads_up_display                                   0.000000
# sos_emergency_assistance                           0.000000
# cassette_player                                    0.000000
# find_my_car_location                               0.000000
# wifi_connectivity                                  0.000000
# headlamp_washers                                   0.000000
# real_time_vehicle_tracking                         0.000000
# roof_carrier                                       0.000000
# smart_key_band                                     0.000000
# lane_watch_camera                                  0.000000
# removable_convertible_top                          0.000000
# power_folding3rd_row_seat                          0.000000
# mileage                                            3.429322
# engine                                             0.047795
# max_power                                          0.716932
# torque                                             0.716932
# seats.1                                            0.071693
# color                                              0.035847
# engine_type                                        3.524913
# displacement                                       0.047795
# max_torque                                         0.716932
# no_of_cylinder                                     0.370415
# values_per_cylinder                                0.609392
# value_configuration                               26.478671
# fuel_suppy_system                                 20.635679
# borex_stroke                                      71.262994
# compression_ratio                                 77.356912
# turbo_charger                                     12.426813
# super_charger                                     23.443661
# length                                             0.943960
# width                                              0.991755
# height                                             0.943960
# wheel_base                                         1.947664
# front_tread                                       42.514040
# rear_tread                                        42.657426
# kerb_weight                                        0.704983
# gross_weight                                      54.259768
# gear_box                                           1.266579
# drive_type                                        18.640220
# seating_capacity                                   0.071693
# steering_type                                      3.046959
# turning_radius                                    19.118174
# front_brake_type                                   1.147090
# rear_brake_type                                    1.147090
# top_speed                                         44.951607
# acceleration                                      41.964392
# tyre_type                                          0.920062
# no_door_numbers                                    0.131437
# cargo_volumn                                      19.034532
# wheel_size                                        35.643446
# alloy_wheel_size                                  35.643446
# ground_clearance_unladen                          93.846338
# car_links                                          0.000000
# city                                               0.000000
# dtype: float64

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100

# Filter columns with a null percentage greater than 0 (i.e., columns that have missing values)
columns_with_null_E100 = null_percentage[null_percentage == 100]
print(columns_with_null_E100)
columns_with_null_E100.shape[0]
# Out:
# pricesaving       100.0
# pricefixedtext    100.0
# dtype: float64
# 2

# %%
#drop "priceFixedText", "priceSaving", "priceActual" columns due to priceActual is 80% 
df_edit.drop(['pricefixedtext','pricesaving','priceactual'], axis=1, inplace=True)

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_GT80 = null_percentage[null_percentage > 80]
print(columns_with_null_GT80)
print(columns_with_null_GT80.shape[0])
# Out:
# ground_clearance_unladen    93.846338
# dtype: float64
# 1

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_BT50to80 = null_percentage[(null_percentage > 50) & (null_percentage <= 80)]
print(columns_with_null_BT50to80)
print(columns_with_null_BT50to80.shape[0])
# Out:
# borex_stroke         71.262994
# compression_ratio    77.356912
# gross_weight         54.259768
# dtype: float64
# 3

# %%
for col in columns_with_null_BT50to80.index:
    unique_values = df_edit[col].unique()
    print(f"Unique values in column {col}: {unique_values}")
# Out:
# Unique values in column borex_stroke: ['73 X 82 mm' '79 X 76.5 mm' '77 X 85.8 mm' nan '69.6 x 82 mm'
#  '74 x 85 mm' '73.0 X 89.4 mm' '84.0 x 90.0 mm' '69 x 72 mm' '74 X 85 mm'
#  '81.0mm X 87.2mm' '82 x 94.6 mm' '68.5 x 72.0 mm' '83 x 92 mm' '76x82.5'
#  '71.5 x 81.5 mm' '69.6 X 82mm' '82.5 x 84.2 mm' '82 x 93.2 mm'
#  '76.5 x 86.9 mm' '84 x 90 mm' '71 x 75.6 mm' '69.6 X 82 mm' '74.5 x 76.4'
#  '77 X 80.5 mm' '69.6 X 82' '76.0 X 82.5 mm' '73.5 X 88.3 mm' '74 x 85'
#  '73 x 82mm' '75.0 x 55.0 mm' '81.5 x 95.8 mm' '74.5x76.4 mm'
#  '82.5 x 92.8' '82x 78.8 mm' '73 x 72 mm' '75.5 X 83.5 mm' '73 X 71.5 mm'
#  '75 x 90 mm' '77.0 X 85.44 mm' '73 X 82mm' '79.5 x 95.5 mm'
#  '82.0 x 78.8 mm' '71 X 75.6 mm' '74.5 X 76.4mm' '76.5 X 75.6 mm'
#  '77.2mm X 84.5mm' '77.0mm X 85.44mm' '83 X 92.35 mm' '72.2 x 81.3'
#  '78.3 x 86.4 mm' '76.5 X 86.9 mm' '85 x 96 mm' '92.9 x 86.0 mm'
#  '83.0 x 92.0 mm' '77x85.8' '77.2 X 84.5 mm' '82.5 x 92.8 mm'
#  '79.5 x 80.5 mm' '3.39 in X 3.39 mm' '77.0 x 80.5 mm' '74.0 x 75.5 mm'
#  '71.5 x 83.5 mm' '84 X 90 mm' '3.62 X 4.08 mm' '88.5 X 96.0 mm'
#  '75 X 79.5 mm' '74 x 75.5 mm' '71 x 84.1' '73.0 x 89.4 mm'
#  '88.9 X 101.6 mm' '81 x 95.5 mm' '78 X 83mm' '68.5 x 67.5 mm'
#  '69.9X82 mm' '76 x 80.5 mm' '73.5 mm x 73.5 mm' '78 x 83.6'
#  '76.0 x 76.5 mm' '73.5mm X 73.5mm' '75 x 79.5 mm' '92.5X93mm'
#  '75 X 79 mm' '76 X 80.5 mm' '75.5 x 83.5 mm' '73.7 x 82.0 mm'
#  '76 X 80.5mm' '70 x 72 mm' '2.85 X 3.57 mm' '81.0 x 95.5 mm'
#  '79 X 76.4 mm' '94 X 90 mm' '73  x 79.5 mm' '82.5 x 84.1 mm'
#  '73.0 X 79.5' '74.0 X 85.0' '78 X 83.6 mm' '11:01' '78 x 83 mm'
#  '73.0 X 79.5 mm' '84.5 x 89.0' '74.0x85.0' '77 x 80.5 mm' '81 x 87.3 mm'
#  '75 X 79mm' '94.6X82.0' '74.5 x 76.4 mm' '78 x 83.6 mm' '2.99 X 3.46 mm'
#  '81 x 77 mm' '77.0 X 85.1 mm' '94 x 94 mm' '69.9 x 82 mm'
#  '77.9 x 73.4 mm' '83x92.4mm' '76.5 x 87 mm' '95.4X104.9' '16,5 :1'
#  '81.6 x 86 mm' '88 x 97 mm' '81X77mm' '84 x 88 mm' '90 X 98 mm'
#  '78.0 X 78.4mm' '74.5 x 81 mm' '73 x 79.5 mm' '74.0 x 85.0 mm'
#  '81 x 93.15 mm' '73x71.5' '83.0 x 92.0mm' '84.5X 86.0mm' '68.5 x 72 mm'
#  '98.0 x 90.5 mm' '90.0 X 84.4 mm' '74.5 x 80 mm' '92 X 90 mm'
#  '81 X 87.3 mm' '79 x 81.5 mm' '66 x 77 mm' '94.6mmX82.0mm' '81 X 95.5 mm'
#  '89.6 x 84 mm' '74.0 x 85.0' '81 X 93.15 mm' '84 X 90' '81.0 X 87.2mm'
#  '81X93.1' '81 x 88 mm' '81X93.15 mm' '81 x 95.5' '77.0mm X85.44mm'
#  '75 x 87 mm' '71.0 X 75.6' '77.0*80.4 mm' '81.0 x 86.4 mm' '77.0 X 80.5'
#  '92 x 92 mm' '79 X 91.5 mm' '78 X 83 mm' '95.0 x 100.0 mm'
#  '3.35 X 3.81 mm' '81 X 93.2 mm' '68.5 x 78 mm' '97 X 100 mm'
#  '83.5 x 73.5 mm' '74 x 71.5 mm' '89.0 X 88.3 mm' '69.9X82' '83x92.3mm'
#  '87.5 X 83.1 mm' '96 (mm) / 83 (mm)' '83 X 92 mm']
# Unique values in column compression_ratio: ['11.0:1' '10.8:1' nan '10.3:1' '16.0:1' '10.5:1' '11.0' '17.7:1' '10:01'
#  '10.1' '9.6:1' ':1' '10.5:1 ' '16.5:1' '17.6:1' '16.2+/-2:1' '10.1:1'
#  '10.2:1' '9.5 : 1' '12.0:1' '9.0:1' '10.0:1' '9:01' '19.0:1' '17.3:1'
#  '16:01' '10.5;1' '18.5:1' '17.2:1' '15.5:1' '9.8:1' '9.4:1' '12.0+-.03'
#  '9.3:1' '9.5:1' '73.5 mm x 73.5 mm' '9.75:1' '12+-0.3' '21:01' '19.5 : 1'
#  '16:1' '17.9:1' '18.0:1' '16.2:2' '16.1:1' '11.2:1' '15.8:1' '9.8'
#  '9.9:1' '10:1' '81 x 87.3 mm' '16.2:1' '8.8:1' '15.0:1' '22:01' '19.5:1 '
#  '17.5:1' '11.3:1' '13.0 : 1' '10' '11:1' '16.8 : 1' '8.6 : 1' '10.7:1'
#  '9.3+/-0.2:1' '11.04:1' '8.9:1' '12.0 ±0.3' '18:1' '10.7:1 ' '17.9'
#  '16.5 :1' '17.8:1' '9.5:1 ' '22.2:1' '9.01' '15.5' '8.5:1' '12.5:1'
#  '16.8:1']
# Unique values in column gross_weight: ['1250kg' '1660Kg' nan '1670kg' '1530Kg' '1340kg' '2450kg' '2160kg' '1335'
#  '2730kg' '2055kg' '1350kg' '1730 Kg' '2165 Kg' '2510 kg' '1640kg'
#  '2240kg' '1185kg' '2510kg' '1655kg' '1140kg' '2995kg' '1500kg' '1260'
#  '1760kg' '1405Kg' '1585kg' '1860kg' '1430kg' '1750Kg' '2060kg' '1360kg'
#  '1720kg' '1580kg' '1965kg' '2124kg' '1740kg' '2430kg' '1985kg' '2610Kg'
#  '2505 kg' '1787kg' '1405kg' '1813kg' '1455kg' '1580 kg' '1620kg' '1915kg'
#  '2220kg' '1680kg' '1758kg' '1705Kg' '1845kg' '1482kg' '1436kg' '2140kg'
#  '1690Kg' '2280kg' '1520' '1505kg' '2300kg' '1490kg' '2320kg' '1530'
#  '1520 Kg' '1890kg' '1660 kg' '1650' '1315Kg' '1980kg' '1315kg' '1525kg'
#  '1210kg' '2135kg' '1415kg' '1510kg' '1950kg' '1315kgs' '2830' '1757kg'
#  '2,010 kg' '1764kg' '2030kg' '2225kg' '1615kg' '1770kg' '1500Kg'
#  '2300 kg' '1410' '1459kg' '1777kg' '1436' '1520kg' '1463kg' '1630kg'
#  '1170' '1940kg' '2185kg' '2165kg' '2075Kg' '1482-1528kg' '2460kg'
#  '1920kg' '2225Kg' '2189kg' '2555kg' '1250kgs' '2950kg' '2500kg' '1600'
#  '2005kg' '1260kg' '1235kg' '1970kg' '2230kg' '2340kg' '2350kg' '2480kg'
#  '1710kg' '1190 kg' '2460' '2525kg' '2510' '1595kg' '2075kg' '1820'
#  '2150kg' '1781kg' '1795kg' '1310kg' '1382kg' '1700' '1570Kg'
#  '1575-1595kg' '2091kg' '1680Kg' '2735' '1760' '2,285 kg' '1930kg'
#  '2410kg' '1405Kgs' '2335kg' '2,625 kg' '2090kg' '1640 kg' '2250kg'
#  '2880kg' '1185' '1448kg' '2115kg' '1895Kg' '2650kg' '1806kg' '1644kg'
#  '1660kg' '1710Kg' '2780kg' '2690kg' '1640' '2505kg' '1889kg' '2050 kg'
#  '2330kg' '1800Kg' '1540kg' '1320kg' '2610kg' '2145kg' '2025kg' '2470kg'
#  '2925 kg' '1670' '2795kg' '1700 kg' '1795' '2735Kg' '2910kg' '3250kg'
#  '2490' '1735kg' '2400 Kg' '1000kg' '1550kg' '1730kg' '1685kg' '1940 kg'
#  '1850kg' '1438' '1340' '2449Kg' '1600kg' '1433kg' '2091 kg.' '3265kg'
#  '1740 Kg' '2100kg' '2315kg' '2450' '1190kg' '2,335 kg' '1435kg' '2493kg'
#  '2020kg' '2490 Kg' '1340Kg' '1275kg' '1855kg' '2060 kg' '1635kg' '2190kg'
#  '2,090 kg' '2070kg' '1475kg' '2755' '2200kg' '1766kg' '2150 Kg' '2005Kg'
#  '2045kg' '2200Kg' '1590 kg' '1665kg' '2360kg' '2430' '2020 kg' '3200kg'
#  '2530kg' '1250' '2580kg' '2840kg' '1955kg' '3230kg' '2445 Kg' '1545 Kg'
#  '1390kg' '2940kg' '2345Kg' '2490Kg' '2715Kg' '2270kg' '2870kg' '3200'
#  '1480' '1645kg' '2815 kg' '2105 Kg' '3150 Kg' '1320' '2490kg' '1765kg'
#  '2125Kg' '1640kg-1670kg' '2735kg' '2400 kg' '2098kg' '1890 Kg' '1825kg'
#  '2065kg' '1482-1528' '1700kg' '1750kg' '1650kg' '1990kg' '1715' '2515kg'
#  '2130 kg' '2000kg' '1765' '1480kg' '2235kg' '1645' '2010kg' '2680' '1405'
#  '2370kg' '1570' '1660 kg.' '1415mm' '2185 Kg' '1971kg' '2210kg'
#  '1650-1660kg' '2365kg' '2830kg' '1779kg' '3175kg' '1740kgs' '3000kg'
#  '1523kg' '2015 kg' '1655' '1755kg' '1995 kg' '2720kg' '1800 Kg' '1533'
#  '1704kg' '1566-1592kg' '2215kg' '3350Kg' '1535kg' '3490Kg' '2225 kg'
#  '1,600 kg' '1870kg' '2215' '1522kg' '2800kg' '1971 kg' '1373' '2400kg'
#  '1,970 kg' '1450kg' '1980 kg' '2295kg' '1461' '2180kg' '1545Kg' '1554kg'
#  '2470 Kg' '2265kg' '2375kg' '2120kg' '2500' '2035kg' '1,505 kg' '2390kg'
#  '1755' '1604kg' '1910kg']

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_BT30to50 = null_percentage[(null_percentage > 30) & (null_percentage <= 50)]
print(columns_with_null_BT30to50)
print(columns_with_null_BT30to50.shape[0])
# Out:
# front_tread         42.514040
# rear_tread          42.657426
# top_speed           44.951607
# acceleration        41.964392
# wheel_size          35.643446
# alloy_wheel_size    35.643446
# dtype: float64
# 6

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_BT10to30 = null_percentage[(null_percentage > 10) & (null_percentage <= 30)]
print(columns_with_null_BT10to30)
print(columns_with_null_BT10to30.shape[0])
# Out:
# rto                    10.682280
# value_configuration    26.478671
# fuel_suppy_system      20.635679
# turbo_charger          12.426813
# super_charger          23.443661
# drive_type             18.640220
# turning_radius         19.118174
# cargo_volumn           19.034532
# dtype: float64
# 8

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_B10 = null_percentage[(null_percentage > 0) & (null_percentage <= 10)]
print(columns_with_null_B10)
print(columns_with_null_B10.shape[0])
# Out:
# bt                     0.047795
# registration_year      0.621341
# insurance_validity     0.047795
# seats                  0.071693
# kms_driven             0.023898
# ownership              0.382363
# engine_displacement    0.047795
# year_of_manufacture    0.238977
# mileage                3.429322
# engine                 0.047795
# max_power              0.716932
# torque                 0.716932
# seats.1                0.071693
# color                  0.035847
# engine_type            3.524913
# displacement           0.047795
# max_torque             0.716932
# no_of_cylinder         0.370415
# values_per_cylinder    0.609392
# length                 0.943960
# width                  0.991755
# height                 0.943960
# wheel_base             1.947664
# kerb_weight            0.704983
# gear_box               1.266579
# seating_capacity       0.071693
# steering_type          3.046959
# front_brake_type       1.147090
# rear_brake_type        1.147090
# tyre_type              0.920062
# no_door_numbers        0.131437
# dtype: float64
# 31

# %%
df_edit['bt'].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'MUV', 'Coupe', 'Minivans',
#        'Pickup Trucks', 'Convertibles', 'Hybrids', nan, 'Wagon'],
#       dtype=object)

# %%
df_edit['variantname'].unique()
# Out:
# array(['VXI', '1.5 Petrol Titanium BSIV', '1.2 Revotron XZ', ...,
#        'XZA Plus P Dark Edition AMT', 'X-Line DCT', 'C 200 CGI Elegance'],
#       dtype=object)

# %%
df_edit['centralvariantid'].unique()
# Out:
# array([3979, 6087, 2983, ..., 8568, 9709, 4672], dtype=int64)

# %%
columns_with_null = null_percentage[null_percentage > 0]
columns_with_null.shape[0]
# Out:
# 49

# %%
columns_with_null
# Out:
# bt                           0.047795
# registration_year            0.621341
# insurance_validity           0.047795
# seats                        0.071693
# kms_driven                   0.023898
# rto                         10.682280
# ownership                    0.382363
# engine_displacement          0.047795
# year_of_manufacture          0.238977
# mileage                      3.429322
# engine                       0.047795
# max_power                    0.716932
# torque                       0.716932
# seats.1                      0.071693
# color                        0.035847
# engine_type                  3.524913
# displacement                 0.047795
# max_torque                   0.716932
# no_of_cylinder               0.370415
# values_per_cylinder          0.609392
# value_configuration         26.478671
# fuel_suppy_system           20.635679
# borex_stroke                71.262994
# compression_ratio           77.356912
# turbo_charger               12.426813
# super_charger               23.443661
# length                       0.943960
# width                        0.991755
# height                       0.943960
# wheel_base                   1.947664
# front_tread                 42.514040
# rear_tread                  42.657426
# kerb_weight                  0.704983
# gross_weight                54.259768
# gear_box                     1.266579
# drive_type                  18.640220
# seating_capacity             0.071693
# steering_type                3.046959
# turning_radius              19.118174
# front_brake_type             1.147090
# rear_brake_type              1.147090
# top_speed                   44.951607
# acceleration                41.964392
# tyre_type                    0.920062
# no_door_numbers              0.131437
# cargo_volumn                19.034532
# wheel_size                  35.643446
# alloy_wheel_size            35.643446
# ground_clearance_unladen    93.846338
# dtype: float64

# %%
df_edit['ground_clearance_unladen'].replace(" ","",inplace = True)
df_edit['ground_clearance_unladen'].replace("mm","",inplace = True)
# Removing spaces
df_edit['ground_clearance_unladen'] = df_edit['ground_clearance_unladen'].str.replace(" ", "", regex=False)

# Removing 'mm'
df_edit['ground_clearance_unladen'] = df_edit['ground_clearance_unladen'].str.replace("mm", "", regex=False)

# Display unique values after replacement
unique_values = df_edit['ground_clearance_unladen'].unique()
print(unique_values)
# Out:
# [nan '190' '205' '209' '155' '120' '192' '210' '160' '110' '185' '178'
#  '116' '145' '200' '170' '184' '180' '140' '91' '175' '165' '156']

# %%
df_edit['ground_clearance_unladen'] = pd.to_numeric(df_edit['ground_clearance_unladen'], errors='coerce')

# %%
df_edit['ground_clearance_unladen'].dtypes
# Out:
# dtype('float64')

# %%
len(df_edit['ground_clearance_unladen'].unique())
# Out:
# 23

# %%
df_edit['ground_clearance_unladen'].isnull().sum()
# Out:
# 7854

# %%
# Dictionary with average ground clearance values for each body type
ground_clearance_values = {
    "Hatchback": 165,
    "SUV": 210,
    "Sedan": 150,
    "MUV": 190,
    "Coupe": 130,
    "Minivans": 160,
    "Pickup Trucks": 220,
    "Convertibles": 130,
    "Hybrids": 150,
    "Wagon": 160
}

def replace_nan(row, values_dict):
    # Check if 'Ground Clearance Unladen' is NaN and 'bt' is not NaN
    if pd.isnull(row['ground_clearance_unladen']) and pd.notnull(row['bt']):
        # Return the value from the dictionary based on 'bt', or NaN if 'bt' is not in the dictionary
        return values_dict.get(row['bt'], row['ground_clearance_unladen'])
    # Return the existing value if 'Ground Clearance Unladen' is not NaN
    return row['ground_clearance_unladen']


# Apply the function to the DataFrame
df_edit['ground_clearance_unladen'] = df_edit.apply(
    lambda row: replace_nan(row, ground_clearance_values),
    axis=1
)

# %%
df_edit['ground_clearance_unladen'].isnull().sum()
# Out:
# 4

# %%
len(df_edit['ground_clearance_unladen'].unique())
# Out:
# 26

# %%
len(df_edit['gross_weight'].unique())
# Out:
# 331

# %%
df_edit['gross_weight'].unique()
# Out:
# array(['1250kg', '1660Kg', nan, '1670kg', '1530Kg', '1340kg', '2450kg',
#        '2160kg', '1335', '2730kg', '2055kg', '1350kg', '1730 Kg',
#        '2165 Kg', '2510 kg', '1640kg', '2240kg', '1185kg', '2510kg',
#        '1655kg', '1140kg', '2995kg', '1500kg', '1260', '1760kg', '1405Kg',
#        '1585kg', '1860kg', '1430kg', '1750Kg', '2060kg', '1360kg',
#        '1720kg', '1580kg', '1965kg', '2124kg', '1740kg', '2430kg',
#        '1985kg', '2610Kg', '2505 kg', '1787kg', '1405kg', '1813kg',
#        '1455kg', '1580 kg', '1620kg', '1915kg', '2220kg', '1680kg',
#        '1758kg', '1705Kg', '1845kg', '1482kg', '1436kg', '2140kg',
#        '1690Kg', '2280kg', '1520', '1505kg', '2300kg', '1490kg', '2320kg',
#        '1530', '1520 Kg', '1890kg', '1660 kg', '1650', '1315Kg', '1980kg',
#        '1315kg', '1525kg', '1210kg', '2135kg', '1415kg', '1510kg',
#        '1950kg', '1315kgs', '2830', '1757kg', '2,010 kg', '1764kg',
#        '2030kg', '2225kg', '1615kg', '1770kg', '1500Kg', '2300 kg',
#        '1410', '1459kg', '1777kg', '1436', '1520kg', '1463kg', '1630kg',
#        '1170', '1940kg', '2185kg', '2165kg', '2075Kg', '1482-1528kg',
#        '2460kg', '1920kg', '2225Kg', '2189kg', '2555kg', '1250kgs',
#        '2950kg', '2500kg', '1600', '2005kg', '1260kg', '1235kg', '1970kg',
#        '2230kg', '2340kg', '2350kg', '2480kg', '1710kg', '1190 kg',
#        '2460', '2525kg', '2510', '1595kg', '2075kg', '1820', '2150kg',
#        '1781kg', '1795kg', '1310kg', '1382kg', '1700', '1570Kg',
#        '1575-1595kg', '2091kg', '1680Kg', '2735', '1760', '2,285 kg',
#        '1930kg', '2410kg', '1405Kgs', '2335kg', '2,625 kg', '2090kg',
#        '1640 kg', '2250kg', '2880kg', '1185', '1448kg', '2115kg',
#        '1895Kg', '2650kg', '1806kg', '1644kg', '1660kg', '1710Kg',
#        '2780kg', '2690kg', '1640', '2505kg', '1889kg', '2050 kg',
#        '2330kg', '1800Kg', '1540kg', '1320kg', '2610kg', '2145kg',
#        '2025kg', '2470kg', '2925 kg', '1670', '2795kg', '1700 kg', '1795',
#        '2735Kg', '2910kg', '3250kg', '2490', '1735kg', '2400 Kg',
#        '1000kg', '1550kg', '1730kg', '1685kg', '1940 kg', '1850kg',
#        '1438', '1340', '2449Kg', '1600kg', '1433kg', '2091 kg.', '3265kg',
#        '1740 Kg', '2100kg', '2315kg', '2450', '1190kg', '2,335 kg',
#        '1435kg', '2493kg', '2020kg', '2490 Kg', '1340Kg', '1275kg',
#        '1855kg', '2060 kg', '1635kg', '2190kg', '2,090 kg', '2070kg',
#        '1475kg', '2755', '2200kg', '1766kg', '2150 Kg', '2005Kg',
#        '2045kg', '2200Kg', '1590 kg', '1665kg', '2360kg', '2430',
#        '2020 kg', '3200kg', '2530kg', '1250', '2580kg', '2840kg',
#        '1955kg', '3230kg', '2445 Kg', '1545 Kg', '1390kg', '2940kg',
#        '2345Kg', '2490Kg', '2715Kg', '2270kg', '2870kg', '3200', '1480',
#        '1645kg', '2815 kg', '2105 Kg', '3150 Kg', '1320', '2490kg',
#        '1765kg', '2125Kg', '1640kg-1670kg', '2735kg', '2400 kg', '2098kg',
#        '1890 Kg', '1825kg', '2065kg', '1482-1528', '1700kg', '1750kg',
#        '1650kg', '1990kg', '1715', '2515kg', '2130 kg', '2000kg', '1765',
#        '1480kg', '2235kg', '1645', '2010kg', '2680', '1405', '2370kg',
#        '1570', '1660 kg.', '1415mm', '2185 Kg', '1971kg', '2210kg',
#        '1650-1660kg', '2365kg', '2830kg', '1779kg', '3175kg', '1740kgs',
#        '3000kg', '1523kg', '2015 kg', '1655', '1755kg', '1995 kg',
#        '2720kg', '1800 Kg', '1533', '1704kg', '1566-1592kg', '2215kg',
#        '3350Kg', '1535kg', '3490Kg', '2225 kg', '1,600 kg', '1870kg',
#        '2215', '1522kg', '2800kg', '1971 kg', '1373', '2400kg',
#        '1,970 kg', '1450kg', '1980 kg', '2295kg', '1461', '2180kg',
#        '1545Kg', '1554kg', '2470 Kg', '2265kg', '2375kg', '2120kg',
#        '2500', '2035kg', '1,505 kg', '2390kg', '1755', '1604kg', '1910kg'],
#       dtype=object)

# %%
df_edit['gross_weight'] = df_edit['gross_weight'].str.replace("Kg", "", regex=False)
df_edit['gross_weight'] = df_edit['gross_weight'].str.replace(" ", "", regex=False)
df_edit['gross_weight'] = df_edit['gross_weight'].str.replace(",", "", regex=False)
df_edit['gross_weight'] = df_edit['gross_weight'].str.replace("s", "", regex=False)
df_edit['gross_weight'] = df_edit['gross_weight'].str.replace("mm", "", regex=False)

# %%
def replace_range_with_average(value):
    if pd.isna(value):
        return np.nan
    try:
        if '-' in value:
            start, end = map(int, value.split('-'))
            return (start + end) / 2
        else:
            return float(value)  # Convert valid numeric strings to float
    except ValueError:
        return np.nan  # Handle invalid formats gracefully

# Apply the function to the 'Gross Weight' column
df_edit['gross_weight'] = df_edit['gross_weight'].apply(replace_range_with_average)

print(df_edit['gross_weight'].unique())
# Out:
# [  nan 1660. 1530. 1335. 1730. 2165. 1260. 1405. 1750. 2610. 1705. 1690.
#  1520. 1650. 1315. 2830. 1500. 1410. 1436. 1170. 2075. 2225. 1600. 2460.
#  2510. 1820. 1700. 1570. 1680. 2735. 1760. 1185. 1895. 1710. 1640. 1800.
#  1670. 1795. 2490. 2400. 1438. 1340. 2449. 1740. 2450. 2755. 2150. 2005.
#  2200. 2430. 1250. 2445. 1545. 2345. 2715. 3200. 1480. 2105. 3150. 1320.
#  2125. 1890. 1505. 1715. 1765. 1645. 2680. 1415. 2185. 1655. 1533. 3350.
#  3490. 2215. 1373. 1461. 2470. 2500. 1755.]

# %%
df_edit['gross_weight'] = pd.to_numeric(df_edit['gross_weight'], errors='coerce')

# %%
df_edit['gross_weight'].dtypes
# Out:
# dtype('float64')

# %%
df_edit['kerb_weight'].unique()
# Out:
# array(['835kg', '1242Kg', '1012kg', '1180', '1230Kg', '1551 kgs', '1070',
#        '1440', '1105', '870kg', '1200', '1066 Kg', '1900', '1562 kgs',
#        '1675', '1120', '1315', '1049kg', '1600kg', '875-905', '2200kg',
#        '1050', '845', '1585', '1595kg', '1940', '1650', '1140', '885kg',
#        '1170 Kg', '1655kg', '1955 kg', '1375', '1066kg', '1515kg',
#        '880kg', '1329kg', '1735kg', '762kg', '1990', '1250kg', '1535',
#        '1980', '705kg', '2535kg', '1825kg', '1060', '2345kg', '1970',
#        '750', '1305Kg', '1095kg', '815', '1206kg', '1225Kg', '1320',
#        '1700', '960Kg', '850kg', '1720', '1105kg', '1360kg', '1376kg',
#        '980kg', '1015kg', '1260', '1380', '1192kg', '1025kg', '1040',
#        '1135', '1865', '890kg', '860kg', '730', '1652kg', '1835', '1345',
#        '1820', '925kg', '910-935', '760kg', '1086', '910', '1179Kg',
#        '1525', '1730', '900', '1300', '1465', '2020', '1350kg', '840kg',
#        '1445kg', '1580', '1608kg', '960', '1100', '1830kg', '755', '1020',
#        '1879kg', '1040-1130kg', '855', '1670', '935kg', '2010', '947',
#        '930', '2060', '1455kg', '1537', '2360', '1745', '1238', '1954 kg',
#        '1390', '1285', '1080kg', '1109 kg', '1274kg', '1158kg', '1395',
#        '1585kg', '1885kg', '950kg', '1325', '1190kg', '1340', '1530',
#        '1240', '1296Kg', '1042 Kg', '1960', '1044kg', '1255', '985Kg',
#        '880-915', '1235kg', '1042kg', '1107kg', '1250', '1115Kg', '890Kg',
#        '1220kg', '1061kg', '1840', '1,240 kg', '1320Kg', '1080', '985kg',
#        '825', '1150kg', '1640kg', '1210kg', '1103kg', '2060kg', '1304Kg',
#        '1800kg', '1060kg', '1680kg', '1220Kg', '1030kg', '1175kg',
#        '1780kg', '1072Kg', '1065', '1490Kg', '1245-1280 kg', '1770',
#        '1205', '895kg', '1460kg', '855-885', '1450', '1039kg', '745',
#        '784kg', '1641 kgs', '1220', '860', '970kg', '1275', '1160',
#        '1085kg', '1125kg', '940kg', '1065kg', '1425kg', '860Kgs',
#        '1537 kgs', '1290', '2195', '1205kg', '865Kg', '1635',
#        '1,350-1,540 kg', '1330', '1540kg', '1240kg', '1115kg', '1890',
#        '1720kg', '1045', '1660kg', '1785', '1138Kg', '1165kg', '1228kg',
#        '2152', '1044Kg', '1280', '1030Kg', '1880kg', '1675kg', '1300Kg',
#        '1055', '1195', '1106', '1288', '1640', '1670 kg', '920-955',
#        '1084kg', '810', '1155', '1210', '1061', '1470', '1088kg',
#        '1140kg', '736-775', '1725', '820', '1403kg', '1915', '1010kg',
#        '860Kg', '1064 Kg', '1228', '770', '779kg', '1016-1044kg',
#        '830-845kg', '699', '1620', '990', '2014kg', '835', '865-890',
#        '910kg', '1715', '915kg', '1710', '1275Kg', '1035-1062 Kg',
#        '1,520', '1495', '1277kg', '1640Kg', '1040kg', '1107-1153kg',
#        '1775kg', '1208', '880Kg', '1395kg', '1630Kg', '1014', '1235', nan,
#        '1604-1706 kg', '1,310', '990kg', '1145Kg', '860-895Kg', '1053kg',
#        '2095', '1281Kg', '835kgs', '2160kg', '2175kg', '1225', '1550',
#        '1115-1130', '1185kg', '1555', '1825', '1570kg', '1252Kg', '930kg',
#        '1430', '1201', '1270', '1130', '1090kg', '785kg', '982', '1439kg',
#        '1703kg', '1036', '1400', '1150', '1238kg', '1790kg', '855kg',
#        '1184 Kg', '1020kg', '1400kg', '845kg', '1590', '1700kg',
#        '955-990Kg', '1290kg', '1835kg', '1520kg', '1450-1525kg', '1310kg',
#        '995kg', '920-940kg', '1035kg', '940', '1510', '765 kg', '2045',
#        '1121kg', '939', '1085', '1845', '2000kg', '1145 Kg', '1795',
#        '1,550', '1155kg', '1625', '1525kg', '720kg', '1135kg', '1543kg',
#        '774kg', '1250-1255', '1275kg', '1650kg', '1145kg', '1010',
#        '1265kg', '1100kg', '2370', '1760kg', '1860', '1059kg', '982kg',
#        '600kg', '945kg', '1139-1169', '1086Kg', '995-1015kg', '1351',
#        '1070kg', '1100-1125kg', '1567kg', '1025', '1095', '1,130 kg',
#        '2000', '1740', '1598kg', '1755', '1735', '1485', '1365-1372kg',
#        '880', '1150-1205', '727kg', '1445', '1630', '870', '1,750 kg',
#        '1345kg', '710kg', '947kg', '1160-1215kg', '1046', '960Kgs',
#        '1038-1047kg', '800kg', '1335', '1280Kg', '1,300', '1182kg',
#        '1100 kg', '1055kg', '890', '1650 kgs', '1066', '1773kg', '1180kg',
#        '1,940 kg', '1085-1095kgs', '710', '865kg', '690', '1097kg',
#        '1815', '1260kg', '1575kg', '1195-1255 kg', '1565kg', '1660',
#        '1030', '2240Kg', '1135-1150', '1225kg', '1092kg', '825kg',
#        '1048kg', '990 kg', '920kg', '1155 kg', '900kg', '1610kg',
#        '1340kg', '765', '1790', '2040kg', '1545kg', '1475', '1258',
#        '1890kg', '1615kg', '1230', '1152kg', '1210-1240kg', '1179kg',
#        '805-825kg', '2200', '1685', '1036Kg', '1430kg', '1865kg', '1570',
#        '2145kg', '1053-1080kg', '2500', '2230', '1309Kg', '1135-1170',
#        '2132kg', '1760', '726-767', '1130-1170', '1355', '625', '1310',
#        '830kg', '757kg', '2115kg', '1350', '1110Kg', '1173kg', '1246kg',
#        '1535 kg', '1200kg', '1690', '1795kg', '1415Kg', '1575', '965Kg',
#        '1163kg', '1970kg', '943kg', '860-895kg', '1170', '1560', '1565',
#        '2220', '810kg', '960kg', '1146kg', '875kg', '1245', '1270kg',
#        '1955kg', '1198kg', '2330 kg', '2240', '1780', '1855', '905kg',
#        '1,240kg', '1405', '1069kg', '970', '1545', '1761', '1233kg',
#        '2280kg', '1995kg', '1468', '1298 kg', '1029kg', '1595', '1805',
#        '1041kg', '2280', '840-865', '1860kg', '765kg', '2150 Kg',
#        '1112-1138', '2505kg', '1130kg', '917kg', '1920', '1218', '1120kg',
#        '1940kg', '1644kg', '924kg', '2150kg', '1945 Kg', '1142Kg', '2030',
#        '650kg', '1816kg', '1187kg', '1110', '1796kg', '1258kg', '1800',
#        '1680', '921kg', '1039Kg', '1420 kg', '1265', '2962 kg', '1354kg',
#        '1063', '1045kg', '1110kg', '907-934', '965kg', '1142kg',
#        '835-850', '1050kg', '1500', '1880', '1799Kg', '1062Kg', '935',
#        '2350', '1500kg', '1855kg', '1645', '1312', '1515', '1026-1044',
#        '1058kg', '1137kg', '1015', '1520', '2515kg', '810-835', '1175',
#        '1635kg', '1820kg', '1705kg', '1870', '842kg', '882kg',
#        '1054-1093 kg', '1215Kg', '1,585 kg', '1040 ', '1215', '1039',
#        'Kerb Weight', '1779kg', '1163Kg', '1540', '635kg', '885', '1192',
#        '1505kg', '1857 Kg', '1016-1033kg', '1190', '1052kg', '995 kg',
#        '1105-1110kg', '1190-1210', '1895kg', '995', '1490', '1655',
#        '1023-1048kg', '1302Kg', '1154kg', '2550', '1404', '1278kg',
#        '1075kg', '1160kg', '1081-1094', '942kg', '1140 kg', '2750kgs',
#        '1246Kg', '1065-1070kg', '921', '1198', '1268Kg', '1115',
#        '1540 kg', '1765', '2001kg', '1612kg', '1,575 kg', '1148',
#        '1340 kg', '2210', '1668', '1625kg', '1435', '1022kg', '1695',
#        '1360', '675', '1050Kg', '1212Kg', '2376', '1665kg', '1740 Kg',
#        '1234', '1195kg', '1565Kg', '1610', '1245kg', '913kg', '1505',
#        '846kg', '1700Kg', '1385', '805', '1090', '1015Kg', '1365',
#        '1730kg', '875', '1775', '1370', '805kg', '1268kg', '965', '2027',
#        '1062kg', '1585 kg', '855Kg', '955kg', '1850', '1830', '2186',
#        '1950', '2195-2260kg', '1510kg', '2270', '720 kg', '905-910kg',
#        '2460kg', '1248', '2040', '1305', '1905', '1875', '1960kg',
#        '2184kg', '1087', '1740Kg', '1016-1043kg', '2600', '1866Kg',
#        '2100kg', '1016-1026kg', '1850kg', '1787kg', '1277Kg', '2110kg',
#        '1705', '2560', '2245', '1168kg', '2245Kg', '831-854', '1667 Kg',
#        '2455kg', '1930kg', '825 kg', '2489 Kg', '905', '1920kg', '1370kg',
#        '1925', '960-985kg', '1555kg', '1945', '1055 kg', '2064', '847kg',
#        '1277', '2080', '1994', '1180kg-1270kg', '1309', '2900', '2150',
#        '2700', '1840kg', '1750', '1729kg', '1628', '1497', '1480',
#        '1871 kg', '1579kg', '1615 Kg', '725kg', '1031Kg', '895', '1905kg',
#        '1810kg', '1614kg', '1615', '1110-1130', '945-957', '1590kg',
#        '1255kg', '1107-1153', '1135Kg', '1027kg', '955', '1000kg',
#        '1239Kg', '1111kg', '1280kg', '1216Kg', '1044 Kg', '1425', '2160',
#        '854kg', '1810', '1935kg', '1211', '1954kg', '1300kg', '1615 kg',
#        '1925kg', '1005kg', '690kg', '1055-1060kg', '2235', '1845kg',
#        '1153kg', '1765kg', '1150 - 1185kg', '1455', '665kg', '2310kg',
#        '990-995', '1745kg', '1232', '1027Kg', '925', '886kg', '1,575',
#        '1210 kg.', '1150 - 1185', '1910', '955Kg', '1,150 kg', '945Kg',
#        '722kg', '1690 Kg', '1389kg', '990 - 1006', '1161Kg', '1231Kg',
#        '1550kg', '1200-1210kg', '1813kg', '2185kg', '1112-1138kg', '1013',
#        '870Kg', '1766kg', '1125', '2675kg', '1533kg', '1290kgs',
#        '1062-1080', '1670kg', '2330kg', '1,570', '1021kg', '1148kg',
#        '1651kg', '950', '1355 kg', '1211kg', '980', '1335 kg', '1269',
#        '1561kg', '1220 Kg', '2410kg', '975Kg', '1605kg', '1132-1160 kg',
#        '1547', '928kg', '1138kg', '1191-1217kg', '1102', '1093', '2425kg',
#        '1660 kg', '1295', '1012-1033kg', '1850Kg', '1105-1135kg',
#        '1790Kg', '1740kg', '1131Kg', '1124kg', '1470 kg', '1,160 kg',
#        '1420kg', '1,965', '1012', '1170kg', '1147kg', '2155kg',
#        '1016-1033Kg', '1306kg', '1776kg', '1330kg', '1389 kg', '975kg',
#        '1871kg', '1475kg', '1851kg', '1110-1130kg', '1,310-1,500 kg',
#        '1420', '1410', '1460', '993kg', '1289kg', '1,380 kg', '1459 kg',
#        '1160Kg', '980 kg', '1681kg', '1230kg', '1,840', '1240Kg',
#        '1230 Kg', '1055Kg', '1104kg', '1675 kg', '1874 Kg', '2250',
#        '1770 Kg', '1824kg', '1217kg', '1770kg', '1261Kg', '2080kg',
#        '1208kg', '1155 Kg', '1645kg', '905-910', '725', '895Kg', '1895',
#        '1527kg', '1885', '945', '1,095 kg', '910-920', '1900kg', '1815kg',
#        '695kg', '1915kg', '1290 - 1295', '1188', '1023kg', '1033kg',
#        '2440', '1295kg', '1390kg', '1490kg', '1935', '1005-1010kg'],
#       dtype=object)

# %%
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace("kg", "", regex=False)
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace(" ", "", regex=False)
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace(",", "", regex=False)
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace("s", "", regex=False)
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace("mm", "", regex=False)

# %%
# Apply the function to the 'Gross Weight' column
df_edit['kerb_weight'] = df_edit['kerb_weight'].apply(replace_range_with_average)

# %%
mean_ratio = (df_edit[df_edit['gross_weight'].notnull()]['gross_weight'] / 
              df_edit[df_edit['gross_weight'].notnull()]['kerb_weight']).mean()

# %%
def replace_nan(row, mean_ratio):
    if pd.isnull(row['gross_weight']) and pd.notnull(row['kerb_weight']):
        return row['kerb_weight'] * (mean_ratio)
    return row['gross_weight']

# Apply the function to each row in the DataFrame
df_edit['gross_weight'] = df_edit.apply(
    lambda row: replace_nan(row, mean_ratio),
    axis=1
)

# %%
df_edit['gross_weight'].isnull().sum()/len(df_edit)
# Out:
# 0.03955072290596248

# %%
# Drop the 'BoreX Stroke', 'Compression Ratio' columns, as these are measurable attributes that cannot be assumed without compromising the quality and features of the product
df_edit.drop(['borex_stroke','compression_ratio'], axis=1, inplace=True)

# %%
df_edit['front_tread'].unique()
# Out:
# array(['1420mm', nan, '1400mm', '1479mm', '1440mm', '1515mm', '1617mm',
#        '1505mm', '1480mm', '1558mm', '1530', '1560', '1624mm', '1463 mm',
#        '1315mm', '1595mm', '1564mm', '1295mm', '1510 mm', '1588mm',
#        '1605mm', '1540 mm', '1569mm', '1627mm', '1501mm', '1655mm',
#        '1651mm', '1450mm', '1430', '1530mm', '1541 mm', '1495mm',
#        '1490mm', '1539mm', '1470mm', '1463mm', '1536', '1386mm', '1457mm',
#        '1546mm', '1460mm', '1560mm', '1,505 mm', '1475mm', '1492mm',
#        '1527', '1644mm', '1621 mm', '1565mm', '1510mm', '1615mm',
#        '1519mm', '1577mm', '1585mm', '1485mm', '1666 mm', '1559mm',
#        '1555mm', '1531', '1520mm', '1435mm', '1552mm', '1520', '1,539 mm',
#        '1620 mm', '1600mm', '1621mm', '1540mm', '1601mm', '1,400 mm',
#        '1490', '1,522 mm', '1316', '1470 mm', '1547', '1544 mm', '1620mm',
#        '1571mm', '1544mm', '1572mm', '1496mm', '1641mm', '1553mm',
#        '1521 mm', '1648mm', '1549mm', '1205mm', '1535mm', '1576mm',
#        '1561mm', '1580mm', '1280', '1540', '1387mm', '1314mm', '1500mm',
#        '1476', '1325 mm', '1545 mm', '1,474 mm', '1616mm', '1443',
#        '1598mm', '1547mm', '1380 mm', '1380mm', '1,496 mm', '1541mm',
#        '1474mm', '1665mm', '1295', '1415 mm', '1445mm', '1634mm',
#        '1543mm', '1690mm', '1463', '1534mm', '1280mm', '1405mm', '1589mm',
#        '1376mm', '1522mm', '1365mm', '1679 mm', '1611mm', '1476 mm',
#        '1590mm', '1,565 mm', '1705mm', '1534 mm', '1628mm', '1505 mm',
#        '1668mm', '1484mm', '1,445 mm', '1641 mm', '1513 mm', '1570mm',
#        '1520 mm', '1,541 mm', '1632mm', '1511mm', '1580 mm', '1517mm',
#        '1578mm', '1618mm', '1569 mm', '1639mm', '1640mm', '1395 mm',
#        '1689mm', '1594mm', '1626mm', '1529mm', '1634 mm', '1568mm',
#        '1501 mm', '1606mm', '1,463 mm', '1666mm', '1485', '1605 mm',
#        '1602mm', '1586mm', '1300mm', '1473mm', '1496', '1355 mm',
#        '1,480 mm', '1465mm', '1619mm', '1450 mm', '1408mm', '1440',
#        '1591mm', '1680mm', '1,450 mm', '1597mm'], dtype=object)

# %%
df_edit['front_tread'] = df_edit['front_tread'].str.replace("mm", "", regex=False)
df_edit['front_tread'] = df_edit['front_tread'].str.replace(",", "", regex=False)
df_edit['front_tread'] = df_edit['front_tread'].str.replace("Mm", "", regex=False)
df_edit['front_tread'] = df_edit['front_tread'].str.replace(" ", "", regex=False)
df_edit['front_tread'] = pd.to_numeric(df_edit['front_tread'], errors='coerce')

# %%
df_edit['rear_tread'].unique()
# Out:
# array(['1410mm', nan, '1420mm', '1493mm', '1445mm', '1525mm', '1596mm',
#        '1503mm', '1465mm', '1581mm', '1530', '1567', '1637mm', '1481 mm',
#        '1300mm', '1597mm', '1551mm', '1290mm', '1520 mm', '1588 mm',
#        '1630mm', '1540 mm', '1515mm', '1582mm', '1618mm', '1501mm',
#        '1675mm', '1681mm', '1530 mm', '1440mm', '1440', '1530mm',
#        '1581 mm', '1505mm', '1478mm', '1534mm', '1480mm', '1463mm',
#        '1490mm', '1385mm', '1585mm', '1535', '1368mm', '1500mm', '1541mm',
#        '1454mm', '1567mm', '1614mm', '1,503 mm', '1470mm', '1484mm',
#        '1525', '1650mm', '1617 mm', '1456mm', '1565mm', '1510mm',
#        '1620mm', '1485mm', '1524mm', '1570mm', '1604mm', '1535mm',
#        '1495mm', '1686 mm', '1605mm', '1526mm', '1516', '1520mm',
#        '1425mm', '1435mm', '1549mm', '1520', '1,528 mm', '1666 mm',
#        '1600mm', '1540mm', '1510 mm', '1626mm', '1,385 mm', '1480',
#        '1,522 mm', '1318', '1480 mm', '1545', '1583 mm', '1636mm',
#        '1575mm', '1583mm', '1555mm', '1654mm', '1552mm', '1514 mm',
#        '1663mm', '1547mm', '1564mm', '1190mm', '1532mm', '1566mm',
#        '1562mm', '1558mm', '1290', '1610mm', '1540', '1388mm', '1627mm',
#        '1295mm', '1537mm', '1280mm', '1494', '1315 mm', '1561 mm',
#        '1460mm', '1,444 mm', '1502mm', '1632mm', '1335', '1529mm',
#        '1574mm', '1545mm', '1360 mm', '1384mm', '1,490 mm', '1544mm',
#        '1594mm', '1444mm', '1713mm', '1378 mm', '1514mm', '1346mm',
#        '1569mm', '1512mm', '1624mm', '1586mm', '1685mm', '1475mm', '1481',
#        '1559mm', '1400mm', '1458mm', '1340mm', '1691 mm', '1494 mm',
#        '1,550 mm', '1498mm', '1606mm', '1649mm', '1692mm', '1609mm',
#        '1512 mm', '1629mm', '1503 mm', '1455mm', '1671mm', '1496mm',
#        '1,420 mm', '1560mm', '1430mm', '1654 mm', '1,380 mm', '1639mm',
#        '1515 mm', '1,544 mm', '1522mm', '1605 mm', '1568mm', '1560 mm',
#        '1450mm', '1405 mm', '1628mm', '1501 mm', '1631mm', '1,463 mm',
#        '1686mm', '1495', '1617mm', '1554mm', '1310mm', '1834mm', '1612mm',
#        '1550mm', '1683mm', '1485', '1462mm', '1546mm', '1520mm`',
#        '1615mm', '1613mm', '1350 mm', '1,460 mm', '1577mm', '1455 mm',
#        '1665mm', '1659mm', '1356mm', '1654 mm ', '1490', '1450', '1591mm',
#        '1651mm', '1,430 mm'], dtype=object)

# %%
df_edit['rear_tread'] = df_edit['rear_tread'].str.replace("mm", "", regex=False)
df_edit['rear_tread'] = df_edit['rear_tread'].str.replace(",", "", regex=False)
df_edit['rear_tread'] = df_edit['rear_tread'].str.replace("Mm", "", regex=False)
df_edit['rear_tread'] = df_edit['rear_tread'].str.replace(" ", "", regex=False)
df_edit['rear_tread']= pd.to_numeric(df_edit['rear_tread'], errors='coerce')

# %%
MMM_imputation(df_edit, 'front_tread', 'mean')
MMM_imputation(df_edit, 'rear_tread', 'mean')

# %%
df_edit['wheel_size'].unique()
# Out:
# array([nan, '16', '14', '17', '15', '19', '13', '18', 'R18', '12', 'R16',
#        'R17', '20', 'R15', 'R19', 'R14', '21', 'R20'], dtype=object)

# %%
# Step 1: Calculate the mode of wheel_size for each body type (bt)
wheel_size_value = df_edit.groupby('bt')['wheel_size'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()

# Step 2: Define the replace_nan function
def replace_nan(row, values_dict):
    if pd.isnull(row['wheel_size']) and pd.notnull(row['bt']):
        return values_dict.get(row['bt'], row['wheel_size'])
    return row['wheel_size']

# Step 3: Apply the function to update the wheel_size column
df_edit['wheel_size'] = df_edit.apply(
    lambda row: replace_nan(row, wheel_size_value),
    axis=1
)

# Check the unique values in the updated wheel_size column
print(df_edit['wheel_size'].unique())

# Check the proportion of null values in the wheel_size and bt columns
print(df_edit['wheel_size'].isnull().sum() / len(df_edit))
print(df_edit['bt'].isnull().sum() / len(df_edit))
# Out:
# ['14' '16' '17' '15' '19' '13' '18' 'R18' '12' 'R16' 'R17' '20' 'R15'
#  'R19' 'R14' '21' 'R20' nan None]
# 0.000597442944198829
# 0.0004779543553590632

# %%
df_edit['wheel_size']=df_edit['wheel_size'].str.replace('R',"",regex=False)

# %%
df_edit['alloy_wheel_size']=df_edit['alloy_wheel_size'].str.replace('R',"",regex=False)
df_edit['alloy_wheel_size'].unique()
# Out:
# array([nan, '16', '14', '17', '15', '19', '13', '18', '12', '20', '21'],
#       dtype=object)

# %%
# Step 1: Calculate the mode of alloy_wheel_size for each body type (bt)
alloy_wheel_size_value = df_edit.groupby('bt')['alloy_wheel_size'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()

# Step 2: Define the replace_nan function for alloy_wheel_size
def replace_nan_alloy(row, values_dict):
    if pd.isnull(row['alloy_wheel_size']) and pd.notnull(row['bt']):
        return values_dict.get(row['bt'], row['alloy_wheel_size'])
    return row['alloy_wheel_size']

# Step 3: Apply the function to update the alloy_wheel_size column
df_edit['alloy_wheel_size'] = df_edit.apply(
    lambda row: replace_nan_alloy(row, alloy_wheel_size_value),
    axis=1
)

# Check the unique values in the updated alloy_wheel_size column
print(df_edit['alloy_wheel_size'].unique())

# Check the proportion of null values in the alloy_wheel_size and bt columns
print(df_edit['alloy_wheel_size'].isnull().sum() / len(df_edit))
print(df_edit['bt'].isnull().sum() / len(df_edit))
# Out:
# ['14' '16' '17' '15' '19' '13' '18' '12' '20' '21' nan None]
# 0.000597442944198829
# 0.0004779543553590632

# %%
df_edit['top_speed'].unique()
# Out:
# array(['150 Kmph', nan, '150 kmph', '172km/hr', '190 Kmph', '180 Kmph',
#        '165 Kmph', '172 Kmph', '175 kmph', '219kmph', '195 Kmph',
#        '226km/hr', '250 kmph', '236 Kmph', '222 Kmph', '152 kmph',
#        '240 Kmph', '250kmph', '176 Kmph', '170 Kmph', '191km/hr',
#        '232 Kmph', '233 Kmph', '137km/hr', '220 Kmph', '215 Kmph',
#        '154.19 kmph', '166 kmph', '183 Kmph', '226 Kmph', '160 kmph',
#        '156 Kmph', '185kmph', '157 Kmph', '165km/hr', '159.4 kmph',
#        '250 Kmph', '135 Kmph', '185 Kmph', '216 kmph', '200 Kmph',
#        '160.2 kmph', '230 Kmph', '216km/hr', '195.68 kmph', '158.83 kmph',
#        '210 Kmph', '168 Kmph', '155 Kmph', '177.22 kmph', '163 Kmph',
#        '230', '164 Kmph', '182km/hr', '186.08 kmph', '172 kmph',
#        '171.43 kmph', '155 kmph', '178.55 kmph', '182 Kmph', '186km/hr',
#        '189 kmph', '165 Km', '175 Kmph', '227km/hr', '164.26 kmph',
#        '194 Kmph', '242km/hr', '158km/hr', '160 Kmph', '190 kmph',
#        '157 kmph', '180 kmph', '225 Kmph', '215 kmph', '242 kmph',
#        '145 Kmph', '160km/hr', '178 kmph', '164.1km/hr', '158 Kmph',
#        '190km/hr', '196 Kmph', '165 kmph', '235kmph', '148.5km/hr',
#        '223km/hr', '171.92 Kmph', '188 Kmph', '151 kmph', '228 kmph',
#        '146 Kmph', '202 km/hr', '144km/hr', '213 kmph', '212 Kmph',
#        '250Kmph', '237 kmph', '196km/hr', '208 Kmph', '202km/hr',
#        '219 kmph', '217 kmph', '169 kmph', '186.69 kmph', '190 Kmph ',
#        '80 kmph', '95 kmph', '207 Kmph', '167.99kmph', '162.9km/hr',
#        '162.41kmph', '195 kmph', '145 kmph', '185km/hr', '167 Km/Hour',
#        '173 kmph', '231 kmph', '140 kmph', '161km/hr', '156km/hr',
#        '140 Kmph', '245', '170 Km/Hour', '105 kmph', '169 Kmph',
#        '117 Kmph', '179 kmph', '210 kmph', '205 Kmph', '185 kmph',
#        '242 Kmph', '153.98', '210km/hr', '105km/hr', '148km/hr',
#        '186 Kmph', '145kmph', '154.6 kmph', '250km/hr', '163 kmph',
#        '155.8 kmph', '170 kmph', '229 kmph', '156 kmph', '224 Kmph',
#        '149 Kmph', '154km/hr', '137 kmph', '228km/hr', '164.26kmph',
#        '152Km/Hour', '235 Kmph', '164 kmph', '198', '154 Kmph',
#        '212 kmph', '141.35', '183km/hr', '205km/hr', '144.93 kmph',
#        '222km/hr', ' ', '177 kmph', '243Kmph', '176 kmph', '234 Kmph',
#        '  ', '186 kmph', '151.63 kmph', '206 kmph', '240 kmph',
#        '157.3 kmph', '225Kmph', '238kmph', '125.67kmph', '128.84kmph',
#        '248 kmph', '237 Kmph', '156.09', '230Kmph', '202 Kmph',
#        '247 Kmph', ' 185 Kmph', '162 kmph', '151.2 kmph', '200.7 kmph',
#        '117 kmph', '150.49', '158.63 kmph', '130 Kmph', '189 Kmph',
#        '220 kmph', '175.61 kmph', '236km/hr', '163 km/hr', '180km/hr',
#        '240kmph', '138 kmph', '152km/hr', '200km/hr', '170km/hr',
#        '201Kmph', '230km/hr', '123.99', '136 kmph', '151.11 kmph',
#        '151.63 Kmph', '165 kmph ', '188 kmph', '175km/hr', '193 kmph',
#        '148.33 kmph', '183.8km/hr', '225km/hr', '180', '217 Kmph',
#        '209 Kmph', '204 Kmph', '219 Kmph', '228kmph', '222', '235km/hr',
#        '130 kmph', '163.81kmph', '191 Kmph', '190kmph', '246kmph',
#        '207kmph', '221Kmph', '221 Kmph', '160.21kmph', '220kmph',
#        '213kmph', '222 kmph', '259kmph', '154 kmph', '199 Kmph',
#        '228 Kmph', '239 Kmph', '241 Kmph', '163km/hr', '162.9 kmph',
#        '235 kmph', '234 kmph', '164.5 Kmph', '183 kmph', '232km/hr',
#        '195km/hr', '206km/hr', '161.7 Kmph', '141km/hr', '210 km/hr',
#        '133.9 kmph', '230 kmph', '233 kmph', '237kmph', '250 km/h', '227',
#        '160.58kmph', '120 Kmph', '225 kmph', '210kmph', '209km/hr',
#        '181 kmph', '195 Km', '171km/hr', '224 kmph', '86 Kmph',
#        '180 km/h', '148.5 kmph', '180.5 kmph', '158 kmph', '161 Kmph',
#        '191.7 kmph', '177km/hr', '150km/hr', '117km/hr', '155km/hr',
#        '163.81 kmph', '192 kmph', ' 160 Kmph', '162km/hr', '141 kmph',
#        '148 kmph', '126 Kmph', '161 kmph', '151 Kmph', '308Kmph',
#        '121.92', '129 Km/Hour', '170.41 kmph', '229 Kmph', '285km/hr',
#        '310 Kmph', '259 Kmph', '144.57kmph', '245kmph', '154.19 Kmph',
#        '142.95kmph', '168.56 kmph', '275 Kmph', '215km/hr', '144 Kmph',
#        '171 Kmph', '155kmph'], dtype=object)

# %%
df_edit['top_speed'] = df_edit['top_speed'].str.replace("Kmph", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("km/hr", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace(" ", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("km/Hour", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("kmph", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("kmph", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("Km/Hour", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("km/h", "", regex=False)
df_edit['top_speed'] = df_edit['top_speed'].str.replace("km", "", regex=False)
df_edit['top_speed'] = pd.to_numeric(df_edit['top_speed'], errors='coerce')

# %%
df_edit['mileage'].unique()
# Out:
# array(['23.1 kmpl', '17 kmpl', '23.84 kmpl', '19.1 kmpl', '23.65 kmpl',
#        '17.1 kmpl', '20.63 kmpl', '18.15 kmpl', '20.28 kmpl', '21.4 kmpl',
#        '18.9 kmpl', '18.2 kmpl', '15.1 kmpl', nan, '21.27 kmpl',
#        '17.33 kmpl', '17.8 kmpl', '18.48 kmpl', '22.38 kmpl',
#        '16.42 kmpl', '7.81 kmpl', '17.4 kmpl', '20.3 kmpl', '13.45 kmpl',
#        '15 kmpl', '17.11 kmpl', '20.14 kmpl', '20.51 kmpl', '19.34 kmpl',
#        '12.6 kmpl', '15.56 kmpl', '11.5 kmpl', '19.87 kmpl', '18.6 kmpl',
#        '22.54 kmpl', '16.3 kmpl', '18.53 kmpl', '22.05 kmpl',
#        '12.05 kmpl', '16.5 kmpl', '19.7 kmpl', '11.3 kmpl', '14.08 kmpl',
#        '12.07 kmpl', '22 kmpl', '21.5 kmpl', '15.3 kmpl', '26.68 kmpl',
#        '21.14 kmpl', '15.9 kmpl', '19.67 kmpl', '14.6 kmpl', '28.4 kmpl',
#        '21.76 kmpl', '26.21 kmpl', '19 kmpl', '19.98 kmpl', '18.5 kmpl',
#        '20 kmpl', '16.8 kmpl', '17.2 kmpl', '21.13 kmpl', '24 kmpl',
#        '25.32 kmpl', '16.55 kmpl', '19.2 kmpl', '24.04 kmpl',
#        '27.03 kmpl', '16.56 kmpl', '19.4 kmpl', '19.56 kmpl',
#        '20.92 kmpl', '19.03 kmpl', '21.1 kmpl', '18.19 kmpl',
#        '17.41 kmpl', '14.2 kmpl', '19.81 kmpl', '14.8 kmpl', '16 kmpl',
#        '18.4 kmpl', '13.2 kmpl', '14.1 kmpl', '20.36 kmpl', '13.24 kmpl',
#        '14.16 kmpl', '24.39 kmpl', '10.91 kmpl', '18.16 kmpl',
#        '20.89 kmpl', '18.1 kmpl', '16.35 kmpl', '15.97 kmpl',
#        '16.07 kmpl', '16.38 kmpl', '14.24 kmpl', '17.9 kmpl',
#        '19.01 kmpl', '25.2 kmpl', '19.6 kmpl', '18 kmpl', '17.21 kmpl',
#        '11.1 kmpl', '11.4 kmpl', '11.72 kmpl', '13.32 kmpl', '20.37 kmpl',
#        '24.3 kmpl', '18.27 kmpl', '20.45 kmpl', '18.7 kmpl', '22.41 kmpl',
#        '20.77 kmpl', '15.63 kmpl', '20.54 kmpl', '21.19 kmpl',
#        '27.39 kmpl', '17.92 kmpl', '26 kmpl', '10 kmpl', '17.5 kmpl',
#        '11.18 kmpl', '23 kmpl', '17.57 kmpl', '14.21 kmpl', '21.43 kmpl',
#        '20.65 kmpl', '22.9 kmpl', '14.5 kmpl', '12.99 kmpl', '19.12 kmpl',
#        '13.8 kmpl', '13.38 kmpl', '14.7 kmpl', '16.36 kmpl', '18.24 kmpl',
#        '21.56 kmpl', '20.38 kmpl', '23.7 kmpl', '20.08 kmpl', '10.9 kmpl',
#        '21.21 kmpl', '15.43 kmpl', '21.74 kmpl', '23.95 kmpl',
#        '19.27 kmpl', '15.4 kmpl', '22.07 kmpl', '20.85 kmpl',
#        '17.01 kmpl', '14.11 kmpl', '22.56 kmpl', '20.5 kmpl', '20.4 kmpl',
#        '20.73 kmpl', '15.6 kmpl', '14.67 kmpl', '19.3 kmpl', '14.71 kmpl',
#        '17.69 kmpl', '13.6 kmpl', '21.72 kmpl', '12.51 kmpl', '16.2 kmpl',
#        '13 kmpl', '17.74 kmpl', '12.55 kmpl', '12.8 kmpl', '22.35 kmpl',
#        '22.77 kmpl', '25.24 kmpl', '17.7 kmpl', '13.06 kmpl', '12.3 kmpl',
#        '17.14 kmpl', '21.03 kmpl', '21.7 kmpl', '23.2 kmpl', '14.69 kmpl',
#        '22.5 kmpl', '20.52 kmpl', '21.46 kmpl', '22.69 kmpl',
#        '22.32 kmpl', '21.01 kmpl', '24.4 kmpl', '17.42 kmpl',
#        '18.56 kmpl', '15.73 kmpl', '17.68 kmpl', '16.13 kmpl',
#        '13.79 kmpl', '18.25 kmpl', '18.3 kmpl', '15.5 kmpl', '15.17 kmpl',
#        '14.99 kmpl', '11.9 kmpl', '15.29 kmpl', '16.09 kmpl',
#        '16.47 kmpl', '20.09 kmpl', '21.63 kmpl', '15.26 kmpl',
#        '11.57 kmpl', '17.03 kmpl', '20.8 kmpl', '17.19 kmpl', '12 kmpl',
#        '23.9 kmpl', '20.04 kmpl', '110 kmpl', '14.59 kmpl', '14 kmpl',
#        '18.45 kmpl', '16.96 kmpl', '12.65 kmpl', '19.33 kmpl',
#        '19.65 kmpl', '22.15 kmpl', '25 kmpl', '14.82 kmpl', '10.75 kmpl',
#        '21.73 kmpl', '8 kmpl', '16.1 kmpl', '20.68 kmpl', '22.7 kmpl',
#        '11.36 kmpl', '13.4 kmpl', '18.49 kmpl', '14.28 kmpl',
#        '17.88 kmpl', '16.11 kmpl', '20.7 kmpl', '16.82 kmpl', '17.3 kmpl',
#        '20.46 kmpl', '12.35 kmpl', '15.04 kmpl', '18.75 kmpl',
#        '15.2 kmpl', '18.12 kmpl', '18.06 kmpl', '11.7 kmpl', '20.1 kmpl',
#        '22.74 kmpl', '28.09 kmpl', '17.67 kmpl', '20.88 km/kg',
#        '26.11 kmpl', '22.1 kmpl', '13.5 kmpl', '24.52 kmpl', '20.25 kmpl',
#        '13.58 kmpl', '10.54 kmpl', '15.7 kmpl', '19.64 kmpl', '140 kmpl',
#        '13.68 kmpl', '16.24 kmpl', '26.59 kmpl', '13.7 kmpl', '17.6 kmpl',
#        '19.69 kmpl', '15.41 kmpl', '14.9 kmpl', '17.52 kmpl',
#        '17.05 kmpl', '24.7 kmpl', '21.9 kmpl', '25.4 kmpl', '19.47 kmpl',
#        '21.66 kmpl', '25.8 kmpl', '10.5 kmpl', '14.4 kmpl', '9 kmpl',
#        '19.09 kmpl', '23.01 kmpl', '22.25 kmpl', '27.28 kmpl',
#        '21.64 kmpl', '22.61 kmpl', '15.8 kmpl', '18.09 kmpl',
#        '19.28 kmpl', '18.78 kmpl', '11.74 kmpl', '8.9 kmpl', '15.85 kmpl',
#        '18.76 kmpl', '16.95 kmpl', '23.59 kmpl', '14.84 kmpl',
#        '19.5 kmpl', '21 kmpl', '15.96 kmpl', '27.3 kmpl', '18.88 kmpl',
#        '13.93 kmpl', '14.74 kmpl', '16.4 kmpl', '16.28 kmpl',
#        '20.86 kmpl', '18.07 kmpl', '21.79 kmpl', '16.6 kmpl', '13.9 kmpl',
#        '26.1 kmpl', '13.92 kmpl', '18.55 kmpl', '14.02 kmpl',
#        '31.59 km/kg', '19.72 kmpl', '14.57 kmpl', '21.8 kmpl',
#        '15.37 kmpl', '13.53 kmpl', '14.53 kmpl', '13.22 kmpl',
#        '25.5 kmpl', '14.75 kmpl', '16.46 kmpl', '19.02 kmpl',
#        '18.41 kmpl', '23.8 kmpl', '14.3 kmpl', '17.99 kmpl', '15.81 kmpl',
#        '15.34 kmpl', '19.08 kmpl', '18.86 kmpl', '19.49 kmpl',
#        '22.95 kmpl', '25.17 kmpl', '16.14 kmpl', '17.09 kmpl',
#        '18.97 kmpl', '12.08 kmpl', '16.78 kmpl', '19.23 kmpl', '8.5 kmpl',
#        '25.6 kmpl', '22.3 kmpl', '18.72 kmpl', '13.96 kmpl', '16.65 kmpl',
#        '12.62 kmpl', '19.44 kmpl', '14.62 kmpl', '23.64 kmpl',
#        '19.71 kmpl', '13.17 kmpl', '19.15 kmpl', '23.56 kmpl',
#        '23.4 kmpl', '19.62 kmpl', '16.25 kmpl', '27.62 kmpl',
#        '25.44 kmpl', '20.71 kmpl', '9.8 kmpl', '13.14 kmpl', '11.33 kmpl',
#        '25.19 kmpl', '24.29 kmpl', '19.16 kmpl', '16.73 kmpl',
#        '19.83 kmpl', '25.83 kmpl', '12.2 kmpl', '12.78 kmpl',
#        '14.49 kmpl', '20.58 kmpl', '24.35 kmpl', '14.19 kmpl',
#        '12.7 kmpl', '26.49 km/kg', '16.98 kmpl', '16.02 kmpl',
#        '18.05 kmpl', '24.2 kmpl', '15.64 kmpl', '19.19 kmpl',
#        '13.01 kmpl', '12.83 kmpl', '11.24 kmpl', '12.18 kmpl',
#        '18.8 kmpl', '26.2 kmpl', '23.08 kmpl', '22.37 kmpl', '16.9 kmpl',
#        '19.59 kmpl', '14.85 kmpl', '12.74 kmpl', '28 km/kg', '12.4 kmpl',
#        '12.5 kmpl', '14.025 kmpl', '19.89 kmpl', '30.48 km/kg',
#        '33.54 kmpl', '19.61 kmpl', '26.08 km/kg', '12.1 kmpl',
#        '12.81 kmpl', '9.2 kmpl', '17.71 kmpl', '16.34 kmpl', '30.46 kmpl',
#        '32.52 kmpl', '11.21 kmpl', '16.39 kmpl', '11.2 kmpl',
#        '12.04 kmpl', '11.67 kmpl', '16.12 kmpl', '26.55 kmpl',
#        '7.08 kmpl', '31.2 kmpl', '12.33 kmpl', '31.79 kmpl', '11 kmpl',
#        '8.13 kmpl', '35.6 km/kg', '16.72 kmpl', '25.1 kmpl', '22.48 kmpl',
#        '20.6 kmpl', '14.01 kmpl', '17.38 kmpl', '12.34 kmpl', '10.8 kmpl',
#        '9.26 kmpl', '12.95 kmpl', '12.9 kmpl', '16.7 kmpl', '15.68 kmpl',
#        '10.4 kmpl', '20.15 kmpl', '31.12 km/kg', '26.8 kmpl',
#        '11.88 kmpl', '18.69 kmpl', '18.9 km/kg', '22.27 kmpl',
#        '15.01 kmpl', '10.26 kmpl', '19.39 kmpl', '14.34 kmpl',
#        '8.45 kmpl', '26.11 km/kg', '12.63 kmpl', '26.6 kmpl',
#        '13.47 kmpl', '10.13 kmpl', '20.27 kmpl', '14.09 kmpl',
#        '20.01 kmpl', '14.47 kmpl', '10.93 kmpl', '26.6 km/kg',
#        '26.83 kmpl', '31.12 kmpl', '24.76 kmpl', '21.11 kmpl',
#        '14.23 kmpl', '26.82 kmpl', '17.32 kmpl', '25.3 kmpl',
#        '19.95 kmpl', '21.12 kmpl', '11.96 kmpl', '21.02 kmpl',
#        '19.68 kmpl', '18.23 kmpl', '23.22 kmpl', '17.97 kmpl',
#        '16.97 kmpl', '13.33 kmpl', '27.4 kmpl', '26.5 kmpl', '25.01 kmpl',
#        '17.43 kmpl', '22.71 kmpl', '20.34 kmpl', '24.1 kmpl',
#        '30.47 km/kg', '17.29 kmpl', '21.49 kmpl', '13.1 kmpl',
#        '21.1 km/kg', '18.43 kmpl', '12.12 kmpl', '9.74 kmpl',
#        '16.77 kmpl', '19.17 kmpl', '21.38 kmpl', '23.57 kmpl',
#        '24.8 kmpl', '7.94 kmpl', '26.49 kmpl', '25.47 kmpl', '18.33 kmpl',
#        '9.4 kmpl', '7.5 kmpl', '13.44 kmpl', '14.94 kmpl', '23.03 kmpl',
#        '15.39 kmpl', '24.97 kmpl', '34.05 kmpl', '17.85 kmpl',
#        '27.97 kmpl', '20.62 kmpl', '15.15 kmpl', '19.8 kmpl',
#        '14.95 kmpl', '11.81 kmpl', '12.98 kmpl'], dtype=object)

# %%
df_edit['mileage'] = df_edit['mileage'].str.replace("kmpl", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace(" ", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace("km/kg", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace("Kmpl", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace("Km/kg", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace("Kmpl", "", regex=False)
df_edit['mileage'] = pd.to_numeric(df_edit['mileage'], errors='coerce')

# %%
# Step 1: Group by 'mileage' and calculate the mean of 'top_speed'
top_speed_value = df_edit.groupby('mileage')['top_speed'].mean().to_dict()

# Step 2: Define the function to replace NaN in 'top_speed'
def replace_nan(row, values_dict):
    if pd.isnull(row['top_speed']) and pd.notnull(row['mileage']):
        return values_dict.get(row['mileage'], row['top_speed'])
    return row['top_speed']

# Step 3: Apply the function to the DataFrame
df_edit['top_speed'] = df_edit.apply(
    lambda row: replace_nan(row, top_speed_value),
    axis=1
)

# %%
#drop "acceleration" column,assumption based on acceleration may be change due to body type, weight, areodynamics  
df_edit.drop('acceleration', axis=1, inplace=True)

# %%
df_edit['value_configuration'].unique()
# Out:
# array(['DOHC', nan, 'SOHC', 'DOHC ', 'undefined', 'DOHC with VIS',
#        '16 Modules 48 Cells', 'iDSI', '23 Modules 69 Cells',
#        'DOHC with VGT', '16-valve DOHC layout', 'DOHC with TIS', 'VTEC',
#        'SOHC '], dtype=object)

# %%
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("DOHC with VIS", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("DOHC with TIS", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("DOHC ", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("16-valve DOHC layout", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("SOHC ", "SOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("SOHC ", "SOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("16-valve DOHClayout", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].str.replace("DOHCwith VGT", "DOHC", regex=False)
df_edit['value_configuration'] = df_edit['value_configuration'].replace("undefined", None)

# %%
df_edit['turbo_charger'].unique()
# Out:
# array(['No', 'Yes', 'NO', nan, 'Twin', 'YES', 'no', 'twin', 'yes',
#        'Turbo'], dtype=object)

# %%
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.lower()
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.replace("turbo", "yes", regex=False)
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.replace("twin", "yes", regex=False)

# %%
df_edit['super_charger'] = df_edit['super_charger'].str.lower()
df_edit['super_charger'].unique()
# Out:
# array(['no', nan, 'yes'], dtype=object)

# %%
df_edit['drive_type'].unique()
# Out:
# array(['FWD', 'FWD ', '4X2', 'AWD', nan, 'RWD', '4x2', '2WD', '4WD',
#        '2 WD', 'Front Wheel Drive', 'Rear Wheel Drive with ESP', '4X4',
#        'Two Wheel Drive', '2WD ', 'All Wheel Drive', '4x4',
#        'AWD INTEGRATED MANAGEMENT', 'RWD(with MTT)',
#        'Permanent all-wheel drive quattro', '4 WD'], dtype=object)

# %%
# Create a dictionary for replacements
replacements = {
    "FWD ": "FWD",
    "Front Wheel Drive": "FWD",
    "2WD ": "2WD",
    "2 WD": "2WD",
    "4 WD": "4WD",
    "Rear Wheel Drive with ESP": "RWD",
    "RWD(with MTT)": "4WD",
    "All Wheel Drive": "AWD",
    "AWD INTEGRATED MANAGEMENT": "AWD",
    "Two Wheel Drive": "2WD",
    "Permanent all-wheel drive quattro": "AWD",
    "4x2": "2WD",
    "4X4": "4WD",
    "4X2": "2WD",
    "4x4": "4WD"
}

# Use the replace method with the dictionary
df_edit['drive_type'] = df_edit['drive_type'].replace(replacements, regex=False)

# %%
df_edit['drive_type'].unique()
# Out:
# array(['FWD', '2WD', 'AWD', nan, 'RWD', '4WD'], dtype=object)

# %%
df_edit['turning_radius'].unique()
# Out:
# array(['4.7 metres', '5.3 metres', '4.9 meters', '5.2 meters', nan,
#        '4.6 metres', '5.4 metres', '4.8 metres', '5.1 meters',
#        '5.6 metres', '5.1', '4.8', '5.2m', '6.15 metres ', '4.4 meters',
#        '6 metres', '5.8 metres', '5.2 metres', '5.61 metres', '5.6',
#        '5.9 m', '5.95 metres', '4.6', '4.6m', '6.2 metres', '6.0 metres',
#        '4.9 metres', '5.1m', '5 m', '4.8 Meters', '5.5 metres',
#        '5.55 metres', '5.3metres', '4.97 metres', '5.3 meters',
#        '5.05 metres', '5.65 metres', '5.3 m', '4.5 metres', '4.9',
#        '4.6metres', '5.55', '4.5', '5.20 m', '4.7 m', '6.4 meters', '5.8',
#        '5.9metres', '5.2meters', '5.5 m', '5.7 metres', '5.4', '4.9 m',
#        '5.75 metres', '5.35 metres', '5.05', '5.0metres', '5.4 m', '5.5m',
#        '4.7m', '5.2', '5.05 meters', '4.85', '5.3', '5.55 m',
#        '5.25 metres', '5.0m', '5.9 metres', '5.0', '4.8metres',
#        '4.7 Metre', '5.9 meters', '4.35mm', '4.2', '4.9metres', '4.1 m',
#        '5.39', '5.4 meters', '5.4m', '5.52 metres', '5 metres',
#        '4.85metres', '4.5metres', '5.35m', '4.9 meter', '5.6 meters',
#        '5.1 metres', '6.28 metres', '5.6metres', '5.0 metres', '5.25 m',
#        '5.1 meter', '4.98', '4 m', '5.2 mtrs.', '5.1metres', '5.75m',
#        '4.65 metres', '5.1 m', '5m', '4.0 metres', '4.9m', '5.25 meters',
#        '5.0 m', '6.35m', '5.42 m', '5.20 mtrs.', '5.42 metres',
#        '5.2metres', '5.7m', '5.45 metres', '6.15 metres', '5.5',
#        '6.05 meters', '4.65metres', '4.8 m', '5.15 metres ',
#        '6.25 meters', '4.7', '5.46 m', '6.45 metres ', '6.1 m',
#        '4.4metres', '5.45 m', '5.8 Metre', '6.1m', '6.1 metres',
#        '11.5 metres', '4.85 metres', '5.6 m', '5.4 Meter', '12 metres',
#        '11.4m', '5.62 m', '4metres', '5.03m', '4.5 m', '5.05 m', '5.8m',
#        '5.2 m', '5.5 meters', '5.85 metres', '4.9 Meters', '5.8 meters',
#        '5.35 m', '5.75meters', '4.6 m', '6.25m', '5.92 metres', '6.42',
#        '5.3 Meter', '5.7', '5.6 Meters', '6.2 Metre', '5.59 metres',
#        '11.6m', '13.51', '6.45 metres', '6.2 Seconds', '13.51 metres',
#        '5.3 Meters', '12.40 m', '4.97 m', '5.9', '5.26 meters',
#        '5.4metres', '4.4m', '5.85 m', '4.97 meters', '6.05 metres',
#        '5.9 metres ', '5.85 meters', '5.25', '5 meters', '5.8 m',
#        '4.58metres', '5.6m', '4.85 metres ', '5.25mm', '5.35', '6250mm',
#        '5.15 metres', '13m', '11.6 metres', '4.6 metres ', '5.9m',
#        '5.65 meters', '5.02', '5.5metres', '4.95m', '6metres', '4.4 m',
#        '5.4 meter', '5.03 m', '4.65 M', '4.7metres', '5.45 metres '],
#       dtype=object)

# %%
df_edit['turning_radius'] = df_edit['turning_radius'].str.replace(r'[^0-9.\-\,]', '', regex=True)
df_edit['turning_radius'] = df_edit['turning_radius'].str.replace("6250", "6.25", regex=False)
df_edit['turning_radius'] = pd.to_numeric(df_edit['turning_radius'], errors='coerce')

# %%
df_edit['cargo_volumn'].unique()
# Out:
# array(['235-litres', '352-litres', '242-litres', '407-litres',
#        '353-litres', '408-litres', '265-litres', '350', '510-litres',
#        '339-litres', '256', '354-litres', nan, '520 litres', '268', '475',
#        '530-litres', '235', '540-litres', '480-litres', '407',
#        '180-liters', '209 litres', '520-litres', '295-litres',
#        '420-litres', '211litres', '242', '433', '285', '680-litres', '73',
#        '330-litres', '279', '313', '460-litres', '400-litres', '425',
#        '268-litres', '520', '207-litres', '590', '236-liters', '311',
#        '506-litres', '460', '256-liters', '243-litres', '225-litre',
#        '300', '380-litres', '259 Litres', '155 L', '175-litres', '405',
#        '215-litres', '494', '476', '587', '400', '720-litres', '445',
#        '460 litres', '565-litres', '475-litres', '214', '295 Lit',
#        '257-litres', '260-litres', '84', '650-litres', '460 liters',
#        '513', '480', '550 Litre', '204-liters', '510', '280',
#        '280-liters', '450-litres', '392 Litres', '328-litres', '350 L',
#        '378', '135-liters', '346-litres', '285-litres', '540-litre',
#        '363 Litres', '232-litres', '300-litres', '400 litres',
#        '430 litres', '385/1405', '385', '177', '320-liters', '486-litres',
#        '465-litres', '540', '560 litres', '625', '440 litres',
#        '160 - 680-litres', '280-litres', '296-litres', '318', '392',
#        '222', '359 Litres', '341 Litres', '465-litre', '257', '485',
#        '284-litres', '419', '225-litres', '506', '508 litres',
#        '480 Liters', '341-litres', '336', '462 litres', '320 liters',
#        '981', '235 Litres', '690-litres', '550-litres', '328',
#        '470-litres', '589-litres', '135litres', '420', '615lits', '345',
#        '220-litres', '330 Ltrs', '232 litres', '505-litres', '535-litre',
#        '384-litres', '170-litres', '470', '217-litre', '580',
#        '755-litres', '354', '500 litres', '390', '550', '177-litres',
#        '416-litres', '504-litres ', '455', '170 litres', '195-litres',
#        '464 litres', '510 litres', '135 Ltrs', '315', '359-litre', '690',
#        '460-litre', '565 Litres', '128', '251-litres', '420 litres',
#        '485-liters', '280 Liters', '339', '368 litres', '565 litres',
#        '80-litres', '340', '521 Litres', '284 Liters', '359-litres',
#        '210-Liter', '506 litres', '190', '450 litres', '300 litres',
#        '380-litre', '490-litres', '380 litres', '475 litres', '505',
#        '504-litres', '260-950 litres', '595', '981-litre', '384',
#        '360-litres', '315-litre', '590-liters', '416-litre', '320',
#        '425-litres', '550-liters', '375', '376-litres', '363',
#        '780-litres', '410-litres', '180', '330', '505 litres',
#        '540-liters', '370-litres', '890 litres', '500-litres', '265',
#        '209', '454-liters', '405 litres', '260', '825-litres',
#        '419 litres', '595-litres', '350-litres', '420Liters',
#        '527 litres', '251', '341', '366', '223-litres', '270',
#        '480-litre', '170-litres ', '330 litre', '347Litre', '436-litres',
#        '520 liters', '347 L', '430-litres', '278-litre', '500-Litres',
#        '243', '217 litres', '575-litres', '280 Litres', '352 litres',
#        '232 Liters', '347 (3rd Row Folded)', '382-litres', '452',
#        '495-liters', '521', '258', '454', '335', '494-liters', '530',
#        '696', '615', '211litrs', '515', '421-litres', '857', '784-litres',
#        '211', '360 Litres', '560', '740litres', '472', '1728-litres',
#        '500', '680-Liters', '458-litres', '160litres', '300-litre',
#        '483lts', '194-litres', '410', '625 litres', '398-litres',
#        '405-litres', '218-litre', '595-litre', '218 litres', '475-litre',
#        '29- Litres', '280 litres', '430', '560-litre', '308',
#        '316 liters', '495-litre', '390-litres', '560-litres', '586',
#        '251-litre', '430-litre', '909-litres', '490', '324-litres', '210',
#        '232-litre', '510litres', '290 litres', '670 litres', '488-litres',
#        '405 liters', '180 liters', '450-litre', '220 litres',
#        '981-litres', '210-litres', '316', '215-litre', '132 L', '205',
#        '786', '558 litre', '445-litres', '462-litre', '465', '48-litres',
#        '196-litres', '200-litres', '259 L', '490-litre'], dtype=object)

# %%
df_edit['cargo_volumn'] = df_edit['cargo_volumn'].str.extract(r'(\d+\.?\d*)', expand=False)

# %%
df_edit['cargo_volumn'] = pd.to_numeric(df_edit['cargo_volumn'], errors='coerce')

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_B10 = null_percentage[(null_percentage > 0) & (null_percentage <= 10)]
print(columns_with_null_B10)
print(columns_with_null_B10.shape[0])
# Out:
# bt                          0.047795
# registration_year           0.621341
# insurance_validity          0.047795
# seats                       0.071693
# kms_driven                  0.023898
# ownership                   0.382363
# engine_displacement         0.047795
# year_of_manufacture         0.238977
# mileage                     3.429322
# engine                      0.047795
# max_power                   0.716932
# torque                      0.716932
# seats.1                     0.071693
# color                       0.035847
# engine_type                 3.524913
# displacement                0.047795
# max_torque                  0.716932
# no_of_cylinder              0.370415
# values_per_cylinder         0.609392
# length                      0.943960
# width                       0.991755
# height                      0.943960
# wheel_base                  1.947664
# kerb_weight                 7.288804
# gross_weight                3.955072
# gear_box                    1.266579
# seating_capacity            0.071693
# steering_type               3.046959
# front_brake_type            1.147090
# rear_brake_type             1.147090
# tyre_type                   0.920062
# no_door_numbers             0.131437
# wheel_size                  0.059744
# alloy_wheel_size            0.059744
# ground_clearance_unladen    0.047795
# dtype: float64
# 35

# %%
# List of columns to fill NaN values based on mode by 'model'
columns_to_fill = [
    'bt', 'registration_year', 'seats', 'kms_driven', 'engine_displacement',
    'year_of_manufacture', 'mileage', 'engine', 'max_power', 'torque',
    'color', 'engine_type', 'displacement', 'max_torque', 'no_of_cylinder',
    'values_per_cylinder', 'length', 'width', 'height', 'wheel_base',
    'kerb_weight', 'gear_box', 'seating_capacity', 'steering_type',
    'front_brake_type', 'rear_brake_type', 'tyre_type', 'no_door_numbers'
]

# Step 1: Calculate the mode of each column for each model value
mode_values = {
    col: df_edit.groupby('model')[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
    for col in columns_to_fill
}

# Step 2: Define the replace_nan function for each column
def replace_nan(row, col, values_dict):
    if pd.isnull(row[col]) and pd.notnull(row['model']):
        return values_dict.get(row['model'], row[col])
    return row[col]

# Step 3: Apply the function to update each column
for col in columns_to_fill:
    df_edit[col] = df_edit.apply(
        lambda row: replace_nan(row, col, mode_values[col]),
        axis=1
    )

# %%
# List of columns to fill NaN values based on mode by 'model'
columns_to_fill = [
    'value_configuration', 'fuel_suppy_system', 'turbo_charger', 'super_charger',
    'drive_type', 'turning_radius', 'cargo_volumn'
]

# Step 1: Calculate the mode of each column for each model value
mode_values = {
    col: df_edit.groupby('model')[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
    for col in columns_to_fill
}

# Step 2: Define the replace_nan function for each column
def replace_nan(row, col, values_dict):
    if pd.isnull(row[col]) and pd.notnull(row['model']):
        return values_dict.get(row['model'], row[col])
    return row[col]

# Step 3: Apply the function to update each column
for col in columns_to_fill:
    df_edit[col] = df_edit.apply(
        lambda row: replace_nan(row, col, mode_values[col]),
        axis=1
    )

# %%
rto_value = df_edit.groupby('city')['rto'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()

def replace_rto(row, values_dict):
    if pd.isnull(row['rto']) and pd.notnull(row['city']):
        return values_dict.get(row['city'], row['rto'])
    return row['rto']

df_edit['rto'] = df_edit.apply(
    lambda row: replace_rto(row, rto_value),  # Use the correct function name here
    axis=1
)

# %%
# Step 1: Calculate the percentage where gross_weight is not null
df_non_null = df_edit[df_edit['gross_weight'].notna()]
df_non_null['percentage_weight_calculation'] = ((df_non_null['gross_weight'] - df_non_null['kerb_weight']) / df_non_null['kerb_weight']) * 100

# Step 2: Compute the mean percentage
mean_percentage = df_non_null['percentage_weight_calculation'].mean()

# Step 3: Fill the null values in gross_weight using the mean percentage
df_edit.loc[df_edit['gross_weight'].isna(), 'gross_weight'] = df_edit['kerb_weight'] * (1 + mean_percentage / 100)
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_1888\832311446.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_null['percentage_weight_calculation'] = ((df_non_null['gross_weight'] - df_non_null['kerb_weight']) / df_non_null['kerb_weight']) * 100

# %%
columns_to_fill = [
    'bt', 'registration_year', 'insurance_validity', 'seats',
    'ownership', 'year_of_manufacture', 'mileage', 'max_power',
    'torque', 'seats.1', 'engine_type', 'max_torque', 'no_of_cylinder',
    'values_per_cylinder', 'value_configuration', 'fuel_suppy_system',
    'turbo_charger', 'super_charger', 'length', 'width', 'height',
    'wheel_base', 'kerb_weight', 'gross_weight', 'gear_box', 'drive_type',
    'seating_capacity', 'steering_type', 'turning_radius', 'front_brake_type',
    'rear_brake_type', 'top_speed', 'tyre_type', 'no_door_numbers',
    'cargo_volumn', 'wheel_size', 'alloy_wheel_size', 'ground_clearance_unladen'
]

# Fill null values with mode for each column
for column in columns_to_fill:
    mode_value = df_edit[column].mode()[0]  # Get the mode value
    df_edit[column].fillna(mode_value, inplace=True)  # Fill NaNs with the mode value

# %%
#drop duplicate columns
df_edit.drop(['owner','fuel_type','kms_driven','ownership','engine_displacement','year_of_manufacture','engine','seats.1','seating_capacity','alloy_wheel_size'], axis=1, inplace=True)

# %%
df_edit.dtypes
# Out:
# it                                                 int64
# ft                                                object
# bt                                                object
# km                                                object
# transmission                                      object
# ownerno                                            int64
# oem                                               object
# model                                             object
# modelyear                                          int64
# centralvariantid                                   int64
# variantname                                       object
# price                                             object
# trendingtext.imgurl                               object
# trendingtext.heading                              object
# trendingtext.desc                                 object
# registration_year                                 object
# insurance_validity                                object
# seats                                             object
# rto                                               object
# power_steering                                      bool
# power_windows_front                                 bool
# air_conditioner                                     bool
# heater                                              bool
# adjustable_head_lights                              bool
# manually_adjustable_exterior_rear_view_mirror       bool
# centeral_locking                                    bool
# child_safety_locks                                  bool
# power_windows_rear                                  bool
# remote_trunk_opener                                 bool
# remote_fuel_lid_opener                              bool
# low_fuel_warning_light                              bool
# accessory_power_outlet                              bool
# vanity_mirror                                       bool
# rear_seat_headrest                                  bool
# cup_holders_front                                   bool
# digital_odometer                                    bool
# electronic_multi_tripmeter                          bool
# fabric_upholstery                                   bool
# glove_compartment                                   bool
# digital_clock                                       bool
# wheel_covers                                        bool
# power_antenna                                       bool
# chrome_grille                                       bool
# day_night_rear_view_mirror                          bool
# passenger_side_rear_view_mirror                     bool
# halogen_headlamps                                   bool
# rear_seat_belts                                     bool
# door_ajar_warning                                   bool
# side_impact_beams                                   bool
# front_impact_beams                                  bool
# adjustable_seats                                    bool
# centrally_mounted_fuel_tank                         bool
# engine_immobilizer                                  bool
# anti_theft_device                                   bool
# fog_lights_front                                    bool
# anti_lock_braking_system                            bool
# cd_player                                           bool
# trunk_light                                         bool
# multifunction_steering_wheel                        bool
# navigation_system                                   bool
# smart_access_card_entry                             bool
# engine_start_stop_button                            bool
# gear_shift_indicator                                bool
# luggage_hook_and_net                                bool
# adjustable_steering                                 bool
# tachometer                                          bool
# leather_steering_wheel                              bool
# outside_temperature_display                         bool
# height_adjustable_driver_seat                       bool
# power_adjustable_exterior_rear_view_mirror          bool
# electric_folding_rear_view_mirror                   bool
# rear_window_wiper                                   bool
# rear_window_washer                                  bool
# rear_window_defogger                                bool
# alloy_wheels                                        bool
# integrated_antenna                                  bool
# outside_rear_view_mirror_turn_indicators            bool
# roof_rail                                           bool
# power_door_locks                                    bool
# driver_air_bag                                      bool
# passenger_air_bag                                   bool
# seat_belt_warning                                   bool
# keyless_entry                                       bool
# engine_check_warning                                bool
# crash_sensor                                        bool
# ebd                                                 bool
# follow_me_home_headlamps                            bool
# rear_camera                                         bool
# speed_sensing_auto_door_lock                        bool
# pretensioners_and_force_limiter_seatbelts           bool
# impact_sensing_auto_door_lock                       bool
# no_of_airbags                                       bool
# radio                                               bool
# speakers_front                                      bool
# speakers_rear                                       bool
# integrated2din_audio                                bool
# usb_auxiliary_input                                 bool
# bluetooth                                           bool
# touch_screen                                        bool
# number_of_speaker                                   bool
# glove_box_cooling                                   bool
# driving_experience_control_eco                      bool
# tinted_glass                                        bool
# rear_spoiler                                        bool
# chrome_garnish                                      bool
# vehicle_stability_control_system                    bool
# rear_reading_lamp                                   bool
# rear_seat_centre_arm_rest                           bool
# cup_holders_rear                                    bool
# rear_acvents                                        bool
# air_quality_control                                 bool
# height_adjustable_front_seat_belts                  bool
# cruise_control                                      bool
# voice_control                                       bool
# audio_system_remote_control                         bool
# leather_seats                                       bool
# fog_lights_rear                                     bool
# traction_control                                    bool
# seat_lumbar_support                                 bool
# battery_saver                                       bool
# lane_change_indicator                               bool
# sun_roof                                            bool
# automatic_driving_lights                            bool
# anti_theft_alarm                                    bool
# automatic_head_lamps                                bool
# isofix_child_seat_mounts                            bool
# hill_assist                                         bool
# tailgate_ajar                                       bool
# brake_assist                                        bool
# steering_wheel_gearshift_paddles                    bool
# ledtaillights                                       bool
# cigarette_lighter                                   bool
# rain_sensing_wiper                                  bool
# drive_modes                                         bool
# active_noise_cancellation                           bool
# adjustable_headrest                                 bool
# hands_free_tailgate                                 bool
# dual_tone_dashboard                                 bool
# leather_wrap_gear_shift_selector                    bool
# dual_tone_body_colour                               bool
# leddrls                                             bool
# ledheadlights                                       bool
# cornering_headlamps                                 bool
# cornering_foglamps                                  bool
# side_air_bag_front                                  bool
# side_air_bag_rear                                   bool
# tyre_pressure_monitor                               bool
# clutch_lock                                         bool
# anti_pinch_power_windows                            bool
# knee_airbags                                        bool
# apple_car_play                                      bool
# android_auto                                        bool
# mirror_link                                         bool
# wireless_phone_charging                             bool
# compass                                             bool
# moon_roof                                           bool
# projector_headlamps                                 bool
# speed_alert                                         bool
# eletronic_stability_control                         bool
# touch_screen_size                                   bool
# xenon_headlamps                                     bool
# cd_changer                                          bool
# power_boot                                          bool
# rear_folding_table                                  bool
# smoke_headlamps                                     bool
# dvd_player                                          bool
# internal_storage                                    bool
# rear_entertainment_system                           bool
# remote_engine_start_stop                            bool
# ventilated_seats                                    bool
# ledfog_lamps                                        bool
# view360camera                                       bool
# geo_fence_alert                                     bool
# steering_mounted_tripmeter                          bool
# remote_climate_control                              bool
# remote_horn_light_control                           bool
# heated_wing_mirror                                  bool
# side_stepper                                        bool
# blind_spot_monitor                                  bool
# hill_descent_control                                bool
# heads_up_display                                    bool
# sos_emergency_assistance                            bool
# cassette_player                                     bool
# find_my_car_location                                bool
# wifi_connectivity                                   bool
# headlamp_washers                                    bool
# real_time_vehicle_tracking                          bool
# roof_carrier                                        bool
# smart_key_band                                      bool
# lane_watch_camera                                   bool
# removable_convertible_top                           bool
# power_folding3rd_row_seat                           bool
# mileage                                          float64
# max_power                                         object
# torque                                            object
# color                                             object
# engine_type                                       object
# displacement                                     float64
# max_torque                                        object
# no_of_cylinder                                   float64
# values_per_cylinder                              float64
# value_configuration                               object
# fuel_suppy_system                                 object
# turbo_charger                                     object
# super_charger                                     object
# length                                            object
# width                                             object
# height                                            object
# wheel_base                                        object
# front_tread                                      float64
# rear_tread                                       float64
# kerb_weight                                      float64
# gross_weight                                     float64
# gear_box                                          object
# drive_type                                        object
# steering_type                                     object
# turning_radius                                   float64
# front_brake_type                                  object
# rear_brake_type                                   object
# top_speed                                        float64
# tyre_type                                         object
# no_door_numbers                                  float64
# cargo_volumn                                     float64
# wheel_size                                        object
# ground_clearance_unladen                         float64
# car_links                                         object
# city                                              object
# dtype: object

# %%
df_edit.isnull().sum()/len(df_edit)
# Out:
# it                                               0.0
# ft                                               0.0
# bt                                               0.0
# km                                               0.0
# transmission                                     0.0
# ownerno                                          0.0
# oem                                              0.0
# model                                            0.0
# modelyear                                        0.0
# centralvariantid                                 0.0
# variantname                                      0.0
# price                                            0.0
# trendingtext.imgurl                              0.0
# trendingtext.heading                             0.0
# trendingtext.desc                                0.0
# registration_year                                0.0
# insurance_validity                               0.0
# seats                                            0.0
# rto                                              0.0
# power_steering                                   0.0
# power_windows_front                              0.0
# air_conditioner                                  0.0
# heater                                           0.0
# adjustable_head_lights                           0.0
# manually_adjustable_exterior_rear_view_mirror    0.0
# centeral_locking                                 0.0
# child_safety_locks                               0.0
# power_windows_rear                               0.0
# remote_trunk_opener                              0.0
# remote_fuel_lid_opener                           0.0
# low_fuel_warning_light                           0.0
# accessory_power_outlet                           0.0
# vanity_mirror                                    0.0
# rear_seat_headrest                               0.0
# cup_holders_front                                0.0
# digital_odometer                                 0.0
# electronic_multi_tripmeter                       0.0
# fabric_upholstery                                0.0
# glove_compartment                                0.0
# digital_clock                                    0.0
# wheel_covers                                     0.0
# power_antenna                                    0.0
# chrome_grille                                    0.0
# day_night_rear_view_mirror                       0.0
# passenger_side_rear_view_mirror                  0.0
# halogen_headlamps                                0.0
# rear_seat_belts                                  0.0
# door_ajar_warning                                0.0
# side_impact_beams                                0.0
# front_impact_beams                               0.0
# adjustable_seats                                 0.0
# centrally_mounted_fuel_tank                      0.0
# engine_immobilizer                               0.0
# anti_theft_device                                0.0
# fog_lights_front                                 0.0
# anti_lock_braking_system                         0.0
# cd_player                                        0.0
# trunk_light                                      0.0
# multifunction_steering_wheel                     0.0
# navigation_system                                0.0
# smart_access_card_entry                          0.0
# engine_start_stop_button                         0.0
# gear_shift_indicator                             0.0
# luggage_hook_and_net                             0.0
# adjustable_steering                              0.0
# tachometer                                       0.0
# leather_steering_wheel                           0.0
# outside_temperature_display                      0.0
# height_adjustable_driver_seat                    0.0
# power_adjustable_exterior_rear_view_mirror       0.0
# electric_folding_rear_view_mirror                0.0
# rear_window_wiper                                0.0
# rear_window_washer                               0.0
# rear_window_defogger                             0.0
# alloy_wheels                                     0.0
# integrated_antenna                               0.0
# outside_rear_view_mirror_turn_indicators         0.0
# roof_rail                                        0.0
# power_door_locks                                 0.0
# driver_air_bag                                   0.0
# passenger_air_bag                                0.0
# seat_belt_warning                                0.0
# keyless_entry                                    0.0
# engine_check_warning                             0.0
# crash_sensor                                     0.0
# ebd                                              0.0
# follow_me_home_headlamps                         0.0
# rear_camera                                      0.0
# speed_sensing_auto_door_lock                     0.0
# pretensioners_and_force_limiter_seatbelts        0.0
# impact_sensing_auto_door_lock                    0.0
# no_of_airbags                                    0.0
# radio                                            0.0
# speakers_front                                   0.0
# speakers_rear                                    0.0
# integrated2din_audio                             0.0
# usb_auxiliary_input                              0.0
# bluetooth                                        0.0
# touch_screen                                     0.0
# number_of_speaker                                0.0
# glove_box_cooling                                0.0
# driving_experience_control_eco                   0.0
# tinted_glass                                     0.0
# rear_spoiler                                     0.0
# chrome_garnish                                   0.0
# vehicle_stability_control_system                 0.0
# rear_reading_lamp                                0.0
# rear_seat_centre_arm_rest                        0.0
# cup_holders_rear                                 0.0
# rear_acvents                                     0.0
# air_quality_control                              0.0
# height_adjustable_front_seat_belts               0.0
# cruise_control                                   0.0
# voice_control                                    0.0
# audio_system_remote_control                      0.0
# leather_seats                                    0.0
# fog_lights_rear                                  0.0
# traction_control                                 0.0
# seat_lumbar_support                              0.0
# battery_saver                                    0.0
# lane_change_indicator                            0.0
# sun_roof                                         0.0
# automatic_driving_lights                         0.0
# anti_theft_alarm                                 0.0
# automatic_head_lamps                             0.0
# isofix_child_seat_mounts                         0.0
# hill_assist                                      0.0
# tailgate_ajar                                    0.0
# brake_assist                                     0.0
# steering_wheel_gearshift_paddles                 0.0
# ledtaillights                                    0.0
# cigarette_lighter                                0.0
# rain_sensing_wiper                               0.0
# drive_modes                                      0.0
# active_noise_cancellation                        0.0
# adjustable_headrest                              0.0
# hands_free_tailgate                              0.0
# dual_tone_dashboard                              0.0
# leather_wrap_gear_shift_selector                 0.0
# dual_tone_body_colour                            0.0
# leddrls                                          0.0
# ledheadlights                                    0.0
# cornering_headlamps                              0.0
# cornering_foglamps                               0.0
# side_air_bag_front                               0.0
# side_air_bag_rear                                0.0
# tyre_pressure_monitor                            0.0
# clutch_lock                                      0.0
# anti_pinch_power_windows                         0.0
# knee_airbags                                     0.0
# apple_car_play                                   0.0
# android_auto                                     0.0
# mirror_link                                      0.0
# wireless_phone_charging                          0.0
# compass                                          0.0
# moon_roof                                        0.0
# projector_headlamps                              0.0
# speed_alert                                      0.0
# eletronic_stability_control                      0.0
# touch_screen_size                                0.0
# xenon_headlamps                                  0.0
# cd_changer                                       0.0
# power_boot                                       0.0
# rear_folding_table                               0.0
# smoke_headlamps                                  0.0
# dvd_player                                       0.0
# internal_storage                                 0.0
# rear_entertainment_system                        0.0
# remote_engine_start_stop                         0.0
# ventilated_seats                                 0.0
# ledfog_lamps                                     0.0
# view360camera                                    0.0
# geo_fence_alert                                  0.0
# steering_mounted_tripmeter                       0.0
# remote_climate_control                           0.0
# remote_horn_light_control                        0.0
# heated_wing_mirror                               0.0
# side_stepper                                     0.0
# blind_spot_monitor                               0.0
# hill_descent_control                             0.0
# heads_up_display                                 0.0
# sos_emergency_assistance                         0.0
# cassette_player                                  0.0
# find_my_car_location                             0.0
# wifi_connectivity                                0.0
# headlamp_washers                                 0.0
# real_time_vehicle_tracking                       0.0
# roof_carrier                                     0.0
# smart_key_band                                   0.0
# lane_watch_camera                                0.0
# removable_convertible_top                        0.0
# power_folding3rd_row_seat                        0.0
# mileage                                          0.0
# max_power                                        0.0
# torque                                           0.0
# color                                            0.0
# engine_type                                      0.0
# displacement                                     0.0
# max_torque                                       0.0
# no_of_cylinder                                   0.0
# values_per_cylinder                              0.0
# value_configuration                              0.0
# fuel_suppy_system                                0.0
# turbo_charger                                    0.0
# super_charger                                    0.0
# length                                           0.0
# width                                            0.0
# height                                           0.0
# wheel_base                                       0.0
# front_tread                                      0.0
# rear_tread                                       0.0
# kerb_weight                                      0.0
# gross_weight                                     0.0
# gear_box                                         0.0
# drive_type                                       0.0
# steering_type                                    0.0
# turning_radius                                   0.0
# front_brake_type                                 0.0
# rear_brake_type                                  0.0
# top_speed                                        0.0
# tyre_type                                        0.0
# no_door_numbers                                  0.0
# cargo_volumn                                     0.0
# wheel_size                                       0.0
# ground_clearance_unladen                         0.0
# car_links                                        0.0
# city                                             0.0
# dtype: float64

# %%
df_edit.to_excel('All_imputed_data.xlsx', index=False)
