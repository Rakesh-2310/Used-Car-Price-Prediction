# %%
import pandas as pd
import numpy as np

# %%
def MMM_imputation(df, column_name, imputation_method):
    """
    Impute missing values in a specified column using the chosen method.

    Parameters:
    - df: DataFrame to be processed.
    - column_name: Name of the column to impute.
    - imputation_method: Method of imputation ('mode', 'median', or 'mean').

    Returns:
    - None: The function modifies the DataFrame in place.
    """
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")

    if imputation_method == "mode":
        mode_value = df[column_name].mode()
        if mode_value.empty:
            raise ValueError(f"Mode could not be computed for column '{column_name}'.")
        df[column_name].fillna(mode_value[0], inplace=True)
    elif imputation_method == "median":
        if not pd.api.types.is_numeric_dtype(df[column_name]):
            raise ValueError(f"Median imputation is not applicable for non-numeric column '{column_name}'.")
        median_value = df[column_name].median()
        df[column_name].fillna(median_value, inplace=True)
    elif imputation_method == "mean":
        if not pd.api.types.is_numeric_dtype(df[column_name]):
            raise ValueError(f"Mean imputation is not applicable for non-numeric column '{column_name}'.")
        mean_value = df[column_name].mean()
        df[column_name].fillna(mean_value, inplace=True)
    else:
        raise ValueError("Imputation method must be 'mode', 'median', or 'mean'.")

# %%
df = pd.read_excel("combined_data.xlsx")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df_edit = df.copy()
for i in df_edit.columns:
    print(f"{i}:unique count -> {df_edit[i].nunique()}, <> unique percentage -> {(df_edit[i].nunique()/len(df_edit))*100}% <>, null value percentage -> {(df_edit[i].isnull().sum()/len(df_edit))*100}%, Data types -> {df_edit[i].dtypes}")
    print("-------------------------------------------------------------------------------------")
# Out:
# it:unique count -> 1, <> unique percentage -> 0.01194885888397658% <>, null value percentage -> 0.0%, Data types -> int64
# -------------------------------------------------------------------------------------
# ft:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# bt:unique count -> 10, <> unique percentage -> 0.1194885888397658% <>, null value percentage -> 0.04779543553590632%, Data types -> object
# -------------------------------------------------------------------------------------
# km:unique count -> 4090, <> unique percentage -> 48.87083283546421% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# transmission:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# ownerNo:unique count -> 6, <> unique percentage -> 0.07169315330385947% <>, null value percentage -> 0.0%, Data types -> int64
# -------------------------------------------------------------------------------------
# owner:unique count -> 6, <> unique percentage -> 0.07169315330385947% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# oem:unique count -> 33, <> unique percentage -> 0.39431234317122715% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# model:unique count -> 315, <> unique percentage -> 3.7638905484526224% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# modelYear:unique count -> 29, <> unique percentage -> 0.34651690763532084% <>, null value percentage -> 0.0%, Data types -> int64
# -------------------------------------------------------------------------------------
# centralVariantId:unique count -> 2713, <> unique percentage -> 32.417254152228466% <>, null value percentage -> 0.0%, Data types -> int64
# -------------------------------------------------------------------------------------
# variantName:unique count -> 2157, <> unique percentage -> 25.773688612737484% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# price:unique count -> 1400, <> unique percentage -> 16.728402437567212% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# priceActual:unique count -> 721, <> unique percentage -> 8.615127255347115% <>, null value percentage -> 80.04540566375911%, Data types -> object
# -------------------------------------------------------------------------------------
# priceSaving:unique count -> 0, <> unique percentage -> 0.0% <>, null value percentage -> 100.0%, Data types -> float64
# -------------------------------------------------------------------------------------
# priceFixedText:unique count -> 0, <> unique percentage -> 0.0% <>, null value percentage -> 100.0%, Data types -> float64
# -------------------------------------------------------------------------------------
# trendingText.imgUrl:unique count -> 1, <> unique percentage -> 0.01194885888397658% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# trendingText.heading:unique count -> 1, <> unique percentage -> 0.01194885888397658% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# trendingText.desc:unique count -> 1, <> unique percentage -> 0.01194885888397658% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# Registration Year:unique count -> 233, <> unique percentage -> 2.7840841199665434% <>, null value percentage -> 0.6213406619667822%, Data types -> object
# -------------------------------------------------------------------------------------
# Insurance Validity:unique count -> 7, <> unique percentage -> 0.08364201218783607% <>, null value percentage -> 0.04779543553590632%, Data types -> object
# -------------------------------------------------------------------------------------
# Fuel Type:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# Seats:unique count -> 8, <> unique percentage -> 0.09559087107181263% <>, null value percentage -> 0.07169315330385947%, Data types -> object
# -------------------------------------------------------------------------------------
# Kms Driven:unique count -> 4089, <> unique percentage -> 48.85888397658024% <>, null value percentage -> 0.02389771776795316%, Data types -> object
# -------------------------------------------------------------------------------------
# RTO:unique count -> 464, <> unique percentage -> 5.544270522165133% <>, null value percentage -> 10.682279842275062%, Data types -> object
# -------------------------------------------------------------------------------------
# Ownership:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 0.38236348428725053%, Data types -> object
# -------------------------------------------------------------------------------------
# Engine Displacement:unique count -> 150, <> unique percentage -> 1.7923288325964868% <>, null value percentage -> 0.04779543553590632%, Data types -> object
# -------------------------------------------------------------------------------------
# Transmission:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# Year of Manufacture:unique count -> 22, <> unique percentage -> 0.26287489544748477% <>, null value percentage -> 0.2389771776795316%, Data types -> float64
# -------------------------------------------------------------------------------------
# Power Steering:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Windows Front:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Air Conditioner:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Heater:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Adjustable Head Lights:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Manually Adjustable Exterior Rear View Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Centeral Locking:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Child Safety Locks:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Windows Rear:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Remote Trunk Opener:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Remote Fuel Lid Opener:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Low Fuel Warning Light:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Accessory Power Outlet:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Vanity Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Seat Headrest:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cup Holders Front:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Digital Odometer:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Electronic Multi Tripmeter:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Fabric Upholstery:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Glove Compartment:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Digital Clock:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Wheel Covers:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Antenna:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Chrome Grille:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Day Night Rear View Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Passenger Side Rear View Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Halogen Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Seat Belts:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Door Ajar Warning:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Side Impact Beams:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Front Impact Beams:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Adjustable Seats:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Centrally Mounted Fuel Tank:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Engine Immobilizer:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Anti Theft Device:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Fog Lights Front:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Anti Lock Braking System:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cd Player:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Trunk Light:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Multifunction Steering Wheel:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Navigation System:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Smart Access Card Entry:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Engine Start Stop Button:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Gear Shift Indicator:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Luggage Hook And Net:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Adjustable Steering:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Tachometer:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Leather Steering Wheel:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Outside Temperature Display:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Height Adjustable Driver Seat:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Adjustable Exterior Rear View Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Electric Folding Rear View Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Window Wiper:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Window Washer:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Window Defogger:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Alloy Wheels:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Integrated Antenna:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Outside Rear View Mirror Turn Indicators:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Roof Rail:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Door Locks:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Driver Air Bag:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Passenger Air Bag:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Seat Belt Warning:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Keyless Entry:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Engine Check Warning:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Crash Sensor:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Ebd:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Follow Me Home Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Camera:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Speed Sensing Auto Door Lock:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Pretensioners And Force Limiter Seatbelts:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Impact Sensing Auto Door Lock:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# No Of Airbags:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Radio:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Speakers Front:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Speakers Rear:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Integrated2Din Audio:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Usb Auxiliary Input:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Bluetooth:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Touch Screen:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Number Of Speaker:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Glove Box Cooling:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Driving Experience Control Eco:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Tinted Glass:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Spoiler:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Chrome Garnish:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Vehicle Stability Control System:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Reading Lamp:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Seat Centre Arm Rest:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cup Holders Rear:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear ACVents:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Air Quality Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Height Adjustable Front Seat Belts:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cruise Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Voice Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Audio System Remote Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Leather Seats:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Fog Lights Rear:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Traction Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Seat Lumbar Support:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Battery Saver:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Lane Change Indicator:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Sun Roof:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Automatic Driving Lights:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Anti Theft Alarm:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Automatic Head Lamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Isofix Child Seat Mounts:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Hill Assist:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Tailgate Ajar:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Brake Assist:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Steering Wheel Gearshift Paddles:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# LEDTaillights:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cigarette Lighter:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rain Sensing Wiper:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Drive Modes:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Active Noise Cancellation:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Adjustable Headrest:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Hands Free Tailgate:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Dual Tone Dashboard:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Leather Wrap Gear Shift Selector:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Dual Tone Body Colour:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# LEDDRLs:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# LEDHeadlights:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cornering Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cornering Foglamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Side Air Bag Front:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Side Air Bag Rear:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Tyre Pressure Monitor:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Clutch Lock:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Anti Pinch Power Windows:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Knee Airbags:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Apple Car Play:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Android Auto:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Mirror Link:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Wireless Phone Charging:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Compass:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Moon Roof:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Projector Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Speed Alert:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Eletronic Stability Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Touch Screen Size:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Xenon Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cd Changer:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Boot:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Folding Table:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Smoke Headlamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Dvd Player:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Internal Storage:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Rear Entertainment System:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Remote Engine Start Stop:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Ventilated Seats:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# LEDFog Lamps:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# View360Camera:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Geo Fence Alert:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Steering Mounted Tripmeter:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Remote Climate Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Remote Horn Light Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Heated Wing Mirror:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Side Stepper:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Blind Spot Monitor:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Hill Descent Control:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Heads Up Display:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Sos Emergency Assistance:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Cassette Player:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Find My Car Location:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Wifi Connectivity:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Headlamp Washers:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Real Time Vehicle Tracking:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Roof Carrier:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Smart Key Band:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Lane Watch Camera:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Removable Convertible Top:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Power Folding3rd Row Seat:unique count -> 2, <> unique percentage -> 0.02389771776795316% <>, null value percentage -> 0.0%, Data types -> bool
# -------------------------------------------------------------------------------------
# Mileage:unique count -> 522, <> unique percentage -> 6.237304337435775% <>, null value percentage -> 3.429322499701278%, Data types -> object
# -------------------------------------------------------------------------------------
# Engine:unique count -> 150, <> unique percentage -> 1.7923288325964868% <>, null value percentage -> 0.04779543553590632%, Data types -> object
# -------------------------------------------------------------------------------------
# Max Power:unique count -> 760, <> unique percentage -> 9.081132751822201% <>, null value percentage -> 0.7169315330385948%, Data types -> object
# -------------------------------------------------------------------------------------
# Torque:unique count -> 366, <> unique percentage -> 4.373282351535428% <>, null value percentage -> 0.7169315330385948%, Data types -> object
# -------------------------------------------------------------------------------------
# Seats.1:unique count -> 8, <> unique percentage -> 0.09559087107181263% <>, null value percentage -> 0.07169315330385947%, Data types -> float64
# -------------------------------------------------------------------------------------
# Color:unique count -> 153, <> unique percentage -> 1.8281754092484166% <>, null value percentage -> 0.03584657665192974%, Data types -> object
# -------------------------------------------------------------------------------------
# Engine Type:unique count -> 508, <> unique percentage -> 6.070020313060103% <>, null value percentage -> 3.524913370773091%, Data types -> object
# -------------------------------------------------------------------------------------
# Displacement:unique count -> 150, <> unique percentage -> 1.7923288325964868% <>, null value percentage -> 0.04779543553590632%, Data types -> float64
# -------------------------------------------------------------------------------------
# Max Torque:unique count -> 617, <> unique percentage -> 7.37244593141355% <>, null value percentage -> 0.7169315330385948%, Data types -> object
# -------------------------------------------------------------------------------------
# No of Cylinder:unique count -> 8, <> unique percentage -> 0.09559087107181263% <>, null value percentage -> 0.37041462540327397%, Data types -> float64
# -------------------------------------------------------------------------------------
# Values per Cylinder:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 0.6093918030828056%, Data types -> float64
# -------------------------------------------------------------------------------------
# Value Configuration:unique count -> 13, <> unique percentage -> 0.15533516549169554% <>, null value percentage -> 26.4786712868921%, Data types -> object
# -------------------------------------------------------------------------------------
# Fuel Suppy System:unique count -> 81, <> unique percentage -> 0.9678575696021031% <>, null value percentage -> 20.635679292627554%, Data types -> object
# -------------------------------------------------------------------------------------
# BoreX Stroke:unique count -> 171, <> unique percentage -> 2.043254869159995% <>, null value percentage -> 71.26299438403633%, Data types -> object
# -------------------------------------------------------------------------------------
# Compression Ratio:unique count -> 79, <> unique percentage -> 0.9439598518341499% <>, null value percentage -> 77.35691241486438%, Data types -> object
# -------------------------------------------------------------------------------------
# Turbo Charger:unique count -> 9, <> unique percentage -> 0.10753972995578923% <>, null value percentage -> 12.426813239335644%, Data types -> object
# -------------------------------------------------------------------------------------
# Super Charger:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 23.443661130362052%, Data types -> object
# -------------------------------------------------------------------------------------
# Length:unique count -> 419, <> unique percentage -> 5.0065718723861865% <>, null value percentage -> 0.9439598518341499%, Data types -> object
# -------------------------------------------------------------------------------------
# Width:unique count -> 318, <> unique percentage -> 3.799737125104553% <>, null value percentage -> 0.9917552873700561%, Data types -> object
# -------------------------------------------------------------------------------------
# Height:unique count -> 354, <> unique percentage -> 4.229896044927709% <>, null value percentage -> 0.9439598518341499%, Data types -> object
# -------------------------------------------------------------------------------------
# Wheel Base:unique count -> 273, <> unique percentage -> 3.2620384753256064% <>, null value percentage -> 1.9476639980881825%, Data types -> object
# -------------------------------------------------------------------------------------
# Front Tread:unique count -> 178, <> unique percentage -> 2.126896881347831% <>, null value percentage -> 42.514039909188675%, Data types -> object
# -------------------------------------------------------------------------------------
# Rear Tread:unique count -> 200, <> unique percentage -> 2.389771776795316% <>, null value percentage -> 42.65742621579639%, Data types -> object
# -------------------------------------------------------------------------------------
# Kerb Weight:unique count -> 901, <> unique percentage -> 10.765921854462897% <>, null value percentage -> 0.7049826741546182%, Data types -> object
# -------------------------------------------------------------------------------------
# Gross Weight:unique count -> 330, <> unique percentage -> 3.943123431712271% <>, null value percentage -> 54.25976819213765%, Data types -> object
# -------------------------------------------------------------------------------------
# Gear Box:unique count -> 118, <> unique percentage -> 1.4099653483092365% <>, null value percentage -> 1.2665790417015175%, Data types -> object
# -------------------------------------------------------------------------------------
# Drive Type:unique count -> 20, <> unique percentage -> 0.2389771776795316% <>, null value percentage -> 18.640219859003466%, Data types -> object
# -------------------------------------------------------------------------------------
# Seating Capacity:unique count -> 8, <> unique percentage -> 0.09559087107181263% <>, null value percentage -> 0.07169315330385947%, Data types -> float64
# -------------------------------------------------------------------------------------
# Steering Type:unique count -> 9, <> unique percentage -> 0.10753972995578923% <>, null value percentage -> 3.046959015414028%, Data types -> object
# -------------------------------------------------------------------------------------
# Turning Radius:unique count -> 196, <> unique percentage -> 2.34197634125941% <>, null value percentage -> 19.11817421436253%, Data types -> object
# -------------------------------------------------------------------------------------
# Front Brake Type:unique count -> 34, <> unique percentage -> 0.4062612020552038% <>, null value percentage -> 1.1470904528617516%, Data types -> object
# -------------------------------------------------------------------------------------
# Rear Brake Type:unique count -> 35, <> unique percentage -> 0.4182100609391803% <>, null value percentage -> 1.1470904528617516%, Data types -> object
# -------------------------------------------------------------------------------------
# Top Speed:unique count -> 305, <> unique percentage -> 3.644401959612857% <>, null value percentage -> 44.95160712151989%, Data types -> object
# -------------------------------------------------------------------------------------
# Acceleration:unique count -> 332, <> unique percentage -> 3.9670211494802246% <>, null value percentage -> 41.96439240052575%, Data types -> object
# -------------------------------------------------------------------------------------
# Tyre Type:unique count -> 34, <> unique percentage -> 0.4062612020552038% <>, null value percentage -> 0.9200621340661966%, Data types -> object
# -------------------------------------------------------------------------------------
# No Door Numbers:unique count -> 5, <> unique percentage -> 0.0597442944198829% <>, null value percentage -> 0.13143744772374238%, Data types -> float64
# -------------------------------------------------------------------------------------
# Cargo Volumn:unique count -> 321, <> unique percentage -> 3.835583701756482% <>, null value percentage -> 19.03453220217469%, Data types -> object
# -------------------------------------------------------------------------------------
# Wheel Size:unique count -> 17, <> unique percentage -> 0.2031306010276019% <>, null value percentage -> 35.64344605090214%, Data types -> object
# -------------------------------------------------------------------------------------
# Alloy Wheel Size:unique count -> 17, <> unique percentage -> 0.2031306010276019% <>, null value percentage -> 35.64344605090214%, Data types -> object
# -------------------------------------------------------------------------------------
# Ground Clearance Unladen:unique count -> 26, <> unique percentage -> 0.3106703309833911% <>, null value percentage -> 93.84633767475205%, Data types -> object
# -------------------------------------------------------------------------------------
# car_links:unique count -> 8361, <> unique percentage -> 99.90440912892818% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------
# city:unique count -> 6, <> unique percentage -> 0.07169315330385947% <>, null value percentage -> 0.0%, Data types -> object
# -------------------------------------------------------------------------------------

# %%
"""
Drop columns based on below category due to lot of columns:- 
1) Duplicate columns - Transmission,Fuel Type,kms_driven,ownership,displacement,engine,seats.1,seating_capacity,wheel_size
2) 100% single value in entire column - it,trendingText.imgUrl,trendingText.heading,trendingText.desc,
3) Unnecessary columns - car_links,
4) Domain knowledge if there is some null values - max_torque, Value Configuration,Fuel Suppy System, BoreX Stroke, Compression Ratio, Front Tread, Rear Tread, Acceleration         
5) Null value over 80% - priceActual, priceSaving, priceFixedText
6) Spec and feature reduced due to high features:- 'power_folding3rd_row_seat','removable_convertible_top','smart_key_band','real_time_vehicle_tracking','headlamp_washers','wifi_connectivity','find_my_car_location','cassette_player','sos_emergency_assistance','heads_up_display','side_stepper','heated_wing_mirror','remote_horn_light_control','geo_fence_alert','remote_engine_start_stop','internal_storage','rear_folding_table','cd_changer','xenon_headlamps','touch_screen_size','compass','mirror_link','leddrls','active_noise_cancellation','drive_modes','cigarette_lighter','ledtaillights','steering_wheel_gearshift_paddles','tailgate_ajar','isofix_child_seat_mounts','seat_lumbar_support','audio_system_remote_control','cup_holders_rear','chrome_garnish','tinted_glass','glove_box_cooling','number_of_speaker','no_of_airbags','follow_me_home_headlamps','ebd','roof_rail','alloy_wheels','luggage_hook_and_net','smart_access_card_entry','trunk_light','centrally_mounted_fuel_tank','chrome_grille','wheel_covers','fabric_upholstery','cup_holders_front','vanity_mirror'

df_edit.drop(['it','priceActual','priceSaving','priceFixedText','trendingText.imgUrl','trendingText.heading','trendingText.desc','Fuel Type','Kms Driven','Transmission','Engine','Displacement','Max Torque','Value Configuration','Fuel Suppy System','BoreX Stroke','Compression Ratio','Front Tread','Rear Tread','Seats.1','car_links','Seating Capacity','Acceleration','Wheel Size','Ownership'],axis=1,inplace=True)
"""

df_edit.drop([
    # Duplicate columns
    'Transmission', 'Fuel Type', 'Kms Driven', 'Ownership', 'Displacement', 'Engine', 'Seats.1', 'Seating Capacity', 'Wheel Size',
    
    # Columns with 100% single value
    'it', 'trendingText.imgUrl', 'trendingText.heading', 'trendingText.desc',
    
    # Unnecessary columns
    'car_links',
    
    # Domain knowledge for nulls and for customer usability
    'Max Torque', 'Value Configuration', 'Fuel Suppy System', 'BoreX Stroke', 'Compression Ratio', 'Front Tread', 'Rear Tread', 'Acceleration',
    
    # Columns with >80% null values
    'priceActual', 'priceSaving', 'priceFixedText'
], axis=1, inplace=True)

df_edit.columns = df_edit.columns.str.lower().str.replace(" ", "_")

df_edit.drop(['power_folding3rd_row_seat','removable_convertible_top','smart_key_band','real_time_vehicle_tracking','headlamp_washers','wifi_connectivity','find_my_car_location','cassette_player','sos_emergency_assistance','heads_up_display','side_stepper','heated_wing_mirror','remote_horn_light_control','geo_fence_alert','remote_engine_start_stop','internal_storage','rear_folding_table','cd_changer','xenon_headlamps','touch_screen_size','compass','mirror_link','leddrls','active_noise_cancellation','drive_modes','cigarette_lighter','ledtaillights','steering_wheel_gearshift_paddles','tailgate_ajar','isofix_child_seat_mounts','seat_lumbar_support','audio_system_remote_control','cup_holders_rear','chrome_garnish','tinted_glass','glove_box_cooling','number_of_speaker','no_of_airbags','follow_me_home_headlamps','ebd','roof_rail','alloy_wheels','luggage_hook_and_net','smart_access_card_entry','trunk_light','centrally_mounted_fuel_tank','chrome_grille','wheel_covers','fabric_upholstery','cup_holders_front','vanity_mirror','remote_climate_control','dual_tone_dashboard','leather_wrap_gear_shift_selector','dual_tone_body_colour','rear_seat_centre_arm_rest','rear_spoiler','keyless_entry','digital_clock','leather_steering_wheel'], axis=1, inplace=True)

# %%
# Creating grouped columns in the dataframe `df_edit`

# Stability Features 
df_edit['stability_features'] = df_edit['eletronic_stability_control'] | df_edit['vehicle_stability_control_system'] | df_edit['traction_control']

# Blind Spot Assistance 
df_edit['blind_spot_assistance'] = df_edit['lane_watch_camera'] | df_edit['blind_spot_monitor']

# Indicators
df_edit['indicators'] = df_edit['outside_rear_view_mirror_turn_indicators'] | df_edit['lane_change_indicator']

# Folding Rear View Mirror
df_edit['Adjustable_rear_view_mirror'] = df_edit['electric_folding_rear_view_mirror'] | df_edit['manually_adjustable_exterior_rear_view_mirror'] | df_edit['power_adjustable_exterior_rear_view_mirror']

# Rear Window Wiper
df_edit['rear_window_wiper'] = df_edit['rear_window_wiper'] | df_edit['rear_window_washer']

# Fog Lamps
df_edit['fog_lamps'] = df_edit['fog_lights_front'] | df_edit['fog_lights_rear'] | df_edit['ledfog_lamps'] | df_edit['cornering_foglamps'] | df_edit['smoke_headlamps']

# Automatic Lamps/Lights 
df_edit['automatic_lamps'] = df_edit['automatic_driving_lights'] | df_edit['automatic_head_lamps']

# Meters 
df_edit['meters'] = df_edit['tachometer'] | df_edit['digital_odometer'] | df_edit['electronic_multi_tripmeter']

#Boot opening
df_edit['power_boot'] = df_edit['hands_free_tailgate'] | df_edit['power_boot']

#roof on car
df_edit['car_roof'] = df_edit['moon_roof'] | df_edit['sun_roof']

#Speakers
df_edit['speakers'] = df_edit['speakers_front'] | df_edit['speakers_rear']

#antenna
df_edit['antenna'] = df_edit['integrated_antenna'] | df_edit['power_antenna']

#player
df_edit['player'] = df_edit['cd_player'] | df_edit['dvd_player']

#Smartphone integrate (android auto and apple carplay)
df_edit['smartphone_integration'] = df_edit['android_auto'] | df_edit['apple_car_play']

#Anti theft device
df_edit['anti_theft_device'] = df_edit['anti_theft_device'] | df_edit['engine_immobilizer']

#adjustable seats
df_edit['adjustable_seats'] = df_edit['adjustable_seats'] | df_edit['height_adjustable_driver_seat']

#Smartphone integrate (android auto and apple carplay)
df_edit['impact_beams'] = df_edit['front_impact_beams'] | df_edit['side_impact_beams']

# %%
# Dropping original columns after grouping in df_edit

# Columns to drop for each group
stability_features_cols = ['eletronic_stability_control', 'vehicle_stability_control_system', 'traction_control']
blind_spot_assistance_cols = ['lane_watch_camera', 'blind_spot_monitor']
indicators_cols = ['outside_rear_view_mirror_turn_indicators', 'lane_change_indicator']
folding_rear_view_mirror_cols = ['electric_folding_rear_view_mirror', 'manually_adjustable_exterior_rear_view_mirror','power_adjustable_exterior_rear_view_mirror']
rear_window_wiper_cols = ['rear_window_wiper', 'rear_window_washer']
fog_lamps_cols = ['fog_lights_front', 'fog_lights_rear', 'ledfog_lamps', 'cornering_foglamps','smoke_headlamps']
automatic_lamps_cols = ['automatic_driving_lights', 'automatic_head_lamps']
meters_cols = ['tachometer', 'digital_odometer', 'electronic_multi_tripmeter']
power_boot_cols = ['hands_free_tailgate', 'power_boot']
car_roof_cols = ['moon_roof', 'sun_roof']
speakers_cols = ['speakers_front', 'speakers_rear']
antenna = ['integrated_antenna', 'power_antenna']
player = ['cd_player', 'dvd_player']
smartphone_integration = ['android_auto', 'apple_car_play']
anti_theft_device = ['anti_theft_device', 'engine_immobilizer']
adjustable_seats = ['adjustable_seats', 'height_adjustable_driver_seat']
impact_beams = ['front_impact_beams', 'side_impact_beams']

# Dropping the columns
df_edit.drop(columns=(stability_features_cols + blind_spot_assistance_cols + indicators_cols +
                      folding_rear_view_mirror_cols + rear_window_wiper_cols + fog_lamps_cols +
                      automatic_lamps_cols + meters_cols+power_boot_cols+car_roof_cols+speakers_cols+antenna+player+
                     smartphone_integration+anti_theft_device+adjustable_seats+impact_beams), inplace=True)

# %%
df_edit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Columns: 132 entries, ft to impact_beams
# dtypes: bool(86), float64(4), int64(3), object(39)
# memory usage: 3.6+ MB

# %%
df_edit.head(1)
# Out:
#        ft         bt        km transmission  ownerno      owner     oem  \
# 0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner  Maruti
#
#             model  modelyear  centralvariantid variantname     price  \
# 0  Maruti Celerio       2015              3979         VXI  ₹ 4 Lakh
#
#   registration_year     insurance_validity    seats   rto engine_displacement  \
# 0              2015  Third Party insurance  5 Seats  KA51              998 cc
#
#    year_of_manufacture  power_steering  power_windows_front  air_conditioner  \
# 0               2015.0            True                 True             True
#
#    heater  adjustable_head_lights  centeral_locking  child_safety_locks  \
# 0    True                    True              True                True
#
#    power_windows_rear  remote_trunk_opener  remote_fuel_lid_opener  \
# 0                True                 True                    True
#
#    low_fuel_warning_light  accessory_power_outlet  rear_seat_headrest  \
# 0                    True                    True                True
#
#    glove_compartment  day_night_rear_view_mirror  \
# 0               True                        True
#
#    passenger_side_rear_view_mirror  halogen_headlamps  rear_seat_belts  \
# 0                             True               True             True
#
#    door_ajar_warning  anti_lock_braking_system  multifunction_steering_wheel  \
# 0               True                     False                         False
#
#    navigation_system  engine_start_stop_button  gear_shift_indicator  \
# 0              False                     False                 False
#
#    adjustable_steering  outside_temperature_display  rear_window_defogger  \
# 0                False                        False                 False
#
#    power_door_locks  driver_air_bag  passenger_air_bag  seat_belt_warning  \
# 0             False           False              False              False
#
#    engine_check_warning  crash_sensor  rear_camera  \
# 0                 False         False        False
#
#    speed_sensing_auto_door_lock  pretensioners_and_force_limiter_seatbelts  \
# 0                         False                                      False
#
#    impact_sensing_auto_door_lock  radio  integrated2din_audio  \
# 0                          False  False                 False
#
#    usb_auxiliary_input  bluetooth  touch_screen  \
# 0                False      False         False
#
#    driving_experience_control_eco  rear_reading_lamp  rear_acvents  \
# 0                           False              False         False
#
#    air_quality_control  height_adjustable_front_seat_belts  cruise_control  \
# 0                False                               False           False
#
#    voice_control  leather_seats  battery_saver  anti_theft_alarm  hill_assist  \
# 0          False          False          False             False        False
#
#    brake_assist  rain_sensing_wiper  adjustable_headrest  ledheadlights  \
# 0         False               False                False          False
#
#    cornering_headlamps  side_air_bag_front  side_air_bag_rear  \
# 0                False               False              False
#
#    tyre_pressure_monitor  clutch_lock  anti_pinch_power_windows  knee_airbags  \
# 0                  False        False                     False         False
#
#    wireless_phone_charging  projector_headlamps  speed_alert  \
# 0                    False                False        False
#
#    rear_entertainment_system  ventilated_seats  view360camera  \
# 0                      False             False          False
#
#    steering_mounted_tripmeter  hill_descent_control  roof_carrier    mileage  \
# 0                       False                 False         False  23.1 kmpl
#
#           max_power torque  color  engine_type  no_of_cylinder  \
# 0  67.04bhp@6000rpm   90Nm  White  K10B Engine             3.0
#
#    values_per_cylinder turbo_charger super_charger  length   width  height  \
# 0                  4.0            No            No  3715mm  1635mm  1565mm
#
#   wheel_base kerb_weight gross_weight  gear_box drive_type steering_type  \
# 0     2425mm       835kg       1250kg  5 Speed         FWD         Power
#
#   turning_radius front_brake_type rear_brake_type top_speed         tyre_type  \
# 0     4.7 metres  Ventilated Disc            Drum  150 Kmph  Tubeless, Radial
#
#    no_door_numbers cargo_volumn alloy_wheel_size ground_clearance_unladen  \
# 0              5.0   235-litres              NaN                      NaN
#
#         city  stability_features  blind_spot_assistance  indicators  \
# 0  bangalore               False                  False       False
#
#    Adjustable_rear_view_mirror  fog_lamps  automatic_lamps  meters  car_roof  \
# 0                         True      False            False    True     False
#
#    speakers  antenna  player  smartphone_integration  impact_beams
# 0     False     True   False                   False          True

# %%
df_edit['ground_clearance_unladen'].unique()
# Out:
# array([nan, '190mm', '205', '209 mm', '155mm', '120mm', '192mm', '210mm',
#        '160', '110mm', '185mm', '178mm', '116mm', '145mm', '200mm', '170',
#        '184mm', '180mm', '140mm', '170mm', '210 mm', '91mm', '180',
#        '175mm', '205mm', '165', '156mm'], dtype=object)

# %%
# Remove spaces and 'mm' in one line, then convert to numeric
df_edit['ground_clearance_unladen'] = (
    df_edit['ground_clearance_unladen']
    .str.replace(" ", "", regex=False)
    .str.replace("mm", "", regex=False)
    .pipe(pd.to_numeric, errors='coerce')
)

# Display unique values after replacement
print(df_edit['ground_clearance_unladen'].unique())

# Dictionary with average ground clearance values for each body type
ground_clearance_values = {
    "Hatchback": 165, "SUV": 210, "Sedan": 150, "MUV": 190, "Coupe": 130,
    "Minivans": 160, "Pickup Trucks": 220, "Convertibles": 130,
    "Hybrids": 150, "Wagon": 160
}

# Function to replace NaN values with average ground clearance based on body type
def replace_nan(row, values_dict):
    return values_dict.get(row['bt'], row['ground_clearance_unladen']) if pd.isnull(row['ground_clearance_unladen']) and pd.notnull(row['bt']) else row['ground_clearance_unladen']

# Apply the function to fill NaN values based on 'bt' column
df_edit['ground_clearance_unladen'] = df_edit.apply(lambda row: replace_nan(row, ground_clearance_values), axis=1)
# Out:
# [ nan 190. 205. 209. 155. 120. 192. 210. 160. 110. 185. 178. 116. 145.
#  200. 170. 184. 180. 140.  91. 175. 165. 156.]

# %%
df_edit['gross_weight'].unique()
# Out:
# array(['1250kg', '1660Kg', nan, '1670kg', '1530Kg', '1340kg', '2450kg',
#        '2160kg', '1335', '2730kg', '2055kg', '1350kg', '1730 Kg',
#        '2165 Kg', '2510 kg', '1640kg', '2240kg', '1185kg', '2510kg',
#        '1655kg', '1140kg', '2995kg', '1500kg', '1260', '1760kg', '1405Kg',
#        '1585kg', '1860kg', '1430kg', '1750Kg', '2060kg', '1360kg',
#        '1720kg', '1580kg', '1965kg', '2124kg', '1740kg', '2430kg',
#        '1985kg', '2610Kg', '2505 kg', '1787kg', '1405kg', '1813kg',
#        '1455kg', '1580 kg', '1620kg', '1915kg', '2220kg', '1680kg',
#        '1758kg', '1705Kg', '1845kg', '1482kg', '1436kg', '2140kg',
#        '1690Kg', '2280kg', '1520', '1505kg', '2300kg', '1490kg', '2320kg',
#        '1530', '1520 Kg', '1890kg', '1660 kg', '1650', '1315Kg', '1980kg',
#        '1315kg', '1525kg', '1210kg', '2135kg', '1415kg', '1510kg',
#        '1950kg', '1315kgs', '2830', '1757kg', '2,010 kg', '1764kg',
#        '2030kg', '2225kg', '1615kg', '1770kg', '1500Kg', '2300 kg',
#        '1410', '1459kg', '1777kg', '1436', '1520kg', '1463kg', '1630kg',
#        '1170', '1940kg', '2185kg', '2165kg', '2075Kg', '1482-1528kg',
#        '2460kg', '1920kg', '2225Kg', '2189kg', '2555kg', '1250kgs',
#        '2950kg', '2500kg', '1600', '2005kg', '1260kg', '1235kg', '1970kg',
#        '2230kg', '2340kg', '2350kg', '2480kg', '1710kg', '1190 kg',
#        '2460', '2525kg', '2510', '1595kg', '2075kg', '1820', '2150kg',
#        '1781kg', '1795kg', '1310kg', '1382kg', '1700', '1570Kg',
#        '1575-1595kg', '2091kg', '1680Kg', '2735', '1760', '2,285 kg',
#        '1930kg', '2410kg', '1405Kgs', '2335kg', '2,625 kg', '2090kg',
#        '1640 kg', '2250kg', '2880kg', '1185', '1448kg', '2115kg',
#        '1895Kg', '2650kg', '1806kg', '1644kg', '1660kg', '1710Kg',
#        '2780kg', '2690kg', '1640', '2505kg', '1889kg', '2050 kg',
#        '2330kg', '1800Kg', '1540kg', '1320kg', '2610kg', '2145kg',
#        '2025kg', '2470kg', '2925 kg', '1670', '2795kg', '1700 kg', '1795',
#        '2735Kg', '2910kg', '3250kg', '2490', '1735kg', '2400 Kg',
#        '1000kg', '1550kg', '1730kg', '1685kg', '1940 kg', '1850kg',
#        '1438', '1340', '2449Kg', '1600kg', '1433kg', '2091 kg.', '3265kg',
#        '1740 Kg', '2100kg', '2315kg', '2450', '1190kg', '2,335 kg',
#        '1435kg', '2493kg', '2020kg', '2490 Kg', '1340Kg', '1275kg',
#        '1855kg', '2060 kg', '1635kg', '2190kg', '2,090 kg', '2070kg',
#        '1475kg', '2755', '2200kg', '1766kg', '2150 Kg', '2005Kg',
#        '2045kg', '2200Kg', '1590 kg', '1665kg', '2360kg', '2430',
#        '2020 kg', '3200kg', '2530kg', '1250', '2580kg', '2840kg',
#        '1955kg', '3230kg', '2445 Kg', '1545 Kg', '1390kg', '2940kg',
#        '2345Kg', '2490Kg', '2715Kg', '2270kg', '2870kg', '3200', '1480',
#        '1645kg', '2815 kg', '2105 Kg', '3150 Kg', '1320', '2490kg',
#        '1765kg', '2125Kg', '1640kg-1670kg', '2735kg', '2400 kg', '2098kg',
#        '1890 Kg', '1825kg', '2065kg', '1482-1528', '1700kg', '1750kg',
#        '1650kg', '1990kg', '1715', '2515kg', '2130 kg', '2000kg', '1765',
#        '1480kg', '2235kg', '1645', '2010kg', '2680', '1405', '2370kg',
#        '1570', '1660 kg.', '1415mm', '2185 Kg', '1971kg', '2210kg',
#        '1650-1660kg', '2365kg', '2830kg', '1779kg', '3175kg', '1740kgs',
#        '3000kg', '1523kg', '2015 kg', '1655', '1755kg', '1995 kg',
#        '2720kg', '1800 Kg', '1533', '1704kg', '1566-1592kg', '2215kg',
#        '3350Kg', '1535kg', '3490Kg', '2225 kg', '1,600 kg', '1870kg',
#        '2215', '1522kg', '2800kg', '1971 kg', '1373', '2400kg',
#        '1,970 kg', '1450kg', '1980 kg', '2295kg', '1461', '2180kg',
#        '1545Kg', '1554kg', '2470 Kg', '2265kg', '2375kg', '2120kg',
#        '2500', '2035kg', '1,505 kg', '2390kg', '1755', '1604kg', '1910kg'],
#       dtype=object)

# %%
# Clean the 'gross_weight' column
df_edit['gross_weight'] = df_edit['gross_weight'].replace({
    "Kg": "", 
    " ": "", 
    ",": "", 
    "s": "", 
    "mm": ""
}, regex=True)

# Function to replace ranges with average
def replace_range_with_average(value):
    if pd.isna(value):
        return np.nan
    try:
        # Handle ranges by splitting and calculating the average
        if '-' in value:
            start, end = map(int, value.split('-'))
            return (start + end) / 2
        # Handle valid numeric strings
        else:
            return float(value)
    except ValueError:
        return np.nan  # Handle invalid formats gracefully

# Apply the function to the 'gross_weight' column
df_edit['gross_weight'] = df_edit['gross_weight'].apply(replace_range_with_average)

# Convert to numeric values, handling errors gracefully
df_edit['gross_weight'] = pd.to_numeric(df_edit['gross_weight'], errors='coerce')

# Print unique values to verify
print(df_edit['gross_weight'].unique())

# Check data type of the 'gross_weight' column
print(df_edit['gross_weight'].dtypes)
# Out:
# [  nan 1660. 1530. 1335. 1730. 2165. 1260. 1405. 1750. 2610. 1705. 1690.
#  1520. 1650. 1315. 2830. 1500. 1410. 1436. 1170. 2075. 2225. 1600. 2460.
#  2510. 1820. 1700. 1570. 1680. 2735. 1760. 1185. 1895. 1710. 1640. 1800.
#  1670. 1795. 2490. 2400. 1438. 1340. 2449. 1740. 2450. 2755. 2150. 2005.
#  2200. 2430. 1250. 2445. 1545. 2345. 2715. 3200. 1480. 2105. 3150. 1320.
#  2125. 1890. 1505. 1715. 1765. 1645. 2680. 1415. 2185. 1655. 1533. 3350.
#  3490. 2215. 1373. 1461. 2470. 2500. 1755.]
# float64

# %%
df_edit['top_speed'].unique()
# Out:
# array(['150 Kmph', nan, '150 kmph', '172km/hr', '190 Kmph', '180 Kmph',
#        '165 Kmph', '172 Kmph', '175 kmph', '219kmph', '195 Kmph',
#        '226km/hr', '250 kmph', '236 Kmph', '222 Kmph', '152 kmph',
#        '240 Kmph', '250kmph', '176 Kmph', '170 Kmph', '191km/hr',
#        '232 Kmph', '233 Kmph', '137km/hr', '220 Kmph', '215 Kmph',
#        '154.19 kmph', '166 kmph', '183 Kmph', '226 Kmph', '160 kmph',
#        '156 Kmph', '185kmph', '157 Kmph', '165km/hr', '159.4 kmph',
#        '250 Kmph', '135 Kmph', '185 Kmph', '216 kmph', '200 Kmph',
#        '160.2 kmph', '230 Kmph', '216km/hr', '195.68 kmph', '158.83 kmph',
#        '210 Kmph', '168 Kmph', '155 Kmph', '177.22 kmph', '163 Kmph',
#        '230', '164 Kmph', '182km/hr', '186.08 kmph', '172 kmph',
#        '171.43 kmph', '155 kmph', '178.55 kmph', '182 Kmph', '186km/hr',
#        '189 kmph', '165 Km', '175 Kmph', '227km/hr', '164.26 kmph',
#        '194 Kmph', '242km/hr', '158km/hr', '160 Kmph', '190 kmph',
#        '157 kmph', '180 kmph', '225 Kmph', '215 kmph', '242 kmph',
#        '145 Kmph', '160km/hr', '178 kmph', '164.1km/hr', '158 Kmph',
#        '190km/hr', '196 Kmph', '165 kmph', '235kmph', '148.5km/hr',
#        '223km/hr', '171.92 Kmph', '188 Kmph', '151 kmph', '228 kmph',
#        '146 Kmph', '202 km/hr', '144km/hr', '213 kmph', '212 Kmph',
#        '250Kmph', '237 kmph', '196km/hr', '208 Kmph', '202km/hr',
#        '219 kmph', '217 kmph', '169 kmph', '186.69 kmph', '190 Kmph ',
#        '80 kmph', '95 kmph', '207 Kmph', '167.99kmph', '162.9km/hr',
#        '162.41kmph', '195 kmph', '145 kmph', '185km/hr', '167 Km/Hour',
#        '173 kmph', '231 kmph', '140 kmph', '161km/hr', '156km/hr',
#        '140 Kmph', '245', '170 Km/Hour', '105 kmph', '169 Kmph',
#        '117 Kmph', '179 kmph', '210 kmph', '205 Kmph', '185 kmph',
#        '242 Kmph', '153.98', '210km/hr', '105km/hr', '148km/hr',
#        '186 Kmph', '145kmph', '154.6 kmph', '250km/hr', '163 kmph',
#        '155.8 kmph', '170 kmph', '229 kmph', '156 kmph', '224 Kmph',
#        '149 Kmph', '154km/hr', '137 kmph', '228km/hr', '164.26kmph',
#        '152Km/Hour', '235 Kmph', '164 kmph', '198', '154 Kmph',
#        '212 kmph', '141.35', '183km/hr', '205km/hr', '144.93 kmph',
#        '222km/hr', ' ', '177 kmph', '243Kmph', '176 kmph', '234 Kmph',
#        '  ', '186 kmph', '151.63 kmph', '206 kmph', '240 kmph',
#        '157.3 kmph', '225Kmph', '238kmph', '125.67kmph', '128.84kmph',
#        '248 kmph', '237 Kmph', '156.09', '230Kmph', '202 Kmph',
#        '247 Kmph', ' 185 Kmph', '162 kmph', '151.2 kmph', '200.7 kmph',
#        '117 kmph', '150.49', '158.63 kmph', '130 Kmph', '189 Kmph',
#        '220 kmph', '175.61 kmph', '236km/hr', '163 km/hr', '180km/hr',
#        '240kmph', '138 kmph', '152km/hr', '200km/hr', '170km/hr',
#        '201Kmph', '230km/hr', '123.99', '136 kmph', '151.11 kmph',
#        '151.63 Kmph', '165 kmph ', '188 kmph', '175km/hr', '193 kmph',
#        '148.33 kmph', '183.8km/hr', '225km/hr', '180', '217 Kmph',
#        '209 Kmph', '204 Kmph', '219 Kmph', '228kmph', '222', '235km/hr',
#        '130 kmph', '163.81kmph', '191 Kmph', '190kmph', '246kmph',
#        '207kmph', '221Kmph', '221 Kmph', '160.21kmph', '220kmph',
#        '213kmph', '222 kmph', '259kmph', '154 kmph', '199 Kmph',
#        '228 Kmph', '239 Kmph', '241 Kmph', '163km/hr', '162.9 kmph',
#        '235 kmph', '234 kmph', '164.5 Kmph', '183 kmph', '232km/hr',
#        '195km/hr', '206km/hr', '161.7 Kmph', '141km/hr', '210 km/hr',
#        '133.9 kmph', '230 kmph', '233 kmph', '237kmph', '250 km/h', '227',
#        '160.58kmph', '120 Kmph', '225 kmph', '210kmph', '209km/hr',
#        '181 kmph', '195 Km', '171km/hr', '224 kmph', '86 Kmph',
#        '180 km/h', '148.5 kmph', '180.5 kmph', '158 kmph', '161 Kmph',
#        '191.7 kmph', '177km/hr', '150km/hr', '117km/hr', '155km/hr',
#        '163.81 kmph', '192 kmph', ' 160 Kmph', '162km/hr', '141 kmph',
#        '148 kmph', '126 Kmph', '161 kmph', '151 Kmph', '308Kmph',
#        '121.92', '129 Km/Hour', '170.41 kmph', '229 Kmph', '285km/hr',
#        '310 Kmph', '259 Kmph', '144.57kmph', '245kmph', '154.19 Kmph',
#        '142.95kmph', '168.56 kmph', '275 Kmph', '215km/hr', '144 Kmph',
#        '171 Kmph', '155kmph'], dtype=object)

# %%
df_edit['mileage'].unique()
# Out:
# array(['23.1 kmpl', '17 kmpl', '23.84 kmpl', '19.1 kmpl', '23.65 kmpl',
#        '17.1 kmpl', '20.63 kmpl', '18.15 kmpl', '20.28 kmpl', '21.4 kmpl',
#        '18.9 kmpl', '18.2 kmpl', '15.1 kmpl', nan, '21.27 kmpl',
#        '17.33 kmpl', '17.8 kmpl', '18.48 kmpl', '22.38 kmpl',
#        '16.42 kmpl', '7.81 kmpl', '17.4 kmpl', '20.3 kmpl', '13.45 kmpl',
#        '15 kmpl', '17.11 kmpl', '20.14 kmpl', '20.51 kmpl', '19.34 kmpl',
#        '12.6 kmpl', '15.56 kmpl', '11.5 kmpl', '19.87 kmpl', '18.6 kmpl',
#        '22.54 kmpl', '16.3 kmpl', '18.53 kmpl', '22.05 kmpl',
#        '12.05 kmpl', '16.5 kmpl', '19.7 kmpl', '11.3 kmpl', '14.08 kmpl',
#        '12.07 kmpl', '22 kmpl', '21.5 kmpl', '15.3 kmpl', '26.68 kmpl',
#        '21.14 kmpl', '15.9 kmpl', '19.67 kmpl', '14.6 kmpl', '28.4 kmpl',
#        '21.76 kmpl', '26.21 kmpl', '19 kmpl', '19.98 kmpl', '18.5 kmpl',
#        '20 kmpl', '16.8 kmpl', '17.2 kmpl', '21.13 kmpl', '24 kmpl',
#        '25.32 kmpl', '16.55 kmpl', '19.2 kmpl', '24.04 kmpl',
#        '27.03 kmpl', '16.56 kmpl', '19.4 kmpl', '19.56 kmpl',
#        '20.92 kmpl', '19.03 kmpl', '21.1 kmpl', '18.19 kmpl',
#        '17.41 kmpl', '14.2 kmpl', '19.81 kmpl', '14.8 kmpl', '16 kmpl',
#        '18.4 kmpl', '13.2 kmpl', '14.1 kmpl', '20.36 kmpl', '13.24 kmpl',
#        '14.16 kmpl', '24.39 kmpl', '10.91 kmpl', '18.16 kmpl',
#        '20.89 kmpl', '18.1 kmpl', '16.35 kmpl', '15.97 kmpl',
#        '16.07 kmpl', '16.38 kmpl', '14.24 kmpl', '17.9 kmpl',
#        '19.01 kmpl', '25.2 kmpl', '19.6 kmpl', '18 kmpl', '17.21 kmpl',
#        '11.1 kmpl', '11.4 kmpl', '11.72 kmpl', '13.32 kmpl', '20.37 kmpl',
#        '24.3 kmpl', '18.27 kmpl', '20.45 kmpl', '18.7 kmpl', '22.41 kmpl',
#        '20.77 kmpl', '15.63 kmpl', '20.54 kmpl', '21.19 kmpl',
#        '27.39 kmpl', '17.92 kmpl', '26 kmpl', '10 kmpl', '17.5 kmpl',
#        '11.18 kmpl', '23 kmpl', '17.57 kmpl', '14.21 kmpl', '21.43 kmpl',
#        '20.65 kmpl', '22.9 kmpl', '14.5 kmpl', '12.99 kmpl', '19.12 kmpl',
#        '13.8 kmpl', '13.38 kmpl', '14.7 kmpl', '16.36 kmpl', '18.24 kmpl',
#        '21.56 kmpl', '20.38 kmpl', '23.7 kmpl', '20.08 kmpl', '10.9 kmpl',
#        '21.21 kmpl', '15.43 kmpl', '21.74 kmpl', '23.95 kmpl',
#        '19.27 kmpl', '15.4 kmpl', '22.07 kmpl', '20.85 kmpl',
#        '17.01 kmpl', '14.11 kmpl', '22.56 kmpl', '20.5 kmpl', '20.4 kmpl',
#        '20.73 kmpl', '15.6 kmpl', '14.67 kmpl', '19.3 kmpl', '14.71 kmpl',
#        '17.69 kmpl', '13.6 kmpl', '21.72 kmpl', '12.51 kmpl', '16.2 kmpl',
#        '13 kmpl', '17.74 kmpl', '12.55 kmpl', '12.8 kmpl', '22.35 kmpl',
#        '22.77 kmpl', '25.24 kmpl', '17.7 kmpl', '13.06 kmpl', '12.3 kmpl',
#        '17.14 kmpl', '21.03 kmpl', '21.7 kmpl', '23.2 kmpl', '14.69 kmpl',
#        '22.5 kmpl', '20.52 kmpl', '21.46 kmpl', '22.69 kmpl',
#        '22.32 kmpl', '21.01 kmpl', '24.4 kmpl', '17.42 kmpl',
#        '18.56 kmpl', '15.73 kmpl', '17.68 kmpl', '16.13 kmpl',
#        '13.79 kmpl', '18.25 kmpl', '18.3 kmpl', '15.5 kmpl', '15.17 kmpl',
#        '14.99 kmpl', '11.9 kmpl', '15.29 kmpl', '16.09 kmpl',
#        '16.47 kmpl', '20.09 kmpl', '21.63 kmpl', '15.26 kmpl',
#        '11.57 kmpl', '17.03 kmpl', '20.8 kmpl', '17.19 kmpl', '12 kmpl',
#        '23.9 kmpl', '20.04 kmpl', '110 kmpl', '14.59 kmpl', '14 kmpl',
#        '18.45 kmpl', '16.96 kmpl', '12.65 kmpl', '19.33 kmpl',
#        '19.65 kmpl', '22.15 kmpl', '25 kmpl', '14.82 kmpl', '10.75 kmpl',
#        '21.73 kmpl', '8 kmpl', '16.1 kmpl', '20.68 kmpl', '22.7 kmpl',
#        '11.36 kmpl', '13.4 kmpl', '18.49 kmpl', '14.28 kmpl',
#        '17.88 kmpl', '16.11 kmpl', '20.7 kmpl', '16.82 kmpl', '17.3 kmpl',
#        '20.46 kmpl', '12.35 kmpl', '15.04 kmpl', '18.75 kmpl',
#        '15.2 kmpl', '18.12 kmpl', '18.06 kmpl', '11.7 kmpl', '20.1 kmpl',
#        '22.74 kmpl', '28.09 kmpl', '17.67 kmpl', '20.88 km/kg',
#        '26.11 kmpl', '22.1 kmpl', '13.5 kmpl', '24.52 kmpl', '20.25 kmpl',
#        '13.58 kmpl', '10.54 kmpl', '15.7 kmpl', '19.64 kmpl', '140 kmpl',
#        '13.68 kmpl', '16.24 kmpl', '26.59 kmpl', '13.7 kmpl', '17.6 kmpl',
#        '19.69 kmpl', '15.41 kmpl', '14.9 kmpl', '17.52 kmpl',
#        '17.05 kmpl', '24.7 kmpl', '21.9 kmpl', '25.4 kmpl', '19.47 kmpl',
#        '21.66 kmpl', '25.8 kmpl', '10.5 kmpl', '14.4 kmpl', '9 kmpl',
#        '19.09 kmpl', '23.01 kmpl', '22.25 kmpl', '27.28 kmpl',
#        '21.64 kmpl', '22.61 kmpl', '15.8 kmpl', '18.09 kmpl',
#        '19.28 kmpl', '18.78 kmpl', '11.74 kmpl', '8.9 kmpl', '15.85 kmpl',
#        '18.76 kmpl', '16.95 kmpl', '23.59 kmpl', '14.84 kmpl',
#        '19.5 kmpl', '21 kmpl', '15.96 kmpl', '27.3 kmpl', '18.88 kmpl',
#        '13.93 kmpl', '14.74 kmpl', '16.4 kmpl', '16.28 kmpl',
#        '20.86 kmpl', '18.07 kmpl', '21.79 kmpl', '16.6 kmpl', '13.9 kmpl',
#        '26.1 kmpl', '13.92 kmpl', '18.55 kmpl', '14.02 kmpl',
#        '31.59 km/kg', '19.72 kmpl', '14.57 kmpl', '21.8 kmpl',
#        '15.37 kmpl', '13.53 kmpl', '14.53 kmpl', '13.22 kmpl',
#        '25.5 kmpl', '14.75 kmpl', '16.46 kmpl', '19.02 kmpl',
#        '18.41 kmpl', '23.8 kmpl', '14.3 kmpl', '17.99 kmpl', '15.81 kmpl',
#        '15.34 kmpl', '19.08 kmpl', '18.86 kmpl', '19.49 kmpl',
#        '22.95 kmpl', '25.17 kmpl', '16.14 kmpl', '17.09 kmpl',
#        '18.97 kmpl', '12.08 kmpl', '16.78 kmpl', '19.23 kmpl', '8.5 kmpl',
#        '25.6 kmpl', '22.3 kmpl', '18.72 kmpl', '13.96 kmpl', '16.65 kmpl',
#        '12.62 kmpl', '19.44 kmpl', '14.62 kmpl', '23.64 kmpl',
#        '19.71 kmpl', '13.17 kmpl', '19.15 kmpl', '23.56 kmpl',
#        '23.4 kmpl', '19.62 kmpl', '16.25 kmpl', '27.62 kmpl',
#        '25.44 kmpl', '20.71 kmpl', '9.8 kmpl', '13.14 kmpl', '11.33 kmpl',
#        '25.19 kmpl', '24.29 kmpl', '19.16 kmpl', '16.73 kmpl',
#        '19.83 kmpl', '25.83 kmpl', '12.2 kmpl', '12.78 kmpl',
#        '14.49 kmpl', '20.58 kmpl', '24.35 kmpl', '14.19 kmpl',
#        '12.7 kmpl', '26.49 km/kg', '16.98 kmpl', '16.02 kmpl',
#        '18.05 kmpl', '24.2 kmpl', '15.64 kmpl', '19.19 kmpl',
#        '13.01 kmpl', '12.83 kmpl', '11.24 kmpl', '12.18 kmpl',
#        '18.8 kmpl', '26.2 kmpl', '23.08 kmpl', '22.37 kmpl', '16.9 kmpl',
#        '19.59 kmpl', '14.85 kmpl', '12.74 kmpl', '28 km/kg', '12.4 kmpl',
#        '12.5 kmpl', '14.025 kmpl', '19.89 kmpl', '30.48 km/kg',
#        '33.54 kmpl', '19.61 kmpl', '26.08 km/kg', '12.1 kmpl',
#        '12.81 kmpl', '9.2 kmpl', '17.71 kmpl', '16.34 kmpl', '30.46 kmpl',
#        '32.52 kmpl', '11.21 kmpl', '16.39 kmpl', '11.2 kmpl',
#        '12.04 kmpl', '11.67 kmpl', '16.12 kmpl', '26.55 kmpl',
#        '7.08 kmpl', '31.2 kmpl', '12.33 kmpl', '31.79 kmpl', '11 kmpl',
#        '8.13 kmpl', '35.6 km/kg', '16.72 kmpl', '25.1 kmpl', '22.48 kmpl',
#        '20.6 kmpl', '14.01 kmpl', '17.38 kmpl', '12.34 kmpl', '10.8 kmpl',
#        '9.26 kmpl', '12.95 kmpl', '12.9 kmpl', '16.7 kmpl', '15.68 kmpl',
#        '10.4 kmpl', '20.15 kmpl', '31.12 km/kg', '26.8 kmpl',
#        '11.88 kmpl', '18.69 kmpl', '18.9 km/kg', '22.27 kmpl',
#        '15.01 kmpl', '10.26 kmpl', '19.39 kmpl', '14.34 kmpl',
#        '8.45 kmpl', '26.11 km/kg', '12.63 kmpl', '26.6 kmpl',
#        '13.47 kmpl', '10.13 kmpl', '20.27 kmpl', '14.09 kmpl',
#        '20.01 kmpl', '14.47 kmpl', '10.93 kmpl', '26.6 km/kg',
#        '26.83 kmpl', '31.12 kmpl', '24.76 kmpl', '21.11 kmpl',
#        '14.23 kmpl', '26.82 kmpl', '17.32 kmpl', '25.3 kmpl',
#        '19.95 kmpl', '21.12 kmpl', '11.96 kmpl', '21.02 kmpl',
#        '19.68 kmpl', '18.23 kmpl', '23.22 kmpl', '17.97 kmpl',
#        '16.97 kmpl', '13.33 kmpl', '27.4 kmpl', '26.5 kmpl', '25.01 kmpl',
#        '17.43 kmpl', '22.71 kmpl', '20.34 kmpl', '24.1 kmpl',
#        '30.47 km/kg', '17.29 kmpl', '21.49 kmpl', '13.1 kmpl',
#        '21.1 km/kg', '18.43 kmpl', '12.12 kmpl', '9.74 kmpl',
#        '16.77 kmpl', '19.17 kmpl', '21.38 kmpl', '23.57 kmpl',
#        '24.8 kmpl', '7.94 kmpl', '26.49 kmpl', '25.47 kmpl', '18.33 kmpl',
#        '9.4 kmpl', '7.5 kmpl', '13.44 kmpl', '14.94 kmpl', '23.03 kmpl',
#        '15.39 kmpl', '24.97 kmpl', '34.05 kmpl', '17.85 kmpl',
#        '27.97 kmpl', '20.62 kmpl', '15.15 kmpl', '19.8 kmpl',
#        '14.95 kmpl', '11.81 kmpl', '12.98 kmpl'], dtype=object)

# %%
# List of patterns to replace in 'top_speed' and 'mileage'
top_speed_patterns = ["Kmph", "km/hr", "km/Hour", "kmph", "Km/Hour", "km/h", "km"]
mileage_patterns = ["kmpl", "km/kg", "Kmpl", "Km/kg"]

# Step 1: Clean 'top_speed' and 'mileage' columns by replacing multiple patterns
for pattern in top_speed_patterns:
    df_edit['top_speed'] = df_edit['top_speed'].str.replace(pattern, "", regex=False)

for pattern in mileage_patterns:
    df_edit['mileage'] = df_edit['mileage'].str.replace(pattern, "", regex=False)

# Remove any spaces
df_edit['top_speed'] = df_edit['top_speed'].str.replace(" ", "", regex=False)
df_edit['mileage'] = df_edit['mileage'].str.replace(" ", "", regex=False)

# Convert 'top_speed' and 'mileage' to numeric values
df_edit['top_speed'] = pd.to_numeric(df_edit['top_speed'], errors='coerce')
df_edit['mileage'] = pd.to_numeric(df_edit['mileage'], errors='coerce')

# Step 2: Group by 'mileage' and calculate the mean of 'top_speed'
top_speed_value = df_edit.groupby('mileage')['top_speed'].mean().to_dict()

# Step 3: Define the function to replace NaN in 'top_speed'
def replace_nan(row, values_dict):
    if pd.isnull(row['top_speed']) and pd.notnull(row['mileage']):
        return values_dict.get(row['mileage'], row['top_speed'])
    return row['top_speed']

# Step 4: Apply the function to the DataFrame
df_edit['top_speed'] = df_edit.apply(
    lambda row: replace_nan(row, top_speed_value),
    axis=1
)

# %%
# Remove 'R' from the alloy_wheel_size column
df_edit['alloy_wheel_size'] = df_edit['alloy_wheel_size'].str.replace('R', "", regex=False)

# Step 1: Calculate the mode of alloy_wheel_size for each body type (bt)
# Using 'mode' and handling the case of multiple modes by choosing the first mode
alloy_wheel_size_value = df_edit.groupby('bt')['alloy_wheel_size'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()

# Step 2: Define the function to replace NaN values in alloy_wheel_size based on body type (bt)
def replace_nan_alloy(row, values_dict):
    # If alloy_wheel_size is NaN and bt is not NaN, replace it with the mode for that bt
    if pd.isnull(row['alloy_wheel_size']) and pd.notnull(row['bt']):
        return values_dict.get(row['bt'], row['alloy_wheel_size'])
    return row['alloy_wheel_size']

# Step 3: Apply the function to update the alloy_wheel_size column
df_edit['alloy_wheel_size'] = df_edit.apply(lambda row: replace_nan_alloy(row, alloy_wheel_size_value), axis=1)

# Check the unique values in the updated alloy_wheel_size column
print("Unique values in alloy_wheel_size after update:", df_edit['alloy_wheel_size'].unique())

# Check the proportion of null values in the alloy_wheel_size and bt columns
null_alloy_percentage = df_edit['alloy_wheel_size'].isnull().sum() / len(df_edit)
null_bt_percentage = df_edit['bt'].isnull().sum() / len(df_edit)

print(f"Proportion of null values in alloy_wheel_size: {null_alloy_percentage:.4f}")
print(f"Proportion of null values in bt: {null_bt_percentage:.4f}")
# Out:
# Unique values in alloy_wheel_size after update: ['14' '16' '17' '15' '19' '13' '18' '12' '20' '21' nan None]
# Proportion of null values in alloy_wheel_size: 0.0006
# Proportion of null values in bt: 0.0005

# %%
rto_value = df_edit.groupby('city')['rto'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()

def replace_rto(row, values_dict):
    if pd.isnull(row['rto']) and pd.notnull(row['city']):
        return values_dict.get(row['city'], row['rto'])
    return row['rto']

df_edit['rto'] = df_edit.apply(
    lambda row: replace_rto(row, rto_value),  # Use the correct function name here
    axis=1
)

# %%
# Create a dictionary for replacements
replacements = {
    "FWD ": "FWD",
    "Front Wheel Drive": "FWD",
    "2WD ": "2WD",
    "2 WD": "2WD",
    "4 WD": "4WD",
    "Rear Wheel Drive with ESP": "RWD",
    "RWD(with MTT)": "4WD",
    "All Wheel Drive": "AWD",
    "AWD INTEGRATED MANAGEMENT": "AWD",
    "Two Wheel Drive": "2WD",
    "Permanent all-wheel drive quattro": "AWD",
    "4x2": "2WD",
    "4X4": "4WD",
    "4X2": "2WD",  # Duplicate entry, already covered in the previous line
    "4x4": "4WD"
}

# Use the replace method with the dictionary, ensuring it applies the replacements correctly
df_edit['drive_type'] = df_edit['drive_type'].replace(replacements, regex=False)

# Check unique values after replacement
df_edit['drive_type'].unique()
# Out:
# array(['FWD', '2WD', 'AWD', nan, 'RWD', '4WD'], dtype=object)

# %%
df_edit['turning_radius'] = df_edit['turning_radius'].str.replace(r'[^0-9.\-\,]', '', regex=True)
df_edit['turning_radius'] = df_edit['turning_radius'].str.replace("6250", "6.25", regex=False)
df_edit['turning_radius'] = pd.to_numeric(df_edit['turning_radius'], errors='coerce')

# Dictionary with turning radius for each body type
turning_radius = {
    "Hatchback": 4.5,          # Hatchbacks are compact with a smaller turning radius
    "SUV": 5.8,                # SUVs are larger and require a larger turning radius
    "Sedan": 5.5,              # Sedans have a moderate turning radius
    "MUV": 5.8,                # Multi-Utility Vehicles (MUVs) are similar to SUVs
    "Coupe": 5.0,              # Coupes are generally compact with a moderate turning radius
    "Minivans": 6.0,           # Minivans are larger with a bigger turning radius
    "Pickup Trucks": 6.4,      # Pickup trucks tend to have a wide turning radius
    "Convertibles": 5.2,       # Convertibles are similar to sedans or coupes in size
    "Hybrids": 5.4,            # Hybrids vary but tend to have a moderate turning radius
    "Wagon": 5.6               # Wagons are mid-sized with a moderate turning radius
}

def replace_nan(row, values_dict):
    """
    Replace NaN turning radius with the corresponding value from the dictionary 
    based on the body type, if body type is not NaN.
    """
    # Check if turning_radius is NaN and body type (bt) is available
    if pd.isnull(row['turning_radius']) and pd.notnull(row.get('bt')):
        # Return the turning radius for the body type, if exists in the dictionary
        return values_dict.get(row['bt'], row['turning_radius'])
    return row['turning_radius']

# Apply the function to the DataFrame to replace NaN values in 'turning_radius'
df_edit['turning_radius'] = df_edit.apply(
    lambda row: replace_nan(row, turning_radius),
    axis=1
)

# %%
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.lower()
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.replace("turbo", "yes", regex=False)
df_edit['turbo_charger'] = df_edit['turbo_charger'].str.replace("twin", "yes", regex=False)

# %%
df_edit['turbo_charger'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df_edit['super_charger'] = df_edit['super_charger'].str.lower()
df_edit['super_charger'].unique()
# Out:
# array(['no', nan, 'yes'], dtype=object)

# %%
print(df_edit['variantname'].nunique())
print("-------------------------------------------------------------------------------------")
print(df_edit['centralvariantid'].nunique(),df_edit['centralvariantid'].dtypes)
print("-------------------------------------------------------------------------------------")
print(df_edit['bt'].nunique())
# Out:
# 2157
# -------------------------------------------------------------------------------------
# 2713 int64
# -------------------------------------------------------------------------------------
# 10

# %%
df_edit.head(1)
# Out:
#        ft         bt        km transmission  ownerno      owner     oem  \
# 0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner  Maruti
#
#             model  modelyear  centralvariantid variantname     price  \
# 0  Maruti Celerio       2015              3979         VXI  ₹ 4 Lakh
#
#   registration_year     insurance_validity    seats   rto engine_displacement  \
# 0              2015  Third Party insurance  5 Seats  KA51              998 cc
#
#    year_of_manufacture  power_steering  power_windows_front  air_conditioner  \
# 0               2015.0            True                 True             True
#
#    heater  adjustable_head_lights  centeral_locking  child_safety_locks  \
# 0    True                    True              True                True
#
#    power_windows_rear  remote_trunk_opener  remote_fuel_lid_opener  \
# 0                True                 True                    True
#
#    low_fuel_warning_light  accessory_power_outlet  rear_seat_headrest  \
# 0                    True                    True                True
#
#    glove_compartment  day_night_rear_view_mirror  \
# 0               True                        True
#
#    passenger_side_rear_view_mirror  halogen_headlamps  rear_seat_belts  \
# 0                             True               True             True
#
#    door_ajar_warning  anti_lock_braking_system  multifunction_steering_wheel  \
# 0               True                     False                         False
#
#    navigation_system  engine_start_stop_button  gear_shift_indicator  \
# 0              False                     False                 False
#
#    adjustable_steering  outside_temperature_display  rear_window_defogger  \
# 0                False                        False                 False
#
#    power_door_locks  driver_air_bag  passenger_air_bag  seat_belt_warning  \
# 0             False           False              False              False
#
#    engine_check_warning  crash_sensor  rear_camera  \
# 0                 False         False        False
#
#    speed_sensing_auto_door_lock  pretensioners_and_force_limiter_seatbelts  \
# 0                         False                                      False
#
#    impact_sensing_auto_door_lock  radio  integrated2din_audio  \
# 0                          False  False                 False
#
#    usb_auxiliary_input  bluetooth  touch_screen  \
# 0                False      False         False
#
#    driving_experience_control_eco  rear_reading_lamp  rear_acvents  \
# 0                           False              False         False
#
#    air_quality_control  height_adjustable_front_seat_belts  cruise_control  \
# 0                False                               False           False
#
#    voice_control  leather_seats  battery_saver  anti_theft_alarm  hill_assist  \
# 0          False          False          False             False        False
#
#    brake_assist  rain_sensing_wiper  adjustable_headrest  ledheadlights  \
# 0         False               False                False          False
#
#    cornering_headlamps  side_air_bag_front  side_air_bag_rear  \
# 0                False               False              False
#
#    tyre_pressure_monitor  clutch_lock  anti_pinch_power_windows  knee_airbags  \
# 0                  False        False                     False         False
#
#    wireless_phone_charging  projector_headlamps  speed_alert  \
# 0                    False                False        False
#
#    rear_entertainment_system  ventilated_seats  view360camera  \
# 0                      False             False          False
#
#    steering_mounted_tripmeter  hill_descent_control  roof_carrier  mileage  \
# 0                       False                 False         False     23.1
#
#           max_power torque  color  engine_type  no_of_cylinder  \
# 0  67.04bhp@6000rpm   90Nm  White  K10B Engine             3.0
#
#    values_per_cylinder turbo_charger super_charger  length   width  height  \
# 0                  4.0            no            no  3715mm  1635mm  1565mm
#
#   wheel_base kerb_weight  gross_weight  gear_box drive_type steering_type  \
# 0     2425mm       835kg           NaN  5 Speed         FWD         Power
#
#    turning_radius front_brake_type rear_brake_type  top_speed  \
# 0             4.7  Ventilated Disc            Drum      150.0
#
#           tyre_type  no_door_numbers cargo_volumn alloy_wheel_size  \
# 0  Tubeless, Radial              5.0   235-litres               14
#
#    ground_clearance_unladen       city  stability_features  \
# 0                     165.0  bangalore               False
#
#    blind_spot_assistance  indicators  Adjustable_rear_view_mirror  fog_lamps  \
# 0                  False       False                         True      False
#
#    automatic_lamps  meters  car_roof  speakers  antenna  player  \
# 0            False    True     False     False     True   False
#
#    smartphone_integration  impact_beams
# 0                   False          True

# %%
# Cleaning 'kerb_weight' column
df_edit['kerb_weight'] = df_edit['kerb_weight'].str.replace(r"kg|s|mm|,| |Kg", "", regex=True).str.strip()
# Apply the function to the 'kerb Weight' column
df_edit['kerb_weight'] = df_edit['kerb_weight'].apply(replace_range_with_average)

# %%
df_edit['cargo_volumn'] = df_edit['cargo_volumn'].str.extract(r'(\d+\.?\d*)', expand=False)
df_edit['cargo_volumn'] = pd.to_numeric(df_edit['cargo_volumn'], errors='coerce')

# %%
# Calculate the percentage of null values for each column
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100

# Identify columns with null percentage less than 5%
columns_to_drop = null_percentage[null_percentage < 5].index

# Drop rows with null values in those columns
df_edit = df_edit.dropna(subset=columns_to_drop)

# %%
for i in df_edit.columns:
    print(f"{i}:null value percentage -> {(df_edit[i].isnull().sum()/len(df_edit))*100}%, Data types -> {df_edit[i].dtypes}")
# Out:
# ft:null value percentage -> 0.0%, Data types -> object
# bt:null value percentage -> 0.0%, Data types -> object
# km:null value percentage -> 0.0%, Data types -> object
# transmission:null value percentage -> 0.0%, Data types -> object
# ownerno:null value percentage -> 0.0%, Data types -> int64
# owner:null value percentage -> 0.0%, Data types -> object
# oem:null value percentage -> 0.0%, Data types -> object
# model:null value percentage -> 0.0%, Data types -> object
# modelyear:null value percentage -> 0.0%, Data types -> int64
# centralvariantid:null value percentage -> 0.0%, Data types -> int64
# variantname:null value percentage -> 0.0%, Data types -> object
# price:null value percentage -> 0.0%, Data types -> object
# registration_year:null value percentage -> 0.0%, Data types -> object
# insurance_validity:null value percentage -> 0.0%, Data types -> object
# seats:null value percentage -> 0.0%, Data types -> object
# rto:null value percentage -> 0.0%, Data types -> object
# engine_displacement:null value percentage -> 0.0%, Data types -> object
# year_of_manufacture:null value percentage -> 0.0%, Data types -> float64
# power_steering:null value percentage -> 0.0%, Data types -> bool
# power_windows_front:null value percentage -> 0.0%, Data types -> bool
# air_conditioner:null value percentage -> 0.0%, Data types -> bool
# heater:null value percentage -> 0.0%, Data types -> bool
# adjustable_head_lights:null value percentage -> 0.0%, Data types -> bool
# centeral_locking:null value percentage -> 0.0%, Data types -> bool
# child_safety_locks:null value percentage -> 0.0%, Data types -> bool
# power_windows_rear:null value percentage -> 0.0%, Data types -> bool
# remote_trunk_opener:null value percentage -> 0.0%, Data types -> bool
# remote_fuel_lid_opener:null value percentage -> 0.0%, Data types -> bool
# low_fuel_warning_light:null value percentage -> 0.0%, Data types -> bool
# accessory_power_outlet:null value percentage -> 0.0%, Data types -> bool
# rear_seat_headrest:null value percentage -> 0.0%, Data types -> bool
# glove_compartment:null value percentage -> 0.0%, Data types -> bool
# day_night_rear_view_mirror:null value percentage -> 0.0%, Data types -> bool
# passenger_side_rear_view_mirror:null value percentage -> 0.0%, Data types -> bool
# halogen_headlamps:null value percentage -> 0.0%, Data types -> bool
# rear_seat_belts:null value percentage -> 0.0%, Data types -> bool
# door_ajar_warning:null value percentage -> 0.0%, Data types -> bool
# anti_lock_braking_system:null value percentage -> 0.0%, Data types -> bool
# multifunction_steering_wheel:null value percentage -> 0.0%, Data types -> bool
# navigation_system:null value percentage -> 0.0%, Data types -> bool
# engine_start_stop_button:null value percentage -> 0.0%, Data types -> bool
# gear_shift_indicator:null value percentage -> 0.0%, Data types -> bool
# adjustable_steering:null value percentage -> 0.0%, Data types -> bool
# outside_temperature_display:null value percentage -> 0.0%, Data types -> bool
# rear_window_defogger:null value percentage -> 0.0%, Data types -> bool
# power_door_locks:null value percentage -> 0.0%, Data types -> bool
# driver_air_bag:null value percentage -> 0.0%, Data types -> bool
# passenger_air_bag:null value percentage -> 0.0%, Data types -> bool
# seat_belt_warning:null value percentage -> 0.0%, Data types -> bool
# engine_check_warning:null value percentage -> 0.0%, Data types -> bool
# crash_sensor:null value percentage -> 0.0%, Data types -> bool
# rear_camera:null value percentage -> 0.0%, Data types -> bool
# speed_sensing_auto_door_lock:null value percentage -> 0.0%, Data types -> bool
# pretensioners_and_force_limiter_seatbelts:null value percentage -> 0.0%, Data types -> bool
# impact_sensing_auto_door_lock:null value percentage -> 0.0%, Data types -> bool
# radio:null value percentage -> 0.0%, Data types -> bool
# integrated2din_audio:null value percentage -> 0.0%, Data types -> bool
# usb_auxiliary_input:null value percentage -> 0.0%, Data types -> bool
# bluetooth:null value percentage -> 0.0%, Data types -> bool
# touch_screen:null value percentage -> 0.0%, Data types -> bool
# driving_experience_control_eco:null value percentage -> 0.0%, Data types -> bool
# rear_reading_lamp:null value percentage -> 0.0%, Data types -> bool
# rear_acvents:null value percentage -> 0.0%, Data types -> bool
# air_quality_control:null value percentage -> 0.0%, Data types -> bool
# height_adjustable_front_seat_belts:null value percentage -> 0.0%, Data types -> bool
# cruise_control:null value percentage -> 0.0%, Data types -> bool
# voice_control:null value percentage -> 0.0%, Data types -> bool
# leather_seats:null value percentage -> 0.0%, Data types -> bool
# battery_saver:null value percentage -> 0.0%, Data types -> bool
# anti_theft_alarm:null value percentage -> 0.0%, Data types -> bool
# hill_assist:null value percentage -> 0.0%, Data types -> bool
# brake_assist:null value percentage -> 0.0%, Data types -> bool
# rain_sensing_wiper:null value percentage -> 0.0%, Data types -> bool
# adjustable_headrest:null value percentage -> 0.0%, Data types -> bool
# ledheadlights:null value percentage -> 0.0%, Data types -> bool
# cornering_headlamps:null value percentage -> 0.0%, Data types -> bool
# side_air_bag_front:null value percentage -> 0.0%, Data types -> bool
# side_air_bag_rear:null value percentage -> 0.0%, Data types -> bool
# tyre_pressure_monitor:null value percentage -> 0.0%, Data types -> bool
# clutch_lock:null value percentage -> 0.0%, Data types -> bool
# anti_pinch_power_windows:null value percentage -> 0.0%, Data types -> bool
# knee_airbags:null value percentage -> 0.0%, Data types -> bool
# wireless_phone_charging:null value percentage -> 0.0%, Data types -> bool
# projector_headlamps:null value percentage -> 0.0%, Data types -> bool
# speed_alert:null value percentage -> 0.0%, Data types -> bool
# rear_entertainment_system:null value percentage -> 0.0%, Data types -> bool
# ventilated_seats:null value percentage -> 0.0%, Data types -> bool
# view360camera:null value percentage -> 0.0%, Data types -> bool
# steering_mounted_tripmeter:null value percentage -> 0.0%, Data types -> bool
# hill_descent_control:null value percentage -> 0.0%, Data types -> bool
# roof_carrier:null value percentage -> 0.0%, Data types -> bool
# mileage:null value percentage -> 0.0%, Data types -> float64
# max_power:null value percentage -> 0.0%, Data types -> object
# torque:null value percentage -> 0.0%, Data types -> object
# color:null value percentage -> 0.0%, Data types -> object
# engine_type:null value percentage -> 0.0%, Data types -> object
# no_of_cylinder:null value percentage -> 0.0%, Data types -> float64
# values_per_cylinder:null value percentage -> 0.0%, Data types -> float64
# turbo_charger:null value percentage -> 8.423876592890679%, Data types -> object
# super_charger:null value percentage -> 16.44533869885983%, Data types -> object
# length:null value percentage -> 0.0%, Data types -> object
# width:null value percentage -> 0.0%, Data types -> object
# height:null value percentage -> 0.0%, Data types -> object
# wheel_base:null value percentage -> 0.0%, Data types -> object
# kerb_weight:null value percentage -> 0.0%, Data types -> float64
# gross_weight:null value percentage -> 89.56405097250168%, Data types -> float64
# gear_box:null value percentage -> 0.0%, Data types -> object
# drive_type:null value percentage -> 14.111334674714957%, Data types -> object
# steering_type:null value percentage -> 0.0%, Data types -> object
# turning_radius:null value percentage -> 0.0%, Data types -> float64
# front_brake_type:null value percentage -> 0.0%, Data types -> object
# rear_brake_type:null value percentage -> 0.0%, Data types -> object
# top_speed:null value percentage -> 17.773306505700873%, Data types -> float64
# tyre_type:null value percentage -> 0.0%, Data types -> object
# no_door_numbers:null value percentage -> 0.0%, Data types -> float64
# cargo_volumn:null value percentage -> 15.560026827632461%, Data types -> float64
# alloy_wheel_size:null value percentage -> 0.0%, Data types -> object
# ground_clearance_unladen:null value percentage -> 0.0%, Data types -> float64
# city:null value percentage -> 0.0%, Data types -> object
# stability_features:null value percentage -> 0.0%, Data types -> bool
# blind_spot_assistance:null value percentage -> 0.0%, Data types -> bool
# indicators:null value percentage -> 0.0%, Data types -> bool
# Adjustable_rear_view_mirror:null value percentage -> 0.0%, Data types -> bool
# fog_lamps:null value percentage -> 0.0%, Data types -> bool
# automatic_lamps:null value percentage -> 0.0%, Data types -> bool
# meters:null value percentage -> 0.0%, Data types -> bool
# car_roof:null value percentage -> 0.0%, Data types -> bool
# speakers:null value percentage -> 0.0%, Data types -> bool
# antenna:null value percentage -> 0.0%, Data types -> bool
# player:null value percentage -> 0.0%, Data types -> bool
# smartphone_integration:null value percentage -> 0.0%, Data types -> bool
# impact_beams:null value percentage -> 0.0%, Data types -> bool

# %%
# List of additional columns to fill NaN values based on mode by 'model'
additional_columns_to_fill = ['turbo_charger', 'super_charger','drive_type', 'cargo_volumn']

# Step 1: Calculate the mode of each column for each model value
mode_values_additional = {
    col: df_edit.groupby('model')[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
    for col in additional_columns_to_fill if col in df_edit.columns  # Ensure the column exists in the dataframe
}

# Step 2: Define the replace_nan function for each column
def replace_nan(row, col, values_dict):
    if pd.isnull(row[col]) and pd.notnull(row['model']):
        return values_dict.get(row['model'], row[col])
    return row[col]

# Step 3: Apply the function to update each column
for col in mode_values_additional:
    df_edit[col] = df_edit.apply(
        lambda row: replace_nan(row, col, mode_values_additional[col]),
        axis=1
    )

# Step 1: Calculate the percentage where gross_weight is not null
df_non_null = df_edit[df_edit['gross_weight'].notna()]
df_non_null['percentage_weight_calculation'] = ((df_non_null['gross_weight'] - df_non_null['kerb_weight']) / df_non_null['kerb_weight']) * 100

# Step 2: Compute the mean percentage
mean_percentage = df_non_null['percentage_weight_calculation'].mean()

# Step 3: Fill the null values in gross_weight using the mean percentage
df_edit.loc[df_edit['gross_weight'].isna(), 'gross_weight'] = df_edit['kerb_weight'] * (1 + mean_percentage / 100)
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_22940\1293886045.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_null['percentage_weight_calculation'] = ((df_non_null['gross_weight'] - df_non_null['kerb_weight']) / df_non_null['kerb_weight']) * 100

# %%
# List of columns to fill NaN values with mode
columns_to_fill_final = ['turbo_charger', 'super_charger', 'top_speed','cargo_volumn']

# Fill null values with mode for each column, ensuring the column exists
for column in columns_to_fill_final:
    if column in df_edit.columns:  # Check if the column exists
        mode_value = df_edit[column].mode()[0]  # Get the mode value
        df_edit[column].fillna(mode_value, inplace=True)  # Fill NaNs with the mode value

# %%
# Calculate the percentage of null values for each column
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100

# Identify columns with null percentage less than 5%
columns_to_drop = null_percentage[null_percentage < 5].index

# Drop rows with null values in those columns
df_edit = df_edit.dropna(subset=columns_to_drop)

# %%
null_percentage = (df_edit.isnull().sum() / len(df_edit)) * 100
columns_with_null_BT10to30 = null_percentage[(null_percentage > 0) & (null_percentage <= 100)]
print(columns_with_null_BT10to30)
print(columns_with_null_BT10to30.shape[0])
# Out:
# Series([], dtype: float64)
# 0

# %%
df_edit.to_excel('All_imputed_data.xlsx', index=False)
